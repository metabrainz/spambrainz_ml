# %%
# importing necessary libraries 
import numpy as np
import random
import pandas as pd
from urllib.parse import urlparse
import datetime
import pickle

# %%
size = 10000

# %% [markdown]
# # Non Spam dummy data creation

# %%
domains_data =  pd.read_csv("domains_data.csv")

# %%
domains_data.columns
# Out:
# Index(['spam_emails', 'spam_website', 'nonspam_emails', 'non_spam_website'], dtype='object')

# %% [markdown]
# ### non_spam_emails dummy data generation code

# %%
non_spam_emails_csv = list(domains_data['nonspam_emails'])
non_spam_emails_csv
# Out:
# ['a@gmail.com',
#  'a@outlook.com',
#  'a@yahoo.com',
#  'a@hotmail.com',
#  'a@mail.ru',
#  'a@vikilx.com',
#  'a@gmx.de',
#  'a@lexxip.com',
#  'a@web.de',
#  'a@aol.com',
#  'a@free.fr',
#  'a@gmx.net',
#  'a@quickenmails.com',
#  'a@hotmail.co.uk',
#  'a@yahoo.co.uk',
#  'a@googlemail.com',
#  'a@yahoo.fr',
#  'a@yandex.com',
#  'a@babymails.com',
#  'a@comcast.net',
#  'a@msn.com',
#  'a@o2.pl',
#  'a@mail.com',
#  'a@yahoo.de',
#  'a@hotmail.fr',
#  'a@gmx.com',
#  'a@live.com',
#  'a@mac.com',
#  'a@kodmailing.com',
#  'a@lovelymail.info',
#  'a@hubspotmails.com',
#  'a@wordpressmails.com',
#  'a@uminga.net',
#  'a@joomlaemails.com',
#  'a@hotspotmails.com',
#  'a@ibmmails.com',
#  'a@temasekmail.com',
#  'a@lolas3.seo-linuxpl.com',
#  'a@dupontmails.com',
#  'a@singtelmails.com',
#  'a@1st-apparelsoftware.info',
#  'a@abrighterfutureday.com',
#  'a@hypermailbox.com',
#  'a@cfphone.net',
#  'a@businesskontakts.com',
#  'a@drupalmails.com',
#  'a@deepemailbox.com',
#  'a@novartismails.com',
#  'a@padita.net',
#  'a@kingdomheartmail.com',
#  'a@anseohero.com',
#  'a@queenofsite.online',
#  'a@justbigbox.com',
#  'a@kingofplace.site',
#  'a@gloriousfuturedays.com',
#  'a@efacs.net',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com',
#  'a@webgarden.com']

# %%
non_spam_email_domains = {email.split("@")[1] for email in non_spam_emails_csv}
non_spam_email_domains = list(non_spam_email_domains)

# %%
non_spam_emails = list()
domains = list(non_spam_email_domains)
letters = ["a", "b", "c", "d","e", "f", "g", "h", "i", "j", "k", "l"]

def get_one_random_domain(domains):
        return domains[random.randint( 0, len(domains)-1)]


def get_one_random_name(letters):
    email_name = ""
    for i in range(7):
        email_name = email_name + letters[random.randint(0,11)]
    return email_name

def generate_random_emails(size):
    for i in range(0,size):
         one_name = str(get_one_random_name(letters))
         one_domain = str(get_one_random_domain(domains))  
         mail = one_name+'@'+one_domain
         non_spam_emails.append(mail)
generate_random_emails(size)

# %%
non_spam_emails
# Out:
# ['ggibhai@businesskontakts.com',
#  'ajkfieh@businesskontakts.com',
#  'igdkali@gmx.de',
#  'eilejdg@lexxip.com',
#  'calhkib@queenofsite.online',
#  'gcbekla@kodmailing.com',
#  'gigehfh@yahoo.com',
#  'ijhfkkj@o2.pl',
#  'ikglaee@singtelmails.com',
#  'hallkfj@lovelymail.info',
#  'fbehhlb@1st-apparelsoftware.info',
#  'idakbje@yahoo.de',
#  'ggbecjl@padita.net',
#  'eedaebc@justbigbox.com',
#  'fjdgkkf@hotspotmails.com',
#  'hkjlghi@yahoo.fr',
#  'gfibgkd@yahoo.co.uk',
#  'ieeidbg@kingdomheartmail.com',
#  'kgcaadh@msn.com',
#  'gijjjjc@gmx.net',
#  'ebakjhg@drupalmails.com',
#  'ldhahjb@mail.com',
#  'feckbii@yahoo.fr',
#  'egfjkla@wordpressmails.com',
#  'ggffcgi@vikilx.com',
#  'jiedjfa@yahoo.co.uk',
#  'gijekbl@hubspotmails.com',
#  'hddadij@gmx.com',
#  'iahebia@live.com',
#  'ekeadli@yahoo.fr',
#  'iehhfdc@gmx.net',
#  'lgadghk@efacs.net',
#  'hjlbibb@comcast.net',
#  'fbebbgd@ibmmails.com',
#  'hiaahec@comcast.net',
#  'clghejc@lolas3.seo-linuxpl.com',
#  'ffcaief@gmx.de',
#  'kkjcfcc@yandex.com',
#  'ifcihac@gmail.com',
#  'laefkij@singtelmails.com',
#  'fggdklf@temasekmail.com',
#  'dagjgda@ibmmails.com',
#  'jchdjek@gmx.com',
#  'djgidkl@web.de',
#  'aljfebc@padita.net',
#  'ccfiige@gmx.com',
#  'jfhgkdf@babymails.com',
#  'hkdcfke@padita.net',
#  'hkjifbg@uminga.net',
#  'jighgig@drupalmails.com',
#  'fadgflc@web.de',
#  'cechgje@quickenmails.com',
#  'hgehfbi@free.fr',
#  'jfkaied@lovelymail.info',
#  'cekdkbj@gmx.de',
#  'jdchjaj@deepemailbox.com',
#  'cfcihih@drupalmails.com',
#  'hldeckl@comcast.net',
#  'bedlejb@anseohero.com',
#  'cldiafe@queenofsite.online',
#  'kcdagae@anseohero.com',
#  'idllale@googlemail.com',
#  'cdgdjgi@1st-apparelsoftware.info',
#  'edefajg@ibmmails.com',
#  'hcfacaj@1st-apparelsoftware.info',
#  'afelidf@queenofsite.online',
#  'lefbhah@abrighterfutureday.com',
#  'gegidjd@singtelmails.com',
#  'glfkflg@yahoo.com',
#  'kblhabc@hypermailbox.com',
#  'hhedile@aol.com',
#  'clcabdk@lexxip.com',
#  'kjkjeab@deepemailbox.com',
#  'cjkcfhe@yahoo.de',
#  'ikdggcc@abrighterfutureday.com',
#  'fgjgdgf@padita.net',
#  'jbbkhha@gmx.net',
#  'lfhigcd@kingofplace.site',
#  'jjlekci@singtelmails.com',
#  'hlddgcc@uminga.net',
#  'bakgfgi@justbigbox.com',
#  'kfbhhji@msn.com',
#  'aagbgeg@deepemailbox.com',
#  'deaffgb@vikilx.com',
#  'lgfbgkf@efacs.net',
#  'fkkbchg@temasekmail.com',
#  'ljijgck@drupalmails.com',
#  'dlibfdk@joomlaemails.com',
#  'iaffghl@kingofplace.site',
#  'eficihl@wordpressmails.com',
#  'kdkjfge@babymails.com',
#  'deiihlf@web.de',
#  'hggdkkl@gloriousfuturedays.com',
#  'eliidah@lolas3.seo-linuxpl.com',
#  'daagjej@dupontmails.com',
#  'gclgkll@ibmmails.com',
#  'jedifec@gloriousfuturedays.com',
#  'kkkbjbj@yahoo.com',
#  'daljhle@ibmmails.com',
#  'ahflegc@aol.com',
#  'ggbhfea@live.com',
#  'lfkkaff@gmx.net',
#  'hghaiej@lolas3.seo-linuxpl.com',
#  'ggcflib@aol.com',
#  'bkafcac@temasekmail.com',
#  'jcealje@aol.com',
#  'cbdbkde@web.de',
#  'hgjlihg@gmx.de',
#  'hkbcgib@queenofsite.online',
#  'jjhlcga@free.fr',
#  'ebgihgi@yahoo.fr',
#  'hdeliik@abrighterfutureday.com',
#  'ggbdake@gmx.net',
#  'icekekj@deepemailbox.com',
#  'hchblhb@web.de',
#  'egflgfk@gmx.net',
#  'ggcblda@yahoo.co.uk',
#  'bhkiffh@msn.com',
#  'ideehfb@lexxip.com',
#  'djaeceb@hypermailbox.com',
#  'kjcjfhb@wordpressmails.com',
#  'bgbdhfk@deepemailbox.com',
#  'cikfeic@webgarden.com',
#  'lfgacel@hotmail.fr',
#  'dibkhfa@hotmail.co.uk',
#  'kjfbkci@uminga.net',
#  'bedalef@gmx.de',
#  'akhfkbj@gloriousfuturedays.com',
#  'akjbccf@abrighterfutureday.com',
#  'dkihklb@abrighterfutureday.com',
#  'dbfabfg@mail.com',
#  'kgdbefl@joomlaemails.com',
#  'cbjlcfe@hotmail.fr',
#  'kilagij@googlemail.com',
#  'fieehjk@kingofplace.site',
#  'ehgilgk@mail.ru',
#  'ibbafhk@hotmail.fr',
#  'cifceli@kodmailing.com',
#  'ccebcal@novartismails.com',
#  'cldhbgi@kodmailing.com',
#  'chjkdlj@mail.com',
#  'hfedhcc@kodmailing.com',
#  'ibjkkff@deepemailbox.com',
#  'bfldaab@hotmail.com',
#  'ifkblhb@gloriousfuturedays.com',
#  'kabjdcj@singtelmails.com',
#  'fbbjkji@web.de',
#  'faejklg@temasekmail.com',
#  'hiljghb@googlemail.com',
#  'klheajh@free.fr',
#  'kdkffif@wordpressmails.com',
#  'gdcdhlg@businesskontakts.com',
#  'kiiehai@mail.com',
#  'bfklfid@dupontmails.com',
#  'ehcdhgj@yahoo.de',
#  'cgfbadk@live.com',
#  'lchedhf@lovelymail.info',
#  'dchggll@wordpressmails.com',
#  'iifgahg@deepemailbox.com',
#  'ajdkfkc@babymails.com',
#  'ajehkjj@anseohero.com',
#  'edbjigl@hotspotmails.com',
#  'gkgbfck@yandex.com',
#  'eldbdff@hotmail.co.uk',
#  'kcgaghb@joomlaemails.com',
#  'aijhhae@temasekmail.com',
#  'dficjii@yahoo.fr',
#  'hbjeedh@mail.com',
#  'fbaebee@mail.com',
#  'fjbigfc@vikilx.com',
#  'ahebccc@1st-apparelsoftware.info',
#  'cbgjecb@o2.pl',
#  'gckcgje@o2.pl',
#  'bafjlgk@yandex.com',
#  'gdiihfj@hotspotmails.com',
#  'abjlgac@deepemailbox.com',
#  'jgdeldb@lexxip.com',
#  'bdahaal@hotmail.com',
#  'abhibae@lovelymail.info',
#  'ekiidff@webgarden.com',
#  'bfabcgi@uminga.net',
#  'fbcggdd@justbigbox.com',
#  'begfbca@yahoo.fr',
#  'cgjldkj@deepemailbox.com',
#  'ehibehf@mac.com',
#  'eedbfaa@hubspotmails.com',
#  'dffddgk@joomlaemails.com',
#  'cklglli@webgarden.com',
#  'hecekef@gmx.com',
#  'kcebidh@hotmail.fr',
#  'kgglihg@msn.com',
#  'iaaacgg@efacs.net',
#  'dihjgkd@dupontmails.com',
#  'lkhlada@drupalmails.com',
#  'hgjhlek@cfphone.net',
#  'cbkelah@gmx.de',
#  'ilkefgk@ibmmails.com',
#  'bjgflga@kingdomheartmail.com',
#  'hclakde@web.de',
#  'faalflj@ibmmails.com',
#  'heigdld@singtelmails.com',
#  'cjildbh@joomlaemails.com',
#  'dceahhk@gmx.de',
#  'djcjhgk@gmx.net',
#  'lfcccll@yahoo.com',
#  'ajghcli@mail.ru',
#  'ejjijce@web.de',
#  'accbced@vikilx.com',
#  'eiihjkf@padita.net',
#  'fdbdkid@gmx.com',
#  'aiechhh@padita.net',
#  'ckcdeha@abrighterfutureday.com',
#  'ihlljgg@mail.ru',
#  'ejedifg@kingofplace.site',
#  'ihhljll@yandex.com',
#  'glbbijc@1st-apparelsoftware.info',
#  'gefkaic@lolas3.seo-linuxpl.com',
#  'fllkfbh@o2.pl',
#  'ijbfagl@kingdomheartmail.com',
#  'jjjkgac@hotmail.co.uk',
#  'kicelbc@lolas3.seo-linuxpl.com',
#  'aabkfhk@yandex.com',
#  'jebehcg@singtelmails.com',
#  'ddeacdg@singtelmails.com',
#  'ilceack@cfphone.net',
#  'dglhicl@anseohero.com',
#  'lagbehc@yahoo.de',
#  'hbblhjf@hubspotmails.com',
#  'bffjdgg@anseohero.com',
#  'jilblbj@gmx.de',
#  'lgjllah@web.de',
#  'ehcigdf@babymails.com',
#  'ejlkkdf@cfphone.net',
#  'jljaajd@yahoo.co.uk',
#  'aajieeb@kodmailing.com',
#  'jgficab@hotmail.fr',
#  'hfdbjfk@hypermailbox.com',
#  'gekhdjg@quickenmails.com',
#  'chfijij@businesskontakts.com',
#  'ehacgae@lolas3.seo-linuxpl.com',
#  'lfjalcl@googlemail.com',
#  'bgadekl@mail.ru',
#  'dbfaikk@novartismails.com',
#  'iikehjl@wordpressmails.com',
#  'ekadhdj@googlemail.com',
#  'khchlge@justbigbox.com',
#  'ggdhacg@lolas3.seo-linuxpl.com',
#  'chblehl@yahoo.fr',
#  'hbjhbbg@lovelymail.info',
#  'fjkbkdb@lolas3.seo-linuxpl.com',
#  'jhjehid@webgarden.com',
#  'fhejkeb@hotmail.com',
#  'bilhlif@gmx.net',
#  'klaedbb@webgarden.com',
#  'khkidhl@queenofsite.online',
#  'clceaab@padita.net',
#  'kcbkhaa@mac.com',
#  'iljehkj@temasekmail.com',
#  'akdhfbl@comcast.net',
#  'jhkkhkc@hotspotmails.com',
#  'djkeehe@gmx.com',
#  'cgcacia@singtelmails.com',
#  'dgacflg@googlemail.com',
#  'bdldgak@hotmail.co.uk',
#  'jfgcjbf@joomlaemails.com',
#  'chlchdl@mail.ru',
#  'gikadlh@novartismails.com',
#  'ggfccfj@outlook.com',
#  'likffea@uminga.net',
#  'gffbgdh@padita.net',
#  'dcjkeaj@gmail.com',
#  'gcgdijb@yahoo.com',
#  'diedach@webgarden.com',
#  'jfffcfd@singtelmails.com',
#  'fgjfgig@mac.com',
#  'geciehg@o2.pl',
#  'jcbfael@gloriousfuturedays.com',
#  'kcheddj@novartismails.com',
#  'kbehakb@aol.com',
#  'ghjgdjc@web.de',
#  'bdakdlk@hubspotmails.com',
#  'efdehhb@hotspotmails.com',
#  'dcfeacg@wordpressmails.com',
#  'bdkclai@kingofplace.site',
#  'jfajcde@1st-apparelsoftware.info',
#  'jdcfaci@drupalmails.com',
#  'hkglbhf@outlook.com',
#  'ccgaeef@lexxip.com',
#  'lgjhlch@hotmail.fr',
#  'eedlalg@businesskontakts.com',
#  'kgblkbc@singtelmails.com',
#  'kebbhii@web.de',
#  'gjhjikg@quickenmails.com',
#  'helkgig@businesskontakts.com',
#  'dbeelel@quickenmails.com',
#  'aihfdkd@aol.com',
#  'bielebh@justbigbox.com',
#  'kahbidd@joomlaemails.com',
#  'flaafej@temasekmail.com',
#  'aeilffd@web.de',
#  'bghjidb@o2.pl',
#  'ddebcla@yahoo.co.uk',
#  'agkbkce@msn.com',
#  'fbbhbhg@o2.pl',
#  'icgjfbd@hotmail.co.uk',
#  'jiiiadi@dupontmails.com',
#  'kdjlabi@babymails.com',
#  'fehaehk@hubspotmails.com',
#  'bejfkek@gloriousfuturedays.com',
#  'acecaja@hotmail.fr',
#  'dfidhdk@msn.com',
#  'cabedbc@live.com',
#  'efececl@yahoo.com',
#  'efgkcal@1st-apparelsoftware.info',
#  'ihlbljk@novartismails.com',
#  'hkcbcai@uminga.net',
#  'alkjllk@deepemailbox.com',
#  'fcedfcj@mail.ru',
#  'chbdiif@quickenmails.com',
#  'gekdlai@kingofplace.site',
#  'ljhgbbb@hotmail.com',
#  'ejeehjf@mail.com',
#  'ajfkjek@ibmmails.com',
#  'eebejlh@comcast.net',
#  'kdhlaif@uminga.net',
#  'edcafda@aol.com',
#  'lhbalbb@lovelymail.info',
#  'fbahccb@aol.com',
#  'jeljbbf@dupontmails.com',
#  'aifjgjc@gmx.de',
#  'jbgfbda@lolas3.seo-linuxpl.com',
#  'bbhedkj@mac.com',
#  'cdbakfb@hypermailbox.com',
#  'llleilb@drupalmails.com',
#  'bcklblh@free.fr',
#  'hbcihkg@webgarden.com',
#  'hfifdad@msn.com',
#  'fblddcd@queenofsite.online',
#  'ahggglf@gmx.de',
#  'ijehkje@aol.com',
#  'ddlcjab@comcast.net',
#  'hjabcbe@quickenmails.com',
#  'kikjcjj@anseohero.com',
#  'gfbfkdk@lolas3.seo-linuxpl.com',
#  'ljdakfl@hotmail.fr',
#  'bbacbif@gmx.com',
#  'liifaci@padita.net',
#  'kijebke@googlemail.com',
#  'aikbdhg@mail.com',
#  'hcfelbj@gmx.net',
#  'cdfkkbe@quickenmails.com',
#  'ecadfaa@o2.pl',
#  'lfcahbf@googlemail.com',
#  'alilcdk@queenofsite.online',
#  'dbflfcc@hotmail.fr',
#  'jdfbfae@novartismails.com',
#  'igjjhgd@live.com',
#  'beieeka@mail.ru',
#  'bfcgeja@hotmail.com',
#  'kcafihi@vikilx.com',
#  'kkfddfb@vikilx.com',
#  'caagkbi@uminga.net',
#  'djbfbki@yahoo.fr',
#  'lehcjfj@hubspotmails.com',
#  'aijjllg@kingdomheartmail.com',
#  'ggckgig@yahoo.de',
#  'hdlcaca@uminga.net',
#  'dkfeehb@gmx.de',
#  'eijallj@gmx.com',
#  'hciljkg@googlemail.com',
#  'jicekef@padita.net',
#  'ebkljie@ibmmails.com',
#  'fdclcei@kingofplace.site',
#  'biijklj@yandex.com',
#  'edkghih@lolas3.seo-linuxpl.com',
#  'adgdldh@uminga.net',
#  'fiifjhl@queenofsite.online',
#  'eicjaef@lolas3.seo-linuxpl.com',
#  'gflbkkj@yahoo.co.uk',
#  'dllaihl@aol.com',
#  'ceiecle@lovelymail.info',
#  'kklbedj@yahoo.com',
#  'hghjfec@googlemail.com',
#  'gkjccie@abrighterfutureday.com',
#  'beilgga@web.de',
#  'aehfgec@dupontmails.com',
#  'bebjkhl@yahoo.de',
#  'kbdhbhc@msn.com',
#  'kahgkdj@cfphone.net',
#  'jjdhial@hubspotmails.com',
#  'affdgbl@singtelmails.com',
#  'dlkgdah@aol.com',
#  'lidghjc@kingdomheartmail.com',
#  'kdhjkll@aol.com',
#  'ijjjklf@kodmailing.com',
#  'jjjbagd@hotmail.com',
#  'accdgjk@temasekmail.com',
#  'kjbkjbi@web.de',
#  'dijbffb@cfphone.net',
#  'ilaebhk@dupontmails.com',
#  'bkcikee@anseohero.com',
#  'bicfcbk@outlook.com',
#  'jjfddck@webgarden.com',
#  'iijbbfi@hypermailbox.com',
#  'cdlffki@dupontmails.com',
#  'kaacfff@quickenmails.com',
#  'ageblkc@deepemailbox.com',
#  'keiddhi@cfphone.net',
#  'jadhihf@drupalmails.com',
#  'dgbhkeg@aol.com',
#  'ldddfhj@yahoo.de',
#  'jgdhdef@comcast.net',
#  'cfkgjlg@efacs.net',
#  'edgjhif@yahoo.de',
#  'laibkab@gmx.net',
#  'akfhaje@gmx.net',
#  'kfhadej@mail.com',
#  'abidade@gmx.de',
#  'ihkeijk@yandex.com',
#  'ceaiaie@yandex.com',
#  'bhlgeii@joomlaemails.com',
#  'laiejjd@mail.com',
#  'gdbbill@yandex.com',
#  'dkiadlc@abrighterfutureday.com',
#  'ehkajid@yahoo.com',
#  'ddelebh@gmx.com',
#  'ffgdcik@webgarden.com',
#  'daegbjk@kodmailing.com',
#  'edgclec@wordpressmails.com',
#  'fcfdgik@temasekmail.com',
#  'kkfkfhe@gmx.de',
#  'delehlk@hypermailbox.com',
#  'lgdlcij@kingdomheartmail.com',
#  'dhkjkfl@padita.net',
#  'hehbjlf@hotmail.com',
#  'kdhaaee@temasekmail.com',
#  'eeekdbj@anseohero.com',
#  'bkdajlh@quickenmails.com',
#  'bjhaljg@hotmail.co.uk',
#  'afeeflc@singtelmails.com',
#  'ighbglf@yahoo.com',
#  'bibkjca@uminga.net',
#  'iablgdc@justbigbox.com',
#  'iffcbll@lolas3.seo-linuxpl.com',
#  'liiecbd@gmail.com',
#  'lijdlih@padita.net',
#  'kdgejdl@uminga.net',
#  'edcbafd@abrighterfutureday.com',
#  'bdibghg@lexxip.com',
#  'fljclil@hotmail.fr',
#  'jchjgkb@novartismails.com',
#  'fbfecjc@googlemail.com',
#  'flddihc@abrighterfutureday.com',
#  'hllbkgd@comcast.net',
#  'bjhfjcg@quickenmails.com',
#  'hceeckc@wordpressmails.com',
#  'bhcjbde@yahoo.co.uk',
#  'jbgfbda@wordpressmails.com',
#  'hgeaiej@lexxip.com',
#  'edhdadf@babymails.com',
#  'ecglkdc@joomlaemails.com',
#  'lccijle@gmx.de',
#  'bfjfail@gloriousfuturedays.com',
#  'aiadfai@yahoo.com',
#  'gkfgdde@mail.com',
#  'kklbkbj@kingdomheartmail.com',
#  'ddaecdh@live.com',
#  'ljjdegf@googlemail.com',
#  'ldahgid@kingdomheartmail.com',
#  'fadjlgh@gmail.com',
#  'bjjbbch@gmx.net',
#  'ecbekki@outlook.com',
#  'cdeedck@joomlaemails.com',
#  'geaaebj@padita.net',
#  'bkjdifg@abrighterfutureday.com',
#  'hbckalh@kodmailing.com',
#  'eajkcli@joomlaemails.com',
#  'lkhhbcl@msn.com',
#  'djhabia@padita.net',
#  'lbjeblj@kodmailing.com',
#  'jbglfal@cfphone.net',
#  'eeijfib@padita.net',
#  'ledkabb@businesskontakts.com',
#  'kihlfcj@web.de',
#  'jkhdaef@efacs.net',
#  'gfkfilh@wordpressmails.com',
#  'igjllhf@dupontmails.com',
#  'ibgkkjb@outlook.com',
#  'iaicafc@kingdomheartmail.com',
#  'dhkeici@lolas3.seo-linuxpl.com',
#  'aifgdhl@businesskontakts.com',
#  'behclab@businesskontakts.com',
#  'fdjjdjg@live.com',
#  'iahehbi@gmx.de',
#  'keiibdh@msn.com',
#  'jagcfal@drupalmails.com',
#  'efdefll@gmx.de',
#  'ejdiikc@webgarden.com',
#  'ebfgjik@dupontmails.com',
#  'gldbhhh@aol.com',
#  'iecekbc@yahoo.com',
#  'gbfieah@gloriousfuturedays.com',
#  'lhbakfj@mac.com',
#  'bdjjekb@mac.com',
#  'ahebgkk@kingofplace.site',
#  'gdchfdg@free.fr',
#  'edblhlb@gloriousfuturedays.com',
#  'ihhfblg@temasekmail.com',
#  'ddebfkl@gloriousfuturedays.com',
#  'cdeifkd@gmx.net',
#  'jggildh@gmx.net',
#  'lklhiae@gmx.com',
#  'gfcfcjh@abrighterfutureday.com',
#  'lakehjc@outlook.com',
#  'hdjfalk@temasekmail.com',
#  'cjfeagh@quickenmails.com',
#  'hglefda@hotmail.com',
#  'dhechbh@hotmail.com',
#  'gcfegcj@hotmail.fr',
#  'cjbkfgl@hypermailbox.com',
#  'giighkc@abrighterfutureday.com',
#  'bedkklb@yahoo.de',
#  'jilckcb@abrighterfutureday.com',
#  'kigbaab@aol.com',
#  'igaiach@outlook.com',
#  'bhdlleh@joomlaemails.com',
#  'dlkiibg@yahoo.fr',
#  'glagajh@mac.com',
#  'ejcaakg@padita.net',
#  'egbehke@mail.ru',
#  'dekggfg@lovelymail.info',
#  'gljkdcj@kingdomheartmail.com',
#  'feghkgi@free.fr',
#  'lecgdgg@joomlaemails.com',
#  'kbgclbc@hubspotmails.com',
#  'aihlalf@hotmail.com',
#  'jhhehck@comcast.net',
#  'iakdelh@comcast.net',
#  'kakejfd@web.de',
#  'caiejbk@hotmail.co.uk',
#  'ghhadba@lovelymail.info',
#  'kcjigik@hypermailbox.com',
#  'fgfjaij@yahoo.com',
#  'haeldil@hubspotmails.com',
#  'ajkdbaj@hubspotmails.com',
#  'dldfgec@cfphone.net',
#  'kkjclhj@temasekmail.com',
#  'lcgdclf@efacs.net',
#  'fbjhhjb@msn.com',
#  'alaafef@hotmail.com',
#  'kgelcli@msn.com',
#  'lbhbkgb@anseohero.com',
#  'hblbibk@lexxip.com',
#  'jielakc@live.com',
#  'elcidgd@hotspotmails.com',
#  'bkibbjh@hotmail.fr',
#  'efilkef@1st-apparelsoftware.info',
#  'kjaijkj@web.de',
#  'ffeejkc@yahoo.com',
#  'jcajiki@yahoo.de',
#  'khbghbb@drupalmails.com',
#  'fcejebf@wordpressmails.com',
#  'ekkaced@outlook.com',
#  'ffdklka@mail.ru',
#  'dkejlbg@live.com',
#  'ieddafk@yandex.com',
#  'gihfdcl@outlook.com',
#  'ljibffd@mail.com',
#  'jdhhhda@hotmail.fr',
#  'ebeblca@yahoo.com',
#  'ckdfdfc@businesskontakts.com',
#  'gflddfd@mail.com',
#  'iceahdj@hypermailbox.com',
#  'cglfklh@1st-apparelsoftware.info',
#  'ifdblaa@ibmmails.com',
#  'jfclikd@efacs.net',
#  'bdehekj@padita.net',
#  'iihdlfa@aol.com',
#  'acdikfd@kingdomheartmail.com',
#  'hcfjiab@mail.com',
#  'kcglfeh@efacs.net',
#  'afcjblk@queenofsite.online',
#  'bgkdblh@deepemailbox.com',
#  'kejhfck@yahoo.de',
#  'heelbji@gmx.net',
#  'chjdadh@wordpressmails.com',
#  'gkklcil@aol.com',
#  'jdfdlab@ibmmails.com',
#  'ejgdiea@queenofsite.online',
#  'gkcjeae@padita.net',
#  'hjbkfgi@justbigbox.com',
#  'ikfbhdk@hotmail.fr',
#  'hhhihcf@yahoo.de',
#  'fdccbgi@dupontmails.com',
#  'kdhkdgj@mail.com',
#  'hekgild@mail.com',
#  'jhidjgd@lexxip.com',
#  'ldjfekg@padita.net',
#  'lidkkid@comcast.net',
#  'ejihaai@free.fr',
#  'ifddlfe@ibmmails.com',
#  'kaebdje@gmx.net',
#  'hgdecbk@temasekmail.com',
#  'dcliaej@mail.ru',
#  'fibkihc@ibmmails.com',
#  'haibahb@yahoo.co.uk',
#  'kcejeij@hotmail.co.uk',
#  'aecfghf@yahoo.com',
#  'bihcjla@msn.com',
#  'jaiaggk@msn.com',
#  'ibehdje@joomlaemails.com',
#  'blefbal@padita.net',
#  'ffijcac@hypermailbox.com',
#  'kgakbjl@anseohero.com',
#  'ckekebl@webgarden.com',
#  'jehfjad@quickenmails.com',
#  'bkajeed@yandex.com',
#  'hlbicbf@o2.pl',
#  'ajdfbgb@dupontmails.com',
#  'ifjajid@drupalmails.com',
#  'adkghhb@yandex.com',
#  'daceebj@mail.com',
#  'jidffhi@kingofplace.site',
#  'hcblehd@msn.com',
#  'jkheebl@web.de',
#  'hdlhiga@yahoo.de',
#  'bdbeigk@lexxip.com',
#  'egdaclc@mail.com',
#  'ekhakeg@kingofplace.site',
#  'bjggija@uminga.net',
#  'kcecbbl@mac.com',
#  'begfafh@lexxip.com',
#  'ckcfeae@joomlaemails.com',
#  'cbjehjc@uminga.net',
#  'gldihbc@1st-apparelsoftware.info',
#  'fchagfa@lovelymail.info',
#  'gkigbcf@live.com',
#  'lkkakfc@o2.pl',
#  'dbkakhl@joomlaemails.com',
#  'cadkffa@1st-apparelsoftware.info',
#  'kacegde@aol.com',
#  'fhhjiji@queenofsite.online',
#  'gjchild@lexxip.com',
#  'gfblefe@yahoo.co.uk',
#  'adkbkfk@gmail.com',
#  'effkfbj@anseohero.com',
#  'kabdglk@lovelymail.info',
#  'adlfiad@quickenmails.com',
#  'dgedfec@justbigbox.com',
#  'clkbegi@babymails.com',
#  'gfgalhf@yahoo.com',
#  'aghedfk@padita.net',
#  'aghlijf@cfphone.net',
#  'kfahgdb@lolas3.seo-linuxpl.com',
#  'kiejflj@justbigbox.com',
#  'cjcliej@novartismails.com',
#  'dbdegjc@gmail.com',
#  'dfjkeji@hotmail.fr',
#  'fffaeie@queenofsite.online',
#  'abbeahj@webgarden.com',
#  'kgccdhj@gmx.net',
#  'djehjll@o2.pl',
#  'eeagdil@dupontmails.com',
#  'echecle@googlemail.com',
#  'lljbecc@yahoo.com',
#  'dclldgl@lovelymail.info',
#  'lealbfj@vikilx.com',
#  'ecjbkid@mail.ru',
#  'bakidaf@yahoo.fr',
#  'feadchh@hotmail.co.uk',
#  'hablkaj@kodmailing.com',
#  'bklceak@free.fr',
#  'kljjffj@yandex.com',
#  'ekhgedi@businesskontakts.com',
#  'kcljdca@gmx.net',
#  'kfjefce@kingdomheartmail.com',
#  'fgebllb@free.fr',
#  'cijhbfg@googlemail.com',
#  'jgkahej@gloriousfuturedays.com',
#  'ljjcgac@outlook.com',
#  'fgccbak@deepemailbox.com',
#  'hijjgbb@cfphone.net',
#  'eglihbf@aol.com',
#  'dckgead@hotmail.com',
#  'hifihal@anseohero.com',
#  'cjgbfkj@dupontmails.com',
#  'flehjdi@hypermailbox.com',
#  'ajkiell@gmx.com',
#  'fefhigg@gloriousfuturedays.com',
#  'dijkjdd@lovelymail.info',
#  'hhfbfjb@kingdomheartmail.com',
#  'fbdkibi@gmx.net',
#  'lahhdhg@webgarden.com',
#  'hajcgii@outlook.com',
#  'ehfkkll@aol.com',
#  'bjhkdce@mail.ru',
#  'kdbfgja@anseohero.com',
#  'jhbiali@dupontmails.com',
#  'bcgkfck@quickenmails.com',
#  'gfdghhh@quickenmails.com',
#  'hlgeigd@anseohero.com',
#  'ccdeihk@free.fr',
#  'ddhdahf@googlemail.com',
#  'kaibglj@efacs.net',
#  'afeeike@hypermailbox.com',
#  'dabjcak@web.de',
#  'beklbjb@kingdomheartmail.com',
#  'alihhjj@businesskontakts.com',
#  'bdafhda@lexxip.com',
#  'agdeidl@webgarden.com',
#  'cjijkci@outlook.com',
#  'lcfbkga@lexxip.com',
#  'afjijaa@mail.ru',
#  'dgklceg@drupalmails.com',
#  'lgiklab@msn.com',
#  'agbijej@babymails.com',
#  'lclikec@novartismails.com',
#  'blbkkcj@queenofsite.online',
#  'lfbhged@gmx.net',
#  'kfjcbbj@hypermailbox.com',
#  'ikhhbea@joomlaemails.com',
#  'bgbdfhd@hotmail.fr',
#  'fglbhki@deepemailbox.com',
#  'gaajlla@hotmail.com',
#  'acljcki@queenofsite.online',
#  'hcfehej@babymails.com',
#  'giecdlk@gmx.com',
#  'cgjflde@kingdomheartmail.com',
#  'kdhbhge@hypermailbox.com',
#  'hdjilkj@hotmail.com',
#  'khijccd@hotmail.fr',
#  'kadklai@wordpressmails.com',
#  'cdbbajf@justbigbox.com',
#  'hljgbfg@hubspotmails.com',
#  'hakahhc@yahoo.de',
#  'ebffcjk@hotspotmails.com',
#  'igkbdjj@drupalmails.com',
#  'clcejfk@kodmailing.com',
#  'lilgdcg@justbigbox.com',
#  'lcljbai@drupalmails.com',
#  'ikeejkd@drupalmails.com',
#  'aegddjf@temasekmail.com',
#  'gigcegd@kingdomheartmail.com',
#  'cjfijai@gloriousfuturedays.com',
#  'ilkabfd@yahoo.fr',
#  'gffhbab@web.de',
#  'bkeleib@singtelmails.com',
#  'lljcike@cfphone.net',
#  'chdjbkf@aol.com',
#  'keffdag@joomlaemails.com',
#  'bfckhdc@vikilx.com',
#  'lldhfbk@mail.ru',
#  'ghbhfda@vikilx.com',
#  'kkjhecl@joomlaemails.com',
#  'jjdelai@mail.ru',
#  'fkaciag@mail.com',
#  'dacblfi@wordpressmails.com',
#  'liiijdb@ibmmails.com',
#  'idfjhbf@o2.pl',
#  'acbjgfe@hotmail.com',
#  'lflccii@yahoo.com',
#  'cdhiadi@gmx.de',
#  'dibbeij@gmx.de',
#  'kkkccfa@kingofplace.site',
#  'ejbhchc@1st-apparelsoftware.info',
#  'ehblbbb@singtelmails.com',
#  'egkgljd@comcast.net',
#  'dbebilk@comcast.net',
#  'hgdlbhe@anseohero.com',
#  'ckgaaff@babymails.com',
#  'chidibj@yahoo.de',
#  'fikghah@web.de',
#  'jcgbbce@singtelmails.com',
#  'fdiakkb@wordpressmails.com',
#  'bfkgadi@hotmail.com',
#  'afhagik@msn.com',
#  'ijefgkj@mac.com',
#  'ikbkgbd@lolas3.seo-linuxpl.com',
#  'jkhkbcb@hubspotmails.com',
#  'ficgkic@novartismails.com',
#  'feehfie@mail.ru',
#  'dffbbfe@abrighterfutureday.com',
#  'bdcdgke@hotmail.com',
#  'icgekfb@hotspotmails.com',
#  'aeaibjh@queenofsite.online',
#  'lgjfiag@lexxip.com',
#  'gklfgac@1st-apparelsoftware.info',
#  'gacbjib@live.com',
#  'ejabkec@padita.net',
#  'lhgdcdf@justbigbox.com',
#  'clfifaf@yahoo.com',
#  'jlfakeb@anseohero.com',
#  'hcjjjib@gloriousfuturedays.com',
#  'hklflcb@webgarden.com',
#  'icfiedk@wordpressmails.com',
#  'fkedjfk@yahoo.co.uk',
#  'jghkiei@webgarden.com',
#  'ggkdcfi@comcast.net',
#  'chchffj@live.com',
#  'efjichc@yahoo.co.uk',
#  'gkebdbg@queenofsite.online',
#  'fafekgf@hotmail.co.uk',
#  'igclhbe@hotmail.fr',
#  'bggkkda@cfphone.net',
#  'kbfdahi@webgarden.com',
#  'ffcafca@hotmail.fr',
#  'hjagbkf@live.com',
#  'iahkdba@singtelmails.com',
#  'blidfgb@vikilx.com',
#  'dkedljh@lovelymail.info',
#  'jfekifa@cfphone.net',
#  'ckkgfbh@free.fr',
#  'ecedfic@gloriousfuturedays.com',
#  'ggahgcg@mail.com',
#  'bhekhla@1st-apparelsoftware.info',
#  'ieclhkc@hotspotmails.com',
#  'faciikj@drupalmails.com',
#  'gijldkg@gmx.net',
#  'fdgeikf@aol.com',
#  'dcdbbek@hotmail.co.uk',
#  'cefelei@quickenmails.com',
#  'cjjgheg@webgarden.com',
#  'jibldla@deepemailbox.com',
#  'hcfhkel@live.com',
#  'lkfjihf@lexxip.com',
#  'akkgaak@efacs.net',
#  'fkhihdi@yahoo.com',
#  'fiahikd@lolas3.seo-linuxpl.com',
#  'kjjebfg@googlemail.com',
#  'fjcaacj@singtelmails.com',
#  'gllffec@kingofplace.site',
#  'bghbhcl@lovelymail.info',
#  'jbjfihe@gmail.com',
#  'dgggadc@businesskontakts.com',
#  'dehhdik@aol.com',
#  'ilfflkb@mail.ru',
#  'kddcffe@businesskontakts.com',
#  'gebdfkc@singtelmails.com',
#  'lbggkae@abrighterfutureday.com',
#  'bjlbgfa@kingofplace.site',
#  'bjgadif@deepemailbox.com',
#  'bkgggbj@kodmailing.com',
#  'fjibjlj@babymails.com',
#  'fddcehb@yahoo.co.uk',
#  'eabeaeb@uminga.net',
#  'ilcjejj@gmail.com',
#  'kakefjh@abrighterfutureday.com',
#  'gaiabji@anseohero.com',
#  'babfglf@wordpressmails.com',
#  'fdifdbd@businesskontakts.com',
#  'dbelbih@gloriousfuturedays.com',
#  'hilccjf@wordpressmails.com',
#  'elbbaaj@mail.com',
#  'hiahlkf@kingofplace.site',
#  'bigahfd@padita.net',
#  'lfgkaah@comcast.net',
#  'hjldefb@free.fr',
#  'dcdakhh@mac.com',
#  'jjhhlee@hotspotmails.com',
#  'ighfdfl@uminga.net',
#  'kajlaej@outlook.com',
#  'jajlckk@lolas3.seo-linuxpl.com',
#  'haghklc@kingdomheartmail.com',
#  'ihhfbbl@lexxip.com',
#  'fjkdjeh@yahoo.de',
#  'abfkkka@lexxip.com',
#  'ggiiiab@1st-apparelsoftware.info',
#  'ajbcefa@1st-apparelsoftware.info',
#  'ghlgleg@gloriousfuturedays.com',
#  'febccle@deepemailbox.com',
#  'dhbdihc@gmail.com',
#  'jfkhehk@gmx.net',
#  'ekkiahe@gmx.de',
#  'fbbblia@justbigbox.com',
#  'fkbghbj@hubspotmails.com',
#  'fgdeaaf@hotmail.fr',
#  'adibghd@abrighterfutureday.com',
#  'jafbhac@drupalmails.com',
#  'afkhkeb@gmail.com',
#  'dijkdef@efacs.net',
#  'cejgdal@hotspotmails.com',
#  'kkjgfje@lolas3.seo-linuxpl.com',
#  'iiaihje@msn.com',
#  'dcajdkg@yahoo.de',
#  'dgcdhgb@yandex.com',
#  'jckcjli@googlemail.com',
#  'bicjlda@gmx.com',
#  'aeaidgh@lolas3.seo-linuxpl.com',
#  'bkikdcg@efacs.net',
#  'egjbgba@wordpressmails.com',
#  'dlhbigi@yahoo.fr',
#  'jcjfged@justbigbox.com',
#  'lgkblab@hubspotmails.com',
#  'lbebcld@webgarden.com',
#  'glfklli@yahoo.de',
#  'edbebjj@aol.com',
#  'bgblejd@kingofplace.site',
#  'jbglhlj@mail.ru',
#  'cglcbgl@lovelymail.info',
#  'bkejled@vikilx.com',
#  'ddfbakl@hotmail.com',
#  'ifhbgeg@queenofsite.online',
#  'kiffgeh@uminga.net',
#  'lgdbfjc@temasekmail.com',
#  'cgekkfg@wordpressmails.com',
#  'elkljbb@googlemail.com',
#  'hiiidef@abrighterfutureday.com',
#  'jeckcag@deepemailbox.com',
#  'cibjghd@mail.com',
#  'ghbkjgb@singtelmails.com',
#  'kdlllhk@cfphone.net',
#  'dehijke@hotspotmails.com',
#  'ifefbkl@webgarden.com',
#  'ieiaikj@dupontmails.com',
#  'fclbghk@babymails.com',
#  'facabdh@yahoo.de',
#  'fhcablk@wordpressmails.com',
#  'flggbhd@deepemailbox.com',
#  'ghhjebj@hotmail.com',
#  'bciajda@mail.com',
#  'hbhcfca@businesskontakts.com',
#  'ejcegga@yahoo.de',
#  'kfhbhgd@gmx.com',
#  'agidkkf@mac.com',
#  'lcbdecg@lexxip.com',
#  'jedebai@joomlaemails.com',
#  'aeikhgh@queenofsite.online',
#  'chbjhcg@uminga.net',
#  'bkddffh@mail.ru',
#  'agdkcbk@gmx.de',
#  'ibackjg@efacs.net',
#  'clcabig@temasekmail.com',
#  'jdicbcf@hotmail.com',
#  'cdibiie@mail.ru',
#  'jbeflee@babymails.com',
#  'lekgjbg@googlemail.com',
#  'acjbflh@o2.pl',
#  'ebfgclk@googlemail.com',
#  'bjgcgfg@hypermailbox.com',
#  'iefaibe@yahoo.de',
#  'bejfbjb@joomlaemails.com',
#  'higcgcg@yahoo.fr',
#  'clhckkc@kingofplace.site',
#  'clbdghk@hotmail.com',
#  'jabgdee@deepemailbox.com',
#  'hdjbibd@yahoo.de',
#  'jlkilfa@kingdomheartmail.com',
#  'aldjihi@abrighterfutureday.com',
#  'glgclbk@hotspotmails.com',
#  'jhjfgeb@efacs.net',
#  'khggccb@hotmail.com',
#  'hcdaacg@o2.pl',
#  'fcciicj@queenofsite.online',
#  'addkcdg@yahoo.com',
#  'lahadae@hubspotmails.com',
#  'ghbblii@singtelmails.com',
#  'hdjlaee@quickenmails.com',
#  'dijcagc@uminga.net',
#  'dkiidih@kingofplace.site',
#  'gejcjjk@gmx.de',
#  'biaeajc@dupontmails.com',
#  'jhhdjfl@live.com',
#  'dafildi@justbigbox.com',
#  'jkhjjlg@outlook.com',
#  'jbfbjlc@singtelmails.com',
#  'glfggga@gmx.net',
#  'cbdfhef@gmx.de',
#  'kibgfbf@webgarden.com',
#  'dlglbgh@yahoo.co.uk',
#  'igafbje@free.fr',
#  'gfbdkkf@cfphone.net',
#  'ilechia@justbigbox.com',
#  'igbfkej@novartismails.com',
#  'lgkgflh@joomlaemails.com',
#  'egdfhbl@vikilx.com',
#  'eiidlfa@justbigbox.com',
#  'fdhlgdl@businesskontakts.com',
#  'gacaedl@lovelymail.info',
#  'kcbklja@mail.ru',
#  'hkkgakh@dupontmails.com',
#  'kliijle@gmail.com',
#  'hlhkijl@cfphone.net',
#  'alecdib@hotspotmails.com',
#  'jaiehhk@hotmail.co.uk',
#  'fgdjcdh@gmx.net',
#  'kgaeeif@hotmail.co.uk',
#  'ljlghcb@gmail.com',
#  'jkcdeaf@outlook.com',
#  'achkalj@novartismails.com',
#  'hgfchje@wordpressmails.com',
#  'hchcack@lovelymail.info',
#  'idfldaf@hotmail.co.uk',
#  'chbbhbk@kodmailing.com',
#  'bgekibe@novartismails.com',
#  'fbjcjjh@hotmail.co.uk',
#  'jljdedb@gmx.net',
#  'gcdkfba@hotmail.co.uk',
#  'gieeidb@queenofsite.online',
#  'hlgabhf@joomlaemails.com',
#  'igciack@lolas3.seo-linuxpl.com',
#  ...]

# %% [markdown]
# ### non_spam_websites dummy data generation code

# %%
non_spam_website_csv = domains_data["non_spam_website"]
non_spam_website_domains = {urlparse(website).hostname for website in non_spam_website_csv}

# %%
non_spam_websites = list()
non_spam_website_domains = list(non_spam_website_domains)
sometimes_https = [random.randint(1,size-1) for i in range(0,int(size/10))]
sometimes_none = [random.randint(1,size-1) for i in range(0,int(size/2.2))]
def generate_website_domains():
    for i in range(0,size):
        one_name = str(get_one_random_name(letters))
        one_domain = str(get_one_random_domain(non_spam_website_domains)) 
        prefix = "http"
        if i in sometimes_https: 
                prefix = "https"
        website = prefix+"://"+one_domain
        non_spam_websites.append(website)
generate_website_domains()
for i in sometimes_none:
    non_spam_websites[i] = None
non_spam_websites
# Out:
# ['http://www.yelp.com',
#  None,
#  None,
#  'https://www.indexemperor.com',
#  None,
#  None,
#  'http://www.google.com',
#  None,
#  None,
#  None,
#  None,
#  'http://bit.ly',
#  'http://gametruetool.com',
#  None,
#  None,
#  'http://www.linkemperor.com',
#  'http://foursquare.com',
#  'http://plus.google.com',
#  'http://www.google.com',
#  'http://www.mangodiet.com',
#  'https://youtu.be',
#  'http://www.indexemperor.com',
#  'http://valeur-dachat.fr',
#  'http://www.yelp.com',
#  None,
#  'http://valeur-dachat.fr',
#  'http://holding30.wordpress.com',
#  'http://www.animuj.pl',
#  'http://foursquare.com',
#  'http://www.animuj.pl',
#  'http://www.linkemperor.com',
#  'http://valeur-dachat.fr',
#  'http://www.facebook.com',
#  'http://www.yelp.com',
#  'http://youtu.be',
#  'http://www.facebook.com',
#  'http://youtu.be',
#  'http://www.mangodiet.com',
#  'http://www.facebook.com',
#  'http://www.yelp.com',
#  'http://www.yahoo.com',
#  None,
#  'http://finance.yahoo.com',
#  'https://www.google.com',
#  'http://storify.com',
#  'http://twitter.com',
#  'http://bit.ly',
#  'http://gametruetool.com',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'http://storify.com',
#  'http://www.facebook.com',
#  None,
#  None,
#  'http://foursquare.com',
#  'http://www.youtube.com',
#  'http://www.youtube.com',
#  'http://plus.google.com',
#  None,
#  None,
#  None,
#  None,
#  'http://bit.ly',
#  'http://www.facebook.com',
#  None,
#  'http://www.indexemperor.com',
#  'http://www.indexemperor.com',
#  None,
#  'http://www.indexemperor.com',
#  None,
#  None,
#  None,
#  'http://www.linkemperor.com',
#  'http://twitter.com',
#  None,
#  None,
#  None,
#  None,
#  'https://goo.gl',
#  'http://twitter.com',
#  'http://www.facebook.com',
#  'http://finance.yahoo.com',
#  None,
#  'http://goo.gl',
#  None,
#  'http://valeur-dachat.fr',
#  'http://plus.google.com',
#  None,
#  'http://gametruetool.com',
#  None,
#  'http://www.animuj.pl',
#  'http://holding30.wordpress.com',
#  'http://www.animuj.pl',
#  'http://www.yahoo.com',
#  None,
#  'http://www.yahoo.com',
#  'http://www.yelp.com',
#  None,
#  None,
#  'http://storify.com',
#  None,
#  'http://www.youtube.com',
#  None,
#  'http://goo.gl',
#  None,
#  'http://valeur-dachat.fr',
#  'http://www.linkemperor.com',
#  'http://www.google.com',
#  'http://embreveaqui.indisciplinar.com',
#  'http://storify.com',
#  None,
#  'http://www.yelp.com',
#  None,
#  'http://foursquare.com',
#  None,
#  'http://www.youtube.com',
#  None,
#  'http://wiki.piraatit.fi',
#  'http://www.youtube.com',
#  'http://www.facebook.com',
#  'http://www.vegasbottle.com',
#  'http://www.facebook.com',
#  None,
#  'http://plus.google.com',
#  None,
#  'http://youtu.be',
#  None,
#  'http://www.animuj.pl',
#  None,
#  'http://gametruetool.com',
#  'http://storify.com',
#  'http://www.google.com',
#  None,
#  None,
#  None,
#  'http://bit.ly',
#  'http://gametruetool.com',
#  None,
#  None,
#  'http://www.indexemperor.com',
#  'http://www.yahoo.com',
#  'http://www.facebook.com',
#  'http://www.facebook.com',
#  'https://www.animuj.pl',
#  'http://www.mangodiet.com',
#  None,
#  None,
#  None,
#  None,
#  'http://finance.yahoo.com',
#  'http://www.animuj.pl',
#  None,
#  None,
#  None,
#  None,
#  'http://www.yelp.com',
#  'http://www.indexemperor.com',
#  None,
#  'http://www.youtube.com',
#  None,
#  'http://kauf-wert.de',
#  None,
#  'http://gametruetool.com',
#  'http://www.youtube.com',
#  None,
#  None,
#  'http://www.yelp.com',
#  'http://gametruetool.com',
#  'http://foursquare.com',
#  None,
#  'http://foursquare.com',
#  None,
#  None,
#  None,
#  'http://www.mangodiet.com',
#  None,
#  'http://www.google.com',
#  'http://www.animuj.pl',
#  None,
#  None,
#  'http://www.youtube.com',
#  None,
#  'http://www.yahoo.com',
#  None,
#  None,
#  'http://bit.ly',
#  'http://www.google.com',
#  'http://embreveaqui.indisciplinar.com',
#  'http://bit.ly',
#  'http://storify.com',
#  None,
#  'http://youtu.be',
#  'http://finance.yahoo.com',
#  'http://www.yahoo.com',
#  None,
#  'http://youtu.be',
#  'http://storify.com',
#  'http://kauf-wert.de',
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  'http://gametruetool.com',
#  'http://valeur-dachat.fr',
#  'http://www.yahoo.com',
#  'http://www.yelp.com',
#  None,
#  None,
#  None,
#  None,
#  'http://www.youtube.com',
#  'http://plus.google.com',
#  'http://www.linkemperor.com',
#  'http://www.google.com',
#  'http://youtu.be',
#  None,
#  'http://www.youtube.com',
#  'http://www.youtube.com',
#  'http://valeur-dachat.fr',
#  'http://wiki.piraatit.fi',
#  'http://www.facebook.com',
#  None,
#  'http://www.animuj.pl',
#  'https://holding30.wordpress.com',
#  None,
#  'http://kauf-wert.de',
#  'http://www.yahoo.com',
#  None,
#  'http://plus.google.com',
#  None,
#  'http://foursquare.com',
#  'http://www.indexemperor.com',
#  'http://valeur-dachat.fr',
#  None,
#  'http://foursquare.com',
#  'http://www.yelp.com',
#  'http://embreveaqui.indisciplinar.com',
#  'http://finance.yahoo.com',
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  'http://storify.com',
#  'http://www.indexemperor.com',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'http://plus.google.com',
#  'http://www.yelp.com',
#  'https://foursquare.com',
#  None,
#  None,
#  'http://plus.google.com',
#  'http://storify.com',
#  'http://wiki.piraatit.fi',
#  'http://wiki.piraatit.fi',
#  'http://www.youtube.com',
#  'http://www.linkemperor.com',
#  'https://www.linkemperor.com',
#  'http://www.youtube.com',
#  'http://www.mangodiet.com',
#  None,
#  None,
#  'http://wiki.piraatit.fi',
#  'http://www.google.com',
#  'http://finance.yahoo.com',
#  'http://kauf-wert.de',
#  'http://gametruetool.com',
#  'http://foursquare.com',
#  'http://www.google.com',
#  None,
#  None,
#  None,
#  None,
#  'http://storify.com',
#  'http://storify.com',
#  'https://storify.com',
#  'http://valeur-dachat.fr',
#  'http://storify.com',
#  None,
#  'http://www.facebook.com',
#  'http://www.youtube.com',
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'http://www.youtube.com',
#  None,
#  None,
#  'http://www.youtube.com',
#  'http://holding30.wordpress.com',
#  'http://gametruetool.com',
#  'http://gametruetool.com',
#  'http://www.facebook.com',
#  None,
#  'http://valeur-dachat.fr',
#  'http://www.indexemperor.com',
#  'http://finance.yahoo.com',
#  None,
#  None,
#  'http://www.yahoo.com',
#  'https://kauf-wert.de',
#  'http://bit.ly',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  None,
#  'https://storify.com',
#  'http://twitter.com',
#  'http://www.animuj.pl',
#  'http://www.vegasbottle.com',
#  'http://www.animuj.pl',
#  None,
#  'http://storify.com',
#  None,
#  'http://www.linkemperor.com',
#  None,
#  'http://www.vegasbottle.com',
#  None,
#  'http://goo.gl',
#  None,
#  None,
#  'http://www.indexemperor.com',
#  None,
#  'http://kauf-wert.de',
#  None,
#  'http://www.indexemperor.com',
#  None,
#  None,
#  None,
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  None,
#  None,
#  'http://www.indexemperor.com',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  None,
#  'http://www.yelp.com',
#  'http://holding30.wordpress.com',
#  None,
#  'http://gametruetool.com',
#  None,
#  'http://www.animuj.pl',
#  None,
#  'http://kauf-wert.de',
#  'http://embreveaqui.indisciplinar.com',
#  'http://embreveaqui.indisciplinar.com',
#  'http://kauf-wert.de',
#  'http://finance.yahoo.com',
#  'https://www.google.com',
#  None,
#  'http://youtu.be',
#  'http://gametruetool.com',
#  'https://wiki.piraatit.fi',
#  None,
#  'http://holding30.wordpress.com',
#  'http://foursquare.com',
#  'http://youtu.be',
#  'http://www.animuj.pl',
#  'http://www.mangodiet.com',
#  'https://embreveaqui.indisciplinar.com',
#  None,
#  'http://www.youtube.com',
#  'http://finance.yahoo.com',
#  'http://twitter.com',
#  None,
#  None,
#  'http://storify.com',
#  'http://www.mangodiet.com',
#  'https://finance.yahoo.com',
#  'http://www.mangodiet.com',
#  'http://www.mangodiet.com',
#  None,
#  'http://foursquare.com',
#  'http://bit.ly',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  'http://www.google.com',
#  'http://goo.gl',
#  None,
#  'http://twitter.com',
#  None,
#  'http://gametruetool.com',
#  None,
#  None,
#  None,
#  'http://youtu.be',
#  'https://gametruetool.com',
#  None,
#  'http://holding30.wordpress.com',
#  'http://finance.yahoo.com',
#  'http://storify.com',
#  None,
#  'http://www.facebook.com',
#  'http://holding30.wordpress.com',
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  'http://gametruetool.com',
#  'http://gametruetool.com',
#  'http://youtu.be',
#  None,
#  'http://www.linkemperor.com',
#  'http://www.animuj.pl',
#  'http://www.vegasbottle.com',
#  'http://finance.yahoo.com',
#  None,
#  'http://bit.ly',
#  'http://www.vegasbottle.com',
#  'http://goo.gl',
#  None,
#  None,
#  'http://gametruetool.com',
#  None,
#  None,
#  'http://www.facebook.com',
#  None,
#  'http://twitter.com',
#  None,
#  None,
#  None,
#  'http://youtu.be',
#  None,
#  'http://finance.yahoo.com',
#  'http://www.google.com',
#  None,
#  'http://www.indexemperor.com',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'http://goo.gl',
#  'http://wiki.piraatit.fi',
#  None,
#  'http://storify.com',
#  'http://goo.gl',
#  'http://www.google.com',
#  'http://gametruetool.com',
#  None,
#  'http://www.facebook.com',
#  'http://storify.com',
#  None,
#  'http://gametruetool.com',
#  'http://www.vegasbottle.com',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://wiki.piraatit.fi',
#  None,
#  None,
#  'http://youtu.be',
#  'http://www.facebook.com',
#  'http://storify.com',
#  None,
#  'http://www.google.com',
#  'http://holding30.wordpress.com',
#  'http://wiki.piraatit.fi',
#  None,
#  'http://www.animuj.pl',
#  'http://www.animuj.pl',
#  'http://embreveaqui.indisciplinar.com',
#  'http://www.youtube.com',
#  None,
#  None,
#  'http://valeur-dachat.fr',
#  'http://www.facebook.com',
#  'http://foursquare.com',
#  'http://finance.yahoo.com',
#  None,
#  'http://embreveaqui.indisciplinar.com',
#  'http://twitter.com',
#  'http://gametruetool.com',
#  None,
#  'http://www.youtube.com',
#  None,
#  'http://www.google.com',
#  'http://bit.ly',
#  None,
#  None,
#  'http://plus.google.com',
#  None,
#  None,
#  None,
#  None,
#  'http://gametruetool.com',
#  'http://finance.yahoo.com',
#  'http://www.linkemperor.com',
#  'http://www.facebook.com',
#  None,
#  None,
#  'http://www.linkemperor.com',
#  None,
#  None,
#  'http://wiki.piraatit.fi',
#  'http://twitter.com',
#  'http://kauf-wert.de',
#  'http://www.vegasbottle.com',
#  'http://foursquare.com',
#  'http://gametruetool.com',
#  'https://storify.com',
#  'http://www.youtube.com',
#  'http://holding30.wordpress.com',
#  'http://holding30.wordpress.com',
#  'http://plus.google.com',
#  None,
#  'http://www.yelp.com',
#  'http://www.linkemperor.com',
#  None,
#  'http://www.linkemperor.com',
#  'http://goo.gl',
#  'http://www.animuj.pl',
#  'http://www.linkemperor.com',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'http://www.youtube.com',
#  None,
#  'http://www.yelp.com',
#  'http://goo.gl',
#  None,
#  None,
#  'http://foursquare.com',
#  None,
#  None,
#  None,
#  None,
#  'http://valeur-dachat.fr',
#  'http://www.indexemperor.com',
#  None,
#  'http://www.mangodiet.com',
#  'http://goo.gl',
#  None,
#  'http://www.youtube.com',
#  'https://finance.yahoo.com',
#  None,
#  None,
#  'http://www.yahoo.com',
#  'http://foursquare.com',
#  None,
#  None,
#  'http://kauf-wert.de',
#  None,
#  'http://kauf-wert.de',
#  'http://twitter.com',
#  'http://bit.ly',
#  None,
#  'http://plus.google.com',
#  'http://bit.ly',
#  'http://www.google.com',
#  None,
#  None,
#  None,
#  None,
#  'http://wiki.piraatit.fi',
#  None,
#  'http://bit.ly',
#  'http://www.animuj.pl',
#  'http://www.yelp.com',
#  None,
#  'http://gametruetool.com',
#  'http://finance.yahoo.com',
#  'http://www.mangodiet.com',
#  None,
#  'https://www.youtube.com',
#  'http://www.facebook.com',
#  'http://wiki.piraatit.fi',
#  'http://www.linkemperor.com',
#  None,
#  None,
#  'http://www.animuj.pl',
#  None,
#  None,
#  'http://www.facebook.com',
#  'http://embreveaqui.indisciplinar.com',
#  'http://www.vegasbottle.com',
#  'http://gametruetool.com',
#  'https://www.facebook.com',
#  'http://kauf-wert.de',
#  'http://www.vegasbottle.com',
#  'http://bit.ly',
#  'http://gametruetool.com',
#  'http://valeur-dachat.fr',
#  'http://holding30.wordpress.com',
#  'http://www.yelp.com',
#  None,
#  'http://embreveaqui.indisciplinar.com',
#  'http://www.vegasbottle.com',
#  None,
#  'http://twitter.com',
#  'http://plus.google.com',
#  'http://www.mangodiet.com',
#  'https://gametruetool.com',
#  'http://www.yelp.com',
#  'http://www.facebook.com',
#  None,
#  'http://foursquare.com',
#  None,
#  None,
#  None,
#  'http://www.indexemperor.com',
#  'http://www.facebook.com',
#  'http://wiki.piraatit.fi',
#  'http://storify.com',
#  'http://plus.google.com',
#  'http://www.animuj.pl',
#  'http://www.linkemperor.com',
#  None,
#  'http://gametruetool.com',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  None,
#  'http://youtu.be',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  'http://bit.ly',
#  'http://storify.com',
#  None,
#  'http://www.google.com',
#  None,
#  None,
#  'http://youtu.be',
#  'http://foursquare.com',
#  'http://www.yelp.com',
#  None,
#  None,
#  None,
#  'http://goo.gl',
#  'http://kauf-wert.de',
#  'http://foursquare.com',
#  'http://embreveaqui.indisciplinar.com',
#  'http://foursquare.com',
#  None,
#  'http://www.animuj.pl',
#  None,
#  None,
#  None,
#  'http://kauf-wert.de',
#  'https://www.vegasbottle.com',
#  'https://finance.yahoo.com',
#  'http://wiki.piraatit.fi',
#  'http://www.vegasbottle.com',
#  'http://twitter.com',
#  None,
#  'https://www.mangodiet.com',
#  None,
#  'http://foursquare.com',
#  'http://youtu.be',
#  'http://www.google.com',
#  'http://twitter.com',
#  'http://plus.google.com',
#  None,
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  'http://www.yelp.com',
#  'https://www.animuj.pl',
#  None,
#  'http://wiki.piraatit.fi',
#  None,
#  None,
#  'http://foursquare.com',
#  'http://www.yahoo.com',
#  None,
#  'https://www.animuj.pl',
#  'http://bit.ly',
#  None,
#  None,
#  None,
#  'http://goo.gl',
#  'http://twitter.com',
#  'http://www.google.com',
#  'https://www.vegasbottle.com',
#  None,
#  'http://www.yelp.com',
#  'https://www.yahoo.com',
#  'http://gametruetool.com',
#  'http://wiki.piraatit.fi',
#  'http://www.yahoo.com',
#  None,
#  'http://finance.yahoo.com',
#  None,
#  'http://embreveaqui.indisciplinar.com',
#  'https://www.yelp.com',
#  None,
#  'http://gametruetool.com',
#  'http://kauf-wert.de',
#  'http://bit.ly',
#  'https://foursquare.com',
#  'http://finance.yahoo.com',
#  'http://www.mangodiet.com',
#  'http://storify.com',
#  'http://goo.gl',
#  None,
#  'http://www.google.com',
#  None,
#  'http://www.animuj.pl',
#  'http://kauf-wert.de',
#  'http://holding30.wordpress.com',
#  None,
#  'https://www.google.com',
#  'http://goo.gl',
#  None,
#  None,
#  'http://wiki.piraatit.fi',
#  'https://www.yahoo.com',
#  'http://valeur-dachat.fr',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  None,
#  'http://www.yahoo.com',
#  'http://bit.ly',
#  None,
#  'http://www.google.com',
#  'http://storify.com',
#  None,
#  None,
#  'http://www.mangodiet.com',
#  None,
#  'http://gametruetool.com',
#  'http://www.yelp.com',
#  'http://www.yahoo.com',
#  'http://www.google.com',
#  'http://youtu.be',
#  'http://twitter.com',
#  None,
#  'http://www.yelp.com',
#  'http://www.animuj.pl',
#  'http://www.youtube.com',
#  'http://storify.com',
#  'https://bit.ly',
#  'http://www.vegasbottle.com',
#  'http://youtu.be',
#  'http://www.linkemperor.com',
#  None,
#  None,
#  'http://www.animuj.pl',
#  None,
#  'http://twitter.com',
#  'http://storify.com',
#  'http://www.animuj.pl',
#  'https://www.indexemperor.com',
#  None,
#  None,
#  'http://valeur-dachat.fr',
#  'http://www.linkemperor.com',
#  None,
#  'http://twitter.com',
#  'http://bit.ly',
#  'http://www.animuj.pl',
#  'http://www.facebook.com',
#  'http://bit.ly',
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  None,
#  'http://bit.ly',
#  None,
#  'http://bit.ly',
#  None,
#  None,
#  'http://www.facebook.com',
#  'http://kauf-wert.de',
#  'http://www.animuj.pl',
#  None,
#  'http://kauf-wert.de',
#  'http://gametruetool.com',
#  'http://www.vegasbottle.com',
#  'http://plus.google.com',
#  None,
#  'http://gametruetool.com',
#  None,
#  None,
#  'http://www.vegasbottle.com',
#  'http://www.youtube.com',
#  'http://finance.yahoo.com',
#  'http://www.indexemperor.com',
#  None,
#  'http://kauf-wert.de',
#  'http://www.yahoo.com',
#  'http://www.animuj.pl',
#  'http://plus.google.com',
#  None,
#  'http://www.linkemperor.com',
#  None,
#  None,
#  None,
#  'http://twitter.com',
#  'https://www.mangodiet.com',
#  'http://holding30.wordpress.com',
#  'http://wiki.piraatit.fi',
#  None,
#  None,
#  'http://www.facebook.com',
#  'http://valeur-dachat.fr',
#  None,
#  'http://www.yahoo.com',
#  'http://storify.com',
#  'http://wiki.piraatit.fi',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  None,
#  None,
#  'http://www.animuj.pl',
#  'http://foursquare.com',
#  'http://foursquare.com',
#  'http://storify.com',
#  None,
#  'http://www.linkemperor.com',
#  'http://valeur-dachat.fr',
#  None,
#  'http://www.indexemperor.com',
#  'http://plus.google.com',
#  None,
#  None,
#  'http://www.youtube.com',
#  'http://valeur-dachat.fr',
#  None,
#  'https://www.youtube.com',
#  None,
#  None,
#  'http://kauf-wert.de',
#  'http://www.mangodiet.com',
#  None,
#  None,
#  'http://wiki.piraatit.fi',
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  'http://www.facebook.com',
#  'http://storify.com',
#  'http://bit.ly',
#  'http://youtu.be',
#  None,
#  'http://www.facebook.com',
#  None,
#  'http://youtu.be',
#  None,
#  'http://www.google.com',
#  None,
#  'http://plus.google.com',
#  'http://www.google.com',
#  'http://valeur-dachat.fr',
#  'http://gametruetool.com',
#  None,
#  'http://www.google.com',
#  None,
#  None,
#  'http://www.mangodiet.com',
#  'http://finance.yahoo.com',
#  'http://embreveaqui.indisciplinar.com',
#  'http://www.linkemperor.com',
#  'http://www.yahoo.com',
#  None,
#  None,
#  'http://valeur-dachat.fr',
#  'http://www.animuj.pl',
#  None,
#  'http://gametruetool.com',
#  'http://embreveaqui.indisciplinar.com',
#  None,
#  None,
#  None,
#  None,
#  'http://finance.yahoo.com',
#  'http://www.facebook.com',
#  None,
#  None,
#  'http://www.google.com',
#  None,
#  'http://plus.google.com',
#  'http://kauf-wert.de',
#  'https://www.facebook.com',
#  'https://foursquare.com',
#  'http://www.youtube.com',
#  None,
#  'https://gametruetool.com',
#  None,
#  'http://www.mangodiet.com',
#  'http://foursquare.com',
#  None,
#  None,
#  'http://foursquare.com',
#  None,
#  'http://finance.yahoo.com',
#  'http://plus.google.com',
#  'http://twitter.com',
#  'http://kauf-wert.de',
#  'http://bit.ly',
#  None,
#  None,
#  'https://kauf-wert.de',
#  'http://www.yelp.com',
#  'http://www.indexemperor.com',
#  None,
#  'http://www.linkemperor.com',
#  None,
#  None,
#  None,
#  'http://gametruetool.com',
#  'http://www.yelp.com',
#  'http://www.yahoo.com',
#  None,
#  'http://www.vegasbottle.com',
#  'https://finance.yahoo.com',
#  'http://www.yelp.com',
#  'http://www.youtube.com',
#  'http://plus.google.com',
#  None,
#  'http://holding30.wordpress.com',
#  None,
#  'http://embreveaqui.indisciplinar.com',
#  'http://www.mangodiet.com',
#  'http://www.vegasbottle.com',
#  'http://www.indexemperor.com',
#  'http://wiki.piraatit.fi',
#  'http://valeur-dachat.fr',
#  'http://www.facebook.com',
#  'http://finance.yahoo.com',
#  None,
#  'https://www.youtube.com',
#  None,
#  'http://valeur-dachat.fr',
#  'http://www.animuj.pl',
#  None,
#  'http://www.mangodiet.com',
#  'http://storify.com',
#  'http://gametruetool.com',
#  'http://kauf-wert.de',
#  None,
#  None,
#  None,
#  'http://www.google.com',
#  'http://holding30.wordpress.com',
#  'http://gametruetool.com',
#  'https://storify.com',
#  'http://www.youtube.com',
#  'http://youtu.be',
#  'http://finance.yahoo.com',
#  'http://www.linkemperor.com',
#  'http://foursquare.com',
#  'http://www.animuj.pl',
#  None,
#  'http://plus.google.com',
#  None,
#  None,
#  'http://www.yahoo.com',
#  'http://www.youtube.com',
#  None,
#  None,
#  'http://www.youtube.com',
#  'http://youtu.be',
#  None,
#  None,
#  'http://kauf-wert.de',
#  None,
#  'http://youtu.be',
#  'http://www.indexemperor.com',
#  'http://storify.com',
#  None,
#  None,
#  'http://www.linkemperor.com',
#  None,
#  'http://www.facebook.com',
#  'http://www.indexemperor.com',
#  'http://www.yelp.com',
#  'http://kauf-wert.de',
#  'http://www.facebook.com',
#  'http://www.yelp.com',
#  'https://youtu.be',
#  None,
#  'http://www.indexemperor.com',
#  'http://finance.yahoo.com',
#  None,
#  None,
#  'http://goo.gl',
#  None,
#  'http://www.indexemperor.com',
#  'http://www.google.com',
#  'https://www.indexemperor.com',
#  'http://www.google.com',
#  'http://www.vegasbottle.com',
#  'http://holding30.wordpress.com',
#  None,
#  None,
#  'http://www.indexemperor.com',
#  'http://www.vegasbottle.com',
#  ...]

# %% [markdown]
# ### non_spam_bios dummy data generation code

# %%
import json
import urllib.request
url = urllib.request.urlopen("https://raw.githubusercontent.com/sindresorhus/mnemonic-words/master/words.json")
words = json.loads(url.read())
random_word = random.choice(words)

non_spam_bios=[0 for i in range(size)]
sentence = ''
for j in range(size):
    for k in range(3):
        for i in range(random.randint(0,50)):
             sentence = random.choice(words) +" "+ sentence
             i+=random.randint(0,10)
        k+=1
    non_spam_bios[j]= sentence
    j+=1
    sentence = ""

len(non_spam_bios)
# Out:
# 10000

# %% [markdown]
# ### non_spam_areas dummy data generation code

# %%
non_spam_areas = [None] *size

# %%
non_spam_area_set = [random.randint(1,size-1) for i in range(0,int(size*0.03))]
for i in non_spam_area_set:
    non_spam_areas[i] = "non_spam_area"

# %%
len(non_spam_areas)
# Out:
# 10000

# %% [markdown]
# ### non_spam_privs dummy data generation code

# %%
non_spam_privs = [0] * size

# %%
non_spam_privs_not_zero = [random.randint(1,size-1) for i in range(0,int(size*0.03))]
for i in non_spam_privs_not_zero:
    non_spam_privs[i] = 4

# %% [markdown]
# ### non_spam_genders dummy data generation code

# %%
non_spam_gender_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.8))]
non_spam_genders = ["gender"]*size
for i in non_spam_gender_not_set:
    non_spam_genders[i] = None

# %% [markdown]
# ### non_spam_birth_dates dummy data generation code

# %%
import datetime
import random
from datetime import timedelta	

non_spam_birth_dates = []
non_spam_birthdates_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.6))]
earliest = datetime.datetime(1998, 1, 1, 2, 30, 27, 5)
latest  = datetime.datetime.now()  - timedelta(days=7000)
delta = latest - earliest
int_delta = (delta.days * 24 * 60 * 60) + delta.seconds    
for i in range(size):
    random_second = random.randrange(int_delta)
    random_date = earliest + datetime.timedelta(seconds = random_second)
    non_spam_birth_dates.append(random_date)   


for i in non_spam_birthdates_not_set:
    non_spam_birth_dates[i] = None
len(non_spam_birth_dates)
# Out:
# 10000

# %% [markdown]
# ### non_spam_member_since dummy data generation code

# %%
import datetime
import random
		
non_spam_member_since = []
earliest = datetime.datetime(2000, 1, 1, 2, 30, 27, 5)
latest  = datetime.datetime.now()
delta = latest - earliest
int_delta = (delta.days * 24 * 60 * 60) + delta.seconds    
for i in range(size):
    random_second = random.randrange(int_delta)
    random_date = earliest + datetime.timedelta(seconds = random_second)
    non_spam_member_since.append(random_date)    
    
len(non_spam_member_since)
# Out:
# 10000

# %% [markdown]
# ### non_spam_email_confirm_dates dummy data generation code

# %%
from datetime import timedelta

non_spam_email_confirm_dates = list()

non_spam_email_confirm_dates_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.1))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = non_spam_member_since[i] + random_lengths[i]
    non_spam_email_confirm_dates.append( temp)
non_spam_email_confirm_dates

for i in non_spam_email_confirm_dates_not_set:
    non_spam_email_confirm_dates[i] = None

# %% [markdown]
# ### non_spam_last_updated dummy data generation code

# %%
#spam_last_updated
non_spam_last_updated = list()

non_spam_last_updated_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.4))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = non_spam_member_since[i] + random_lengths[i]
    non_spam_last_updated.append( temp)


for i in non_spam_last_updated_not_set:
    non_spam_last_updated[i] = None

# %% [markdown]
# ### non_spam_last_login_dates dummy data generation code

# %%
non_spam_last_login_dates = list()

non_spam_last_login_dates_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.1))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = non_spam_member_since[i] + random_lengths[i]
    non_spam_last_login_dates.append( temp)


for i in non_spam_last_login_dates_not_set:
    non_spam_last_login_dates[i] = None

# %% [markdown]
# ## Create pickle file from generated data

# %%
import pickle

# %%
non_spam_dummy_data = {}

# %%
for i in range(1,size):
    temp = {
        'email' : non_spam_emails[i],
        'website' : non_spam_websites[i],
        'bio' : non_spam_bios[i],
        'area' : non_spam_areas[i],
        'privs' : non_spam_privs[i],
        'gender' : non_spam_genders[i],
        'birth_date' : non_spam_birth_dates[i],
        'member_since' : non_spam_member_since[i],
        'email_confirm_date' : non_spam_email_confirm_dates[i],
        'last_updated' : non_spam_last_updated[i],
        'last_login_date' : non_spam_last_login_dates[i],
    }
    non_spam_dummy_data[i] = temp

# %%
with open('non_spam_editors_dummy_data.pickle', 'wb') as handle:
    pickle.dump(non_spam_dummy_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
