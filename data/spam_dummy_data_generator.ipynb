# %%
# importing necessary libraries 
import numpy as np
import random
import pandas as pd
from urllib.parse import urlparse
import datetime
import pickle

# %%
size = 1000

# %% [markdown]
# # Spam dummy data creation

# %%
domains_data =  pd.read_csv("domains_data.csv")

# %%
domains_data.columns
# Out:
# Index(['spam_emails', 'spam_website', 'nonspam_emails', 'non_spam_website'], dtype='object')

# %% [markdown]
# ### spam_emails dummy data generation code

# %%
spam_emails_csv = list(domains_data['spam_emails'])
spam_emails_csv
# Out:
# ['knottyunificati44@mail.ru',
#  'barrettallenjutefy@continumail.com',
#  'geminiswan10tnqqcp@drupalmails.com',
#  'paulcomb36nlutgy@joomlaemails.com',
#  'iqtest@angrybirds2.pl',
#  'morrisdykoma@inemaling.com',
#  'feigneddispatch@cfphone.net',
#  'ipop23@gmx.com',
#  'juteepoxy40tusssg@mailclubs.info',
#  'shrimpwheel16vvnxhf@joomlaemails.com',
#  'zen@bolo.eu.org',
#  'randompolish06iiocyr@deepemailbox.com',
#  'astonishingutop@uminga.net',
#  'e_pydrina@mail.ru',
#  'jermainecoakleybww@yahoo.com',
#  'lushmovie99@devsapps.net',
#  'mercadomichael@grow-mail.com',
#  'august@allemaling.com',
#  's.a.n.a.kh.a.l.i.d.3.2.6@gmail.com',
#  'calvindonald1@mail.ru',
#  'sheepbath07dvrzbn@drupalmails.com',
#  'kristenaisha868@gmail.com',
#  'killinconc60@gmail.com',
#  'goldbill34cqagtr@wordpressmails.com',
#  'faucetbroker16zbhbjl@joomlaemails.com',
#  'spearsoap69lojgvq@justbigbox.com',
#  'uglydesperado46@ginxmail.com',
#  'brightfruit27@cfphone.net',
#  'changeableyacht@uminga.net',
#  'humdrumtimetabl@uminga.net',
#  'currenkarleenpoxyji@kodmailing.com',
#  'grillrouter90nefkbh@wordpressmails.com',
#  'jerryjfoster@outlook.com',
#  'bungeegum@nomail.ga',
#  'locusjawise18@mail.ru',
#  'unsuitabledeity@devsapps.net',
#  'stickcut74oawxji@joomlaemails.com',
#  'mccrawanna743@mabermail.com',
#  'barcodescanner1@mail.ru',
#  'walletvalley32crdnba@joomlaemails.com',
#  'calh653684@gmail.com',
#  'cheaphosting007@trango.co',
#  'nestsound72qwasal@joomlaemails.com',
#  'moneypatch44jguvrn@joomlaemails.com',
#  'baityjose@visitinbox.com',
#  'zeniaheidrickjuy@yahoo.com',
#  'cadydbhxugaq@outlook.com',
#  'burkettchastity@yahoo.com',
#  'cityswitch94fliuna@joomlaemails.com',
#  'dryervent2@hotmail.com',
#  'cerealquill18rmwigr@hypermailbox.com',
#  'needbrazil37dlbesh@drupalmails.com',
#  'thingtights87cyvfhv@drupalmails.com',
#  'designpoet70rksjfc@wordpressmails.com',
#  'soillan46imrijl@joomlaemails.com',
#  'ira.1988.33@mail.ru',
#  'cupslash46wiuksf@drupalmails.com',
#  'jcapps57@webgarden.com',
#  'mosquewaste56moimwe@joomlaemails.com',
#  'nydiacargillqqgz@yahoo.com',
#  'jurysharon36dolfht@joomlaemails.com',
#  'manfred.bardola1990@o2.pl',
#  'bonsaibakery24icmwcy@abrighterfutureday.com',
#  'crowncloth35dzhyxx@wordpressmails.com',
#  'planetlilac13covkta@hotspotmails.com',
#  'duran243@out-email.com',
#  'moleshape16qgxgtt@joomlaemails.com',
#  'violinyam75wflgog@joomlaemails.com',
#  'morugandawson@gmail.com',
#  'plainbutton27gyubnt@joomlaemails.com',
#  'shedramati.3n51uh1@gmail.com',
#  'lundebycarolyne1011@digiuoso.com',
#  'carolyneparenteaupcn@yahoo.com',
#  'carolyne.suarezrpil@yahoo.com',
#  'carolynetruppuqmn@yahoo.com',
#  'asiavansumerenqmu@yahoo.com',
#  'davidscott@mabermail.com',
#  'motley@continumail.com',
#  'curveguilty16qosnkv@singtelmails.com',
#  'tacitenthusiast@devsapps.net',
#  'prosetuna73oykbir@joomlaemails.com',
#  'peppercrime73viqkkb@hypermailbox.com',
#  'beliefpasta40dpskvl@ibmmails.com',
#  'metalcondor47kzsfgr@abrighterfutureday.com',
#  'zinaida1hk2ge@mail.ru',
#  'summerlycra52wrfpnh@wordpressmails.com',
#  'poetactive51uofhle@joomlaemails.com',
#  'peacegray34fjmsqe@joomlaemails.com',
#  'birthclick01onaigf@ibmmails.com',
#  '2561peggyfowler@sobeessentialenergy.com',
#  'activebow41dnwyez@drupalmails.com',
#  'sternertujado@checknowmail.com',
#  'tennisburn14hgnuxe@temasekmail.com',
#  'choate654@consimail.com',
#  'babieswash98meewnk@joomlaemails.com',
#  'horaciomartin4020@buysteroids365.com',
#  'blackwoodsxashleaep@rediffmail.com',
#  'ilonafriedxbh@yahoo.com',
#  'elizebethpullemgrse@yahoo.com',
#  'oakoutput78uqttyh@abrighterfutureday.com',
#  'krasnozhon.lida@mail.ru',
#  'pimplemale16amvqwv@joomlaemails.com',
#  'gunpajama56wmoirc@drupalmails.com',
#  'bageljeff07mcxasv@abrighterfutureday.com',
#  'fangd467@gmail.com',
#  'shivanidhankhar7@gmail.com',
#  'quickbookenterprise@rediffmail.com',
#  'quickbooktraining92@outlook.com',
#  'gray70birchwpjcmm@intervisionplc.com',
#  'rogerstrichellkqn@yahoo.com',
#  'malvaforney1618@yahoo.com',
#  'spearsoap69lojgvq@justbigbox.com',
#  'sexmaple57hpukhg@justbigbox.com',
#  'duvallbeatrice@continumail.com',
#  'crowdjaw68oxrnbp@joomlaemails.com',
#  'turkeyfish16lituva@abrighterfutureday.com',
#  'artsquid15hxyvty@mailclubs.info',
#  'dollarbreak82yutbtj@joomlaemails.com',
#  'roaddate25nnnvok@joomlaemails.com',
#  'rumseyqimony@out-email.com',
#  'e_ushankina@mail.ru',
#  'oliverhilds@faithmail.org',
#  'willardledfod@faithmail.org',
#  'charfili30@gmail.com',
#  'fgklghbjjofghjflkj8487t5@gmail.com',
#  'moonakondo03@gmail.com',
#  '199creative.com@gmail.com',
#  'e9b2ee02@opayq.com',
#  'zitakim55@gmail.com',
#  'mohamedelareef1992@gmail.com',
#  'plolongnol3@gmail.com',
#  'chairbugle19lwissx@babymails.com',
#  'creamsingle78hvezyi@joomlaemails.com',
#  'fababetac@p33.org',
#  'comment9@freefileserver.com',
#  'priyayseo@gmail.com',
#  'h.neverus2@gmail.com',
#  'febrianisinta.fpr@gmail.com',
#  'sophieandrews803@gmail.com',
#  'randomdalban05@gmail.com',
#  'wekaari8899@gmail.com',
#  'ushehab51@gmail.com',
#  'alexasmith078@gmail.com',
#  'aryssetyawan27@gmail.com',
#  'mrsureprime@gmail.com',
#  '3657harrybarnette@thiet-ke-web.org',
#  'invhome12@gmail.com',
#  'professionalseo2008@gmail.com',
#  'rickpdomas@gmail.com',
#  'kasperskyantivirushelpdesk@gmail.com',
#  'omathewjohn@gmail.com',
#  'zahop@matchpol.net',
#  'admin@motorcyclebd.com',
#  'janeearora1992@gmail.com',
#  'anand.vihari222@gmail.com',
#  'wikarocezo@haydoo.com',
#  'himelpain24@gmail.com',
#  'priciljong@gmail.com',
#  'bethmichelle@matchpol.net',
#  'kathleenwarrencj@gmail.com',
#  'bi-sa.sa2017@yandex.com',
#  'chillmill71@gmail.com',
#  'cs.ibet57@gmail.com',
#  'mycadhome07@gmail.com',
#  'qbnumberus@gmail.com',
#  'jualanstorecom@gmail.com',
#  'farid404x@gmail.com',
#  'bupluhsn@gmail.com',
#  'webmaster@designawebsite.in',
#  'info@shopsousvide.com',
#  'nationalchiropractor+4@gmail.com',
#  'mohamed.shaaban0146@gmail.com',
#  'tvskyflixs@pokemail.net',
#  'skyflixs@pokemail.net',
#  'patwetzel92@gmail.com',
#  'gethighdaily111@gmail.com',
#  'seanpsion@mail.com',
#  'haoseo@yostyle.com.vn',
#  'thongtinveduhocduc@gmail.com',
#  'chamsocsacdeponline6@gmail.com',
#  '9gio32@gmail.com',
#  'giaytaynam2@gmail.com',
#  'giaytaynam123@gmail.com',
#  'nothin2505@gmail.com',
#  'angela_thuy@yahoo.com.vn',
#  'dongphucthienphuoc@gmail.com',
#  'sieumuanhanh1@gmail.com',
#  'lyndameltons@gmail.com',
#  'highmedstore@gmail.com',
#  'luyenthitienghan123@gmail.com',
#  'latulaskittwdtl@hotmail.com',
#  'chawlashilpi123@gmail.com',
#  'edensahkrpne@hotmail.com',
#  'arifboss439@gmail.com',
#  'hossiwlggali@hotmail.com',
#  'titlysarker102@gmail.com',
#  'aanik1012@gmail.com',
#  'zpkfbkstp@pullmail.info',
#  'vhevhjjdy@pullmail.info',
#  'fannie@sinemailing.com',
#  'clarabdias@outlook.com',
#  'pilatesbh@teimur.com',
#  'clarabowen970@allemaling.com',
#  'rnufxojk@gmail4u.eu',
#  'admin@hand-painted-scarves.eu',
#  '1490clarabartel@chemeng-masdar.com',
#  'brxjazmnpqy@hotmail.com',
#  'somakatun4587@gmail.com',
#  'sdtfghjmjklio@gmail.com',
#  'cfpchampionship17@gmail.com',
#  'liveto9@yandex.com',
#  'juyjty@gmail.com',
#  'jamesabauera@outlook.com',
#  'carolsclarka@outlook.com',
#  'andreadgraham@outlook.com',
#  'fifa18cheatshack@yahoo.com',
#  'josbuttlerharper@yahoo.com',
#  'no_one098@outlook.com',
#  'emilydmelo@outlook.com',
#  'threadplough07ipdzth@babymails.com',
#  'receptivedog9565@trango.co',
#  'receptivedynamo@trango.co',
#  'receptivedoctri06@trango.co',
#  'detailactive43pgpnuc@babymails.com',
#  'oksana.baturskaya@mail.ru',
#  'lacepickle57yyvkye@joomlaemails.com',
#  'hofabi@porsh.net',
#  'helenggardner@mail.com',
#  'fourbyfitouts1@gmail.com',
#  'cy20170805@gmail.com',
#  'agency2018@yandex.com',
#  'clancy201@mabermail.com',
#  'platenancy20lyjqis@intervisionplc.com',
#  'popovnin.yaroslav@mail.ru',
#  'oddershedeclancy20vnesfn@babymails.com',
#  'theseoagency2017@gmail.com',
#  'utopianlegacy20@devsapps.net',
#  'janetxdiaz@outlook.com',
#  'dolloffjanetxijumo@sin-mailing.com',
#  'cookjohan@outlook.com',
#  'zonejumbo87ogyelf@intervisionplc.com',
#  'lyrebetty41emdiwl@intervisionplc.com',
#  'gaylecookjonoky@brmailing.com',
#  'cookjohn471@kod-maling.com',
#  'cookjumper01pzagwy@babymails.com',
#  'cookjeans28jcytny@drupalmails.com',
#  'bablin@jourrapide.com',
#  'barbarassmith11@mail.com',
#  'glassmilk37wzgndn@drupalmails.com',
#  'grassmind28rybwcs@joomlaemails.com',
#  'pandaalto24cqfcsv@babymails.com',
#  'robertjones4153@businesstutorialsonline.org',
#  'paulariggs541@financehowtolearn.com',
#  '3538lonniearmstrong@researchobservatories.org.uk',
#  '7658marvinrock@businesshowtomakemoney.com',
#  'bulltent16nteysc@babymails.com',
#  'bulltent16nteysc@babymails.com',
#  'helmetfield55dczpam@joomlaemails.com',
#  'kirkpatrickcurrin35kvvqoz@babymails.com',
#  'christopher.sexton@yourmailbox.co',
#  'innatewhiz1@trango.co',
#  'makeupgrip59xorwnb@justbigbox.com',
#  'aa59@baseblogger.com',
#  'velazquezjoyce64cwnxuf@babymails.com',
#  'handsomecard56@padita.net',
#  'mrignayanikolkatashowroom@gmail.com',
#  'forkmonth54dfcbeg@babymails.com',
#  'danielarmstrong1497@topbuysteroids365.com',
#  'mimosamotion58xmhpgk@justbigbox.com',
#  'clarahunt91@gmail.com',
#  'jumanawilly@gmail.com',
#  'adamcrispin843@gmail.com',
#  'stephendevasya94@gmail.com',
#  '5975a3a66ed3a@mailbox92.biz',
#  '597750366c880@mailbox92.biz',
#  'rotuva@binnary.com',
#  'tajhorton@mail.com',
#  'valeriefpedrick@outlook.com',
#  'valerieford2@mail.ru',
#  'jonenkong@mail.com',
#  'marycbatson@outlook.com',
#  'jonnyhopes@outlook.com',
#  'ottohandal@mail.com',
#  'susandcook@outlook.com',
#  'henzlouip@outlook.com',
#  'irmaapeterson@mail.com',
#  'audraobalch@outlook.com',
#  'jackielwitt@mail.com',
#  'tendonfault@interia.pl',
#  'leighdnapper@outlook.com',
#  'sanderfrandsen@mail.com',
#  'joepflores@yopmail.com',
#  'louisjenem@mail.com',
#  'luibulks@outlook.com',
#  'hopepglaser@outlook.com',
#  'lauratbagwell@outlook.com',
#  'pameladgrant2@outlook.com',
#  'socksyrup99lqdhxt@intervisionplc.com',
#  'ahliqqnety@gmail.com',
#  'revenzeress@outlook.com',
#  'mbavalencia@hotmail.com',
#  'robbiewolf76@gmail.com',
#  'pacoxdeluna@gmail.com',
#  'herbalsejagat99@gmail.com',
#  'penthousedigital.co.uk@gmail.com',
#  'gnanasekar.6914@gmail.com',
#  'ahlicasino366@gmail.com',
#  'fullerdorothyj@gmail.com',
#  'bisapasti001@gmail.com',
#  'emmawilliamsvmak@gmail.com',
#  'adf98cb3@mozej.com',
#  'jogakhichuri30@gmail.com',
#  'divya35mehra@gmail.com',
#  'glxmcnfwkd32@gmail.com',
#  'approveloannow4@gmail.com',
#  'nativespellcaster@gmail.com',
#  'levihuongxuan@gmail.com',
#  'burnsubway56yysqlv@babymails.com',
#  'basketlunch00hoboiv@joomlaemails.com',
#  'apkdownload9108@lexxip.com',
#  'zombocalypse67@lexxip.com',
#  'alexandercginther02@protonmail.com',
#  'shadanigroup01@gmail.com',
#  'arijahari98@gmail.com',
#  'vipoku3@gmail.com',
#  'chudesuckhoe@gmail.com',
#  'angelinajohn9182@yahoo.com',
#  'shardagroup001@gmail.com',
#  'rawatsakshi289@gmail.com',
#  'conductexam.seo@gmail.com',
#  'alexson0126@gmail.com',
#  'meripyaribin.du0001@gmail.com',
#  'sosyal@teknokenar.com',
#  'nokiaemars@gmail.com',
#  'anikakmi47@gmail.com',
#  'markjohnn09@gmail.com',
#  'krishnakanth8796@gmail.com',
#  'angusa728@gmail.com',
#  'jack885256@gmail.com',
#  'laceymarkgeek@gmail.com',
#  'jonesgeek90@gmail.com',
#  'agarwalcartransport123@gmail.com',
#  'honeybella12@yopmail.com',
#  'happykelli15@yopmail.com',
#  'hotgoodsonsale@gmail.com',
#  'rappuxollyx-6168@yopmail.com',
#  'info.veintecmx@gmail.com',
#  'ixuhaffinn-6282@yopmail.com',
#  'shadanigroup01@gmail.com',
#  '800tollfreenumber3@gmail.com',
#  'smithdavid18299@gmail.com',
#  'awesomeeagler@gmail.com',
#  'amywatson490@gmail.com',
#  'jamesrhodetube@gmail.com',
#  'neilbhisma2671@gmail.com',
#  'camera247num@gmail.com',
#  'aaronruslee@gmail.com',
#  'jonnyjain820@gmail.com',
#  'masin83c@yahoo.com',
#  'wrewrewwrwrwr@gmail.com',
#  'meansakti@gmail.com',
#  'caodangsaigon.tphcm@gmail.com',
#  'lalitjain13923@gmail.com',
#  'shyamsingh18594@gmail.com',
#  'rani4567501@gmail.com',
#  'ahkhan@externetworks.com',
#  'yunmin1983ce@yahoo.com',
#  'ashaikfe@gmail.com',
#  'qizhenzln@gmail.com',
#  'nikithavalepu@gmail.com',
#  'nujuya@cliptik.net',
#  'christopherhobbs01@outlook.com',
#  'colinkroll@cliptik.net',
#  'paredesmusik@gmail.com',
#  'abc@intervisionplc.com',
#  'abc@lexxip.com',
#  'abc@joomlaemails.com',
#  'abc@babymails.com',
#  'abc@freemailhosts.com',
#  'abc@lovelymail.info',
#  'abc@kingdomheartmail.com',
#  'abc@wordpressmails.com',
#  'abc@abrighterfutureday.com',
#  'abc@hubspotmails.com',
#  'abc@trango.co',
#  'abc@devsapps.net',
#  'abc@businesskontakts.com',
#  'abc@drupalmails.com',
#  'abc@webgarden.com',
#  'abc@ibmmails.com',
#  'abc@hotspotmails.com',
#  'abc@cfphone.net',
#  'abc@queenofsite.online',
#  'abc@uminga.net',
#  'abc@singtelmails.com',
#  'abc@temasekmail.com',
#  'abc@hypermailbox.com',
#  'abc@gloriousfuturedays.com',
#  'abc@kingofplace.site',
#  'abc@1st-apparelsoftware.info',
#  'abc@padita.net',
#  'abc@deepemailbox.com',
#  'abc@lolas3.seo-linuxpl.com',
#  'abc@justbigbox.com',
#  'abc@dupontmails.com',
#  'abc@techspotny.com',
#  'abc@novartismails.com',
#  'abc@efacs.net',
#  'abc@anseohero.com']

# %%
spam_email_domains = {email.split("@")[1] for email in spam_emails_csv}
spam_email_domains = list(spam_email_domains)

# %%
spam_emails = list()
domains = list(spam_email_domains)
letters = ["a", "b", "c", "d","e", "f", "g", "h", "i", "j", "k", "l"]

def get_one_random_domain(domains):
        return domains[random.randint( 0, len(domains)-1)]


def get_one_random_name(letters):
    email_name = ""
    for i in range(7):
        email_name = email_name + letters[random.randint(0,11)]
    return email_name

def generate_random_emails(size):
    for i in range(0,size):
         one_name = str(get_one_random_name(letters))
         one_domain = str(get_one_random_domain(domains))  
         mail = one_name+'@'+one_domain
         spam_emails.append(mail)
generate_random_emails(size)

# %%
spam_emails
# Out:
# ['klldadi@singtelmails.com',
#  'ehkbcfl@buysteroids365.com',
#  'ehglebc@topbuysteroids365.com',
#  'afiadjh@trango.co',
#  'aggekde@externetworks.com',
#  'lakkjfe@kingdomheartmail.com',
#  'jlelbae@drupalmails.com',
#  'dljjhgk@hypermailbox.com',
#  'ljiejah@hypermailbox.com',
#  'klekhfj@matchpol.net',
#  'ljfdjba@hand-painted-scarves.eu',
#  'fiajgkh@pokemail.net',
#  'bjiiaek@consimail.com',
#  'dflfhgk@mail.com',
#  'kllafck@mabermail.com',
#  'ikcgghb@kod-maling.com',
#  'ejefiha@gloriousfuturedays.com',
#  'lhchhlh@ibmmails.com',
#  'ljcagbb@dupontmails.com',
#  'kdflaik@pokemail.net',
#  'hcikdfi@deepemailbox.com',
#  'kiadgak@teknokenar.com',
#  'dacbfhj@ibmmails.com',
#  'kjalgkc@kingdomheartmail.com',
#  'hbkbgfc@mabermail.com',
#  'fikjdjf@porsh.net',
#  'elkhigg@gmail.com',
#  'hakdkll@pullmail.info',
#  'bfibbkg@uminga.net',
#  'cjaakhl@porsh.net',
#  'ahdgbll@mail.ru',
#  'bhblkif@kod-maling.com',
#  'cldfdhl@faithmail.org',
#  'jkfighe@kod-maling.com',
#  'eidecbl@intervisionplc.com',
#  'bifgkgd@brmailing.com',
#  'akhhlae@babymails.com',
#  'ijkiije@inemaling.com',
#  'lcdjida@teknokenar.com',
#  'bggabkd@digiuoso.com',
#  'bdakfbf@ginxmail.com',
#  'ladfbke@hotspotmails.com',
#  'kacigdb@interia.pl',
#  'lbfadle@kingdomheartmail.com',
#  'lahdhka@mabermail.com',
#  'jbcjggd@designawebsite.in',
#  'keiadaj@devsapps.net',
#  'fclalhf@yourmailbox.co',
#  'ahajhik@brmailing.com',
#  'gkfkhaf@opayq.com',
#  'afbkgec@babymails.com',
#  'ggligac@anseohero.com',
#  'fkgekkf@webgarden.com',
#  'dgjcfek@visitinbox.com',
#  'aebaldf@financehowtolearn.com',
#  'cbdajff@singtelmails.com',
#  'aclcahi@dupontmails.com',
#  'dkbkhfg@padita.net',
#  'ccfgdfe@devsapps.net',
#  'fajkhka@babymails.com',
#  'cbhlhff@kod-maling.com',
#  'hjekfdj@continumail.com',
#  'lfacick@outlook.com',
#  'bbebbaf@queenofsite.online',
#  'jcikfhf@kingofplace.site',
#  'fabgaec@lexxip.com',
#  'eecfiae@protonmail.com',
#  'hehdbjj@externetworks.com',
#  'ceifdfd@bolo.eu.org',
#  'bilbjfa@gmail4u.eu',
#  'jkhkdli@financehowtolearn.com',
#  'cjcdbdf@lexxip.com',
#  'flgkjgc@wordpressmails.com',
#  'ifbibhk@yahoo.com',
#  'ekhgfhd@dupontmails.com',
#  'bjdedad@wordpressmails.com',
#  'kfflkdl@allemaling.com',
#  'blcicja@teimur.com',
#  'kjjjcej@queenofsite.online',
#  'caagfcg@uminga.net',
#  'hbggjfj@teknokenar.com',
#  'ddhfbfd@cfphone.net',
#  'hddileh@brmailing.com',
#  'ailhcfa@temasekmail.com',
#  'jfibiba@lolas3.seo-linuxpl.com',
#  'aahfjgg@porsh.net',
#  'jfadkge@novartismails.com',
#  'jhlblgf@hotspotmails.com',
#  'fahhdbb@topbuysteroids365.com',
#  'fhhjgbg@externetworks.com',
#  'ihagebe@out-email.com',
#  'igkihll@chemeng-masdar.com',
#  'ifgdkjl@designawebsite.in',
#  'gbkfgkk@kodmailing.com',
#  'icgkhfh@businesskontakts.com',
#  'bcjdkda@yandex.com',
#  'bhhjjhk@sin-mailing.com',
#  'iaechfb@mail.com',
#  'kjlkehc@devsapps.net',
#  'dglfkig@gmail4u.eu',
#  'cflecle@yopmail.com',
#  'lbafdjf@webgarden.com',
#  'ffclccd@hand-painted-scarves.eu',
#  'jkhjkka@kod-maling.com',
#  'gdcgbgl@grow-mail.com',
#  'hagcbjh@brmailing.com',
#  'ceffdce@thiet-ke-web.org',
#  'cieehgd@rediffmail.com',
#  'dghgaeg@gmail.com',
#  'fifdgld@jourrapide.com',
#  'ikgekjl@dupontmails.com',
#  'ffcdafa@yahoo.com.vn',
#  'cghjbae@cliptik.net',
#  'igkabbd@1st-apparelsoftware.info',
#  'afbilel@gmail4u.eu',
#  'fjajgli@jourrapide.com',
#  'jfgkegf@angrybirds2.pl',
#  'ghllbkd@lolas3.seo-linuxpl.com',
#  'diijdca@nomail.ga',
#  'achkchi@gmx.com',
#  'eljhadd@techspotny.com',
#  'aklfgcc@teimur.com',
#  'fbldcll@queenofsite.online',
#  'abjbldc@designawebsite.in',
#  'dglhkjd@businesshowtomakemoney.com',
#  'ggcifkb@anseohero.com',
#  'hebaiaa@singtelmails.com',
#  'agcgefj@allemaling.com',
#  'jbeighg@kodmailing.com',
#  'ggbfkgf@mozej.com',
#  'gjlbihb@matchpol.net',
#  'ggbhede@protonmail.com',
#  'fegadlk@kingdomheartmail.com',
#  'cegdgfd@trango.co',
#  'gagfhig@buysteroids365.com',
#  'hdacglc@financehowtolearn.com',
#  'iggibkh@ginxmail.com',
#  'clikdgk@joomlaemails.com',
#  'ibibifd@hypermailbox.com',
#  'diehiil@ibmmails.com',
#  'jfibfff@sobeessentialenergy.com',
#  'egkaifi@chemeng-masdar.com',
#  'hkjbjhc@businesshowtomakemoney.com',
#  'chgkfhd@mail.ru',
#  'cfhkkaa@kingdomheartmail.com',
#  'jbjjhil@gmx.com',
#  'jjdablh@kod-maling.com',
#  'jdgjgca@interia.pl',
#  'ifgdilj@binnary.com',
#  'gikdiaa@yopmail.com',
#  'bceadbh@techspotny.com',
#  'fbijckh@o2.pl',
#  'hchekff@temasekmail.com',
#  'gbcbfci@hotmail.com',
#  'caddcli@hotspotmails.com',
#  'illkdah@webgarden.com',
#  'ldfgbfg@sobeessentialenergy.com',
#  'aeailag@mailbox92.biz',
#  'ladagkc@efacs.net',
#  'ahfedih@sin-mailing.com',
#  'bkadckc@brmailing.com',
#  'didkcha@visitinbox.com',
#  'fbbbcjd@cfphone.net',
#  'kjcbjif@gmail4u.eu',
#  'aejjebc@pokemail.net',
#  'jlhckaf@yahoo.com',
#  'kacjhlj@matchpol.net',
#  'llkacdj@mozej.com',
#  'adjjigl@uminga.net',
#  'gdibjlb@pullmail.info',
#  'cakceed@singtelmails.com',
#  'gecadlb@businesstutorialsonline.org',
#  'abgkahc@binnary.com',
#  'ehhlijc@bolo.eu.org',
#  'hkickhi@thiet-ke-web.org',
#  'jjcbjfc@brmailing.com',
#  'lgdgjgk@businesshowtomakemoney.com',
#  'dbgkdjh@o2.pl',
#  'edcjbcf@rediffmail.com',
#  'hbgdbhj@cfphone.net',
#  'fchjcgk@hubspotmails.com',
#  'jkghgbg@drupalmails.com',
#  'kadcblk@visitinbox.com',
#  'cheefhg@temasekmail.com',
#  'aejfaaj@externetworks.com',
#  'alfibba@kingofplace.site',
#  'ihcelfi@justbigbox.com',
#  'elghgci@protonmail.com',
#  'aehjiej@yahoo.com',
#  'hjabgah@mailbox92.biz',
#  'ehdjbij@singtelmails.com',
#  'eagaelg@mailclubs.info',
#  'bjkklaf@matchpol.net',
#  'gbilkef@buysteroids365.com',
#  'hkkdgki@1st-apparelsoftware.info',
#  'eaeajki@freefileserver.com',
#  'jagldcc@binnary.com',
#  'cccddgh@sin-mailing.com',
#  'kgkhegd@lexxip.com',
#  'cccjaff@trango.co',
#  'edhheah@sobeessentialenergy.com',
#  'hhlekeg@p33.org',
#  'ddhikgc@pullmail.info',
#  'bhdajdd@yahoo.com',
#  'ghjekkh@temasekmail.com',
#  'gkkabkh@lovelymail.info',
#  'jafdkcd@matchpol.net',
#  'icdebff@freemailhosts.com',
#  'clideka@sin-mailing.com',
#  'cicdecf@digiuoso.com',
#  'lejdjic@motorcyclebd.com',
#  'aejaeid@faithmail.org',
#  'kejjfle@drupalmails.com',
#  'ajbjfkc@sobeessentialenergy.com',
#  'eijejkf@inemaling.com',
#  'alljkfa@gmail.com',
#  'klbcjge@rediffmail.com',
#  'gakiiak@temasekmail.com',
#  'ggcfjha@drupalmails.com',
#  'ehcebej@yourmailbox.co',
#  'ihiigji@techspotny.com',
#  'ejacjbh@motorcyclebd.com',
#  'gfgcaii@hypermailbox.com',
#  'gdgdlkc@ibmmails.com',
#  'bdbjkjg@freefileserver.com',
#  'kibfhjb@visitinbox.com',
#  'ahfefbf@sin-mailing.com',
#  'bbdedkl@outlook.com',
#  'ikeeddj@sobeessentialenergy.com',
#  'ccbjfla@haydoo.com',
#  'hdijadf@externetworks.com',
#  'aebllfl@gmx.com',
#  'ljgaeaj@sobeessentialenergy.com',
#  'lcakkhe@yostyle.com.vn',
#  'jekjbfh@cfphone.net',
#  'jegdeel@p33.org',
#  'dajjahe@novartismails.com',
#  'lifihbl@checknowmail.com',
#  'ddkddhj@lolas3.seo-linuxpl.com',
#  'fcdbcia@nomail.ga',
#  'baglcak@mozej.com',
#  'jeiijea@yourmailbox.co',
#  'ijihgjh@kingofplace.site',
#  'bafjjel@temasekmail.com',
#  'aailjhg@gloriousfuturedays.com',
#  'hfbbalf@ginxmail.com',
#  'gajllaf@justbigbox.com',
#  'egiebgk@gmail4u.eu',
#  'ckillji@kodmailing.com',
#  'jhekdai@gloriousfuturedays.com',
#  'bcjijfe@mail.ru',
#  'gajgdfj@p33.org',
#  'jjaihhb@queenofsite.online',
#  'ffbcgel@gmail.com',
#  'edcijbb@bolo.eu.org',
#  'fkkaiek@digiuoso.com',
#  'ehlaclc@baseblogger.com',
#  'dhjligf@businesskontakts.com',
#  'fabildc@nomail.ga',
#  'ihcbajc@intervisionplc.com',
#  'kajaclc@thiet-ke-web.org',
#  'jifglhl@buysteroids365.com',
#  'bkbckch@mailclubs.info',
#  'hjdaigd@temasekmail.com',
#  'igiagai@cfphone.net',
#  'kafgeag@visitinbox.com',
#  'hlejhee@gmail4u.eu',
#  'jljkfgg@lolas3.seo-linuxpl.com',
#  'felkaid@thiet-ke-web.org',
#  'bhaljdj@outlook.com',
#  'bcbibbi@businesskontakts.com',
#  'cedbbkl@digiuoso.com',
#  'bgfljdc@freefileserver.com',
#  'gilkdid@deepemailbox.com',
#  'hlfgkjb@grow-mail.com',
#  'kahdejj@joomlaemails.com',
#  'lhaihck@p33.org',
#  'efgffii@ginxmail.com',
#  'cdkefei@sobeessentialenergy.com',
#  'eijikkh@cfphone.net',
#  'iljekfh@out-email.com',
#  'ebcbeae@yopmail.com',
#  'kagheeg@checknowmail.com',
#  'kjfehej@bolo.eu.org',
#  'adklggd@faithmail.org',
#  'fajfhbk@gloriousfuturedays.com',
#  'eeadckf@freefileserver.com',
#  'klekice@sobeessentialenergy.com',
#  'lfbkagc@angrybirds2.pl',
#  'dkfbelc@yandex.com',
#  'hekffdf@kod-maling.com',
#  'igehbah@padita.net',
#  'gdgfdbd@singtelmails.com',
#  'dkfehfa@gmail.com',
#  'dkcehcd@hand-painted-scarves.eu',
#  'jcdeaah@lexxip.com',
#  'ibhibfl@intervisionplc.com',
#  'jfhcefa@efacs.net',
#  'kghkiie@checknowmail.com',
#  'jaijflb@p33.org',
#  'hbkklie@novartismails.com',
#  'jljabfk@yahoo.com.vn',
#  'fcjjkdk@lolas3.seo-linuxpl.com',
#  'iiccaaa@dupontmails.com',
#  'jdaelbb@grow-mail.com',
#  'ighdgbe@dupontmails.com',
#  'ecidaae@dupontmails.com',
#  'fedgfgf@p33.org',
#  'eeijdae@freefileserver.com',
#  'llgfdcc@webgarden.com',
#  'afclgjl@yostyle.com.vn',
#  'gbilbai@jourrapide.com',
#  'dadbbcf@o2.pl',
#  'igakdda@deepemailbox.com',
#  'kgbgadb@kodmailing.com',
#  'ajegcje@checknowmail.com',
#  'jikbhek@pullmail.info',
#  'kkladhg@webgarden.com',
#  'bdhdlje@yostyle.com.vn',
#  'iheadgi@teimur.com',
#  'idaldek@uminga.net',
#  'cahadhg@hotmail.com',
#  'jigiclk@mabermail.com',
#  'ggaikki@matchpol.net',
#  'lcehfkh@gmx.com',
#  'gccikcl@freemailhosts.com',
#  'gflbfhg@techspotny.com',
#  'ikkkjjh@justbigbox.com',
#  'jlceejd@sinemailing.com',
#  'icgcgbc@thiet-ke-web.org',
#  'gliadlf@hotmail.com',
#  'eeljgdi@motorcyclebd.com',
#  'hjgddgh@kingofplace.site',
#  'ifkdkbb@singtelmails.com',
#  'dkeiaba@hubspotmails.com',
#  'kebhcik@porsh.net',
#  'jbbfcjd@gmail.com',
#  'akiachf@temasekmail.com',
#  'hhdachl@teimur.com',
#  'kklighl@babymails.com',
#  'jggclhe@techspotny.com',
#  'jcejlbc@1st-apparelsoftware.info',
#  'hjcafkj@mailbox92.biz',
#  'idikiaj@outlook.com',
#  'ibddcff@intervisionplc.com',
#  'bkehfib@freemailhosts.com',
#  'hlcheij@consimail.com',
#  'hbkghkc@gmx.com',
#  'kibclef@topbuysteroids365.com',
#  'cbbjbgd@gmail.com',
#  'haejagi@digiuoso.com',
#  'hbkhcdl@angrybirds2.pl',
#  'lbedbji@mabermail.com',
#  'lfjbfej@drupalmails.com',
#  'hbihfci@nomail.ga',
#  'kgkcbef@protonmail.com',
#  'bcibecb@brmailing.com',
#  'djhdkkd@thiet-ke-web.org',
#  'clffchk@businesskontakts.com',
#  'kkjgdjf@teknokenar.com',
#  'licleak@lolas3.seo-linuxpl.com',
#  'cfjekbj@pullmail.info',
#  'ajgaabi@drupalmails.com',
#  'ghdadji@outlook.com',
#  'jkjkelk@pullmail.info',
#  'kdbbkhf@faithmail.org',
#  'kdgcdfb@binnary.com',
#  'llalbll@yandex.com',
#  'gadebdl@kodmailing.com',
#  'hdjkgkl@yostyle.com.vn',
#  'hliblhi@yahoo.com',
#  'jbfciie@mozej.com',
#  'ehljegi@visitinbox.com',
#  'gfedjid@grow-mail.com',
#  'jdhhkha@mail.ru',
#  'gglaiij@yourmailbox.co',
#  'afjlfgh@continumail.com',
#  'fjjdgla@sin-mailing.com',
#  'jgibhhc@protonmail.com',
#  'dcfdadg@digiuoso.com',
#  'kikijke@p33.org',
#  'lcefkji@businesskontakts.com',
#  'jifhgid@yostyle.com.vn',
#  'abjbfek@techspotny.com',
#  'liacdei@yourmailbox.co',
#  'jcdilia@teimur.com',
#  'fkdigbk@shopsousvide.com',
#  'cbacehk@yourmailbox.co',
#  'lcbjhaj@yopmail.com',
#  'dddkfgj@cliptik.net',
#  'fgkeeca@externetworks.com',
#  'iiedfch@trango.co',
#  'afkchee@padita.net',
#  'ahicjdg@freemailhosts.com',
#  'jkfifjb@allemaling.com',
#  'gjbhllh@businesstutorialsonline.org',
#  'gibaibg@motorcyclebd.com',
#  'kljeahh@freemailhosts.com',
#  'clldlcg@intervisionplc.com',
#  'iafcdli@kingdomheartmail.com',
#  'hhlbcae@mail.com',
#  'aeiljhk@allemaling.com',
#  'fiaghci@gmx.com',
#  'jjjkbaa@justbigbox.com',
#  'ghfghcc@visitinbox.com',
#  'fddcgkk@interia.pl',
#  'hgheiah@drupalmails.com',
#  'lciffck@babymails.com',
#  'ichfide@binnary.com',
#  'bhcflhl@anseohero.com',
#  'fblbdbh@angrybirds2.pl',
#  'edjefee@yourmailbox.co',
#  'jicklli@visitinbox.com',
#  'fdhecai@yourmailbox.co',
#  'kagfifa@interia.pl',
#  'aabcjki@1st-apparelsoftware.info',
#  'hklkhfj@porsh.net',
#  'ciccacg@justbigbox.com',
#  'gfchlac@abrighterfutureday.com',
#  'cbjieah@interia.pl',
#  'fgkalkk@gmail4u.eu',
#  'kbddaaa@yopmail.com',
#  'bdkelkh@consimail.com',
#  'ggbicjd@singtelmails.com',
#  'gdbafkk@businesstutorialsonline.org',
#  'agdjgeg@novartismails.com',
#  'ecjagbl@babymails.com',
#  'kkklgfc@dupontmails.com',
#  'eafkbcd@gmail.com',
#  'kjdfbdk@yostyle.com.vn',
#  'geidiid@brmailing.com',
#  'dajific@ibmmails.com',
#  'dacbfbc@allemaling.com',
#  'dajlakd@hubspotmails.com',
#  'acldaef@out-email.com',
#  'lfcgdij@rediffmail.com',
#  'ababkld@sinemailing.com',
#  'lcgfiaf@kingdomheartmail.com',
#  'dadlklj@teimur.com',
#  'cicagdb@hotspotmails.com',
#  'ehjeigj@businesskontakts.com',
#  'ballbda@businesstutorialsonline.org',
#  'djebaak@hypermailbox.com',
#  'gfjgegh@hotspotmails.com',
#  'hbejbbl@cfphone.net',
#  'ecdcfak@yahoo.com',
#  'gijccch@researchobservatories.org.uk',
#  'hgbgdaa@kingdomheartmail.com',
#  'bcgdhhh@inemaling.com',
#  'cabilcc@consimail.com',
#  'gheklbc@intervisionplc.com',
#  'iidjhbj@mail.com',
#  'kkdblhe@buysteroids365.com',
#  'acgejfb@angrybirds2.pl',
#  'flhfahd@sobeessentialenergy.com',
#  'jaihcgk@gmx.com',
#  'gchdlal@opayq.com',
#  'hiebjec@lolas3.seo-linuxpl.com',
#  'bljeeba@yopmail.com',
#  'bjeiljg@teimur.com',
#  'iigejkj@jourrapide.com',
#  'ejkaejb@sinemailing.com',
#  'ejfhejl@yourmailbox.co',
#  'liakbbb@temasekmail.com',
#  'ifligfb@drupalmails.com',
#  'bkkhijj@hypermailbox.com',
#  'kfjekih@mailclubs.info',
#  'haaiijl@consimail.com',
#  'lglceei@checknowmail.com',
#  'likdhle@yandex.com',
#  'hbabffd@hotmail.com',
#  'egikdee@yandex.com',
#  'ekbbbdl@dupontmails.com',
#  'feajbbg@ginxmail.com',
#  'hkabdeh@businesstutorialsonline.org',
#  'aachcaf@yahoo.com.vn',
#  'heeckgj@dupontmails.com',
#  'djflibj@intervisionplc.com',
#  'hldabka@researchobservatories.org.uk',
#  'ebidbkl@jourrapide.com',
#  'ekdeiji@padita.net',
#  'ffkfahe@checknowmail.com',
#  'jhkclab@porsh.net',
#  'lldlfgf@teknokenar.com',
#  'eacfiii@mailclubs.info',
#  'bfjflif@ibmmails.com',
#  'bacaidl@bolo.eu.org',
#  'iiegfbj@temasekmail.com',
#  'fbfbbaj@gmx.com',
#  'efabffd@deepemailbox.com',
#  'kibakle@pokemail.net',
#  'jbidike@pokemail.net',
#  'lcchlgk@lolas3.seo-linuxpl.com',
#  'edfidcd@visitinbox.com',
#  'ielfhcc@jourrapide.com',
#  'hifjhig@yourmailbox.co',
#  'bbhjeba@kod-maling.com',
#  'lbljdgk@digiuoso.com',
#  'aiebaja@uminga.net',
#  'ffbbcba@sin-mailing.com',
#  'lillcif@haydoo.com',
#  'bhdbjjk@freemailhosts.com',
#  'kafdkld@abrighterfutureday.com',
#  'hacabaf@padita.net',
#  'cafljdd@mail.ru',
#  'lielahi@mozej.com',
#  'ljggjcj@lolas3.seo-linuxpl.com',
#  'fdhhjel@o2.pl',
#  'kfehjkd@inemaling.com',
#  'idfhjic@mailbox92.biz',
#  'jlihdka@pullmail.info',
#  'dlabgbc@p33.org',
#  'alebagb@teimur.com',
#  'fheafke@temasekmail.com',
#  'ligefil@justbigbox.com',
#  'kdjbddf@pokemail.net',
#  'fibhlkg@mail.com',
#  'kggfclb@yourmailbox.co',
#  'efjkgga@kingdomheartmail.com',
#  'cifdale@protonmail.com',
#  'eggefei@devsapps.net',
#  'abfljje@yostyle.com.vn',
#  'agiceii@ibmmails.com',
#  'ekkdjbi@topbuysteroids365.com',
#  'bkgkckg@out-email.com',
#  'eiigica@sobeessentialenergy.com',
#  'iagdjbk@cliptik.net',
#  'bcibaeb@freemailhosts.com',
#  'clfahak@yandex.com',
#  'ebaeejj@digiuoso.com',
#  'ehkcjel@sinemailing.com',
#  'cigeahl@kodmailing.com',
#  'fflidel@inemaling.com',
#  'fakiedc@topbuysteroids365.com',
#  'idffilh@mozej.com',
#  'bcdlfak@opayq.com',
#  'lbbchck@opayq.com',
#  'ijchdah@ibmmails.com',
#  'kicbaia@angrybirds2.pl',
#  'hdfgdjj@webgarden.com',
#  'ejhaaah@novartismails.com',
#  'ekejifj@hypermailbox.com',
#  'ikbfihf@singtelmails.com',
#  'kklfdjh@yahoo.com.vn',
#  'delllak@brmailing.com',
#  'fdhilej@ibmmails.com',
#  'fkfkifg@continumail.com',
#  'dlhilja@sinemailing.com',
#  'dlfbhdj@bolo.eu.org',
#  'iifdjdb@gloriousfuturedays.com',
#  'fgecekb@gmx.com',
#  'egccaag@pokemail.net',
#  'jkgcack@lexxip.com',
#  'gkaelii@p33.org',
#  'fchhgab@designawebsite.in',
#  'ajihijb@outlook.com',
#  'ijlcljh@visitinbox.com',
#  'hffkcgc@chemeng-masdar.com',
#  'jjcfgkk@intervisionplc.com',
#  'keaalab@hand-painted-scarves.eu',
#  'iebhfdi@thiet-ke-web.org',
#  'cjihfhe@researchobservatories.org.uk',
#  'jbkfkca@teknokenar.com',
#  'hjffbkd@cfphone.net',
#  'hcdjiif@angrybirds2.pl',
#  'kgbligd@sobeessentialenergy.com',
#  'aaeealc@yandex.com',
#  'ggbafcf@hubspotmails.com',
#  'aafiefd@sin-mailing.com',
#  'ejdjgbj@hotmail.com',
#  'aighaej@yourmailbox.co',
#  'fjjjabc@drupalmails.com',
#  'jafclgj@temasekmail.com',
#  'jijleck@mozej.com',
#  'fhfkgli@1st-apparelsoftware.info',
#  'ckfcbcc@mabermail.com',
#  'jfiicka@cliptik.net',
#  'ajabhcc@mail.ru',
#  'gcaffed@techspotny.com',
#  'lebbfgg@outlook.com',
#  'kdkijhd@cliptik.net',
#  'ifldada@abrighterfutureday.com',
#  'bchacid@techspotny.com',
#  'fggdcaf@continumail.com',
#  'fbbball@dupontmails.com',
#  'lejfacg@pokemail.net',
#  'cfabcil@techspotny.com',
#  'kkhegke@opayq.com',
#  'ehkcigi@protonmail.com',
#  'algaigk@teknokenar.com',
#  'jhieech@digiuoso.com',
#  'lhflkch@angrybirds2.pl',
#  'hlikdkj@mozej.com',
#  'jcgjigc@mozej.com',
#  'dihjice@ibmmails.com',
#  'bacjbej@chemeng-masdar.com',
#  'lglldcd@buysteroids365.com',
#  'cjffgjc@freefileserver.com',
#  'ccghbkc@allemaling.com',
#  'fiadidc@yandex.com',
#  'alggfad@visitinbox.com',
#  'hibjcli@baseblogger.com',
#  'daagblc@webgarden.com',
#  'lfjlgde@uminga.net',
#  'fabbjia@designawebsite.in',
#  'gkbegik@shopsousvide.com',
#  'diddjac@justbigbox.com',
#  'lahfgcc@outlook.com',
#  'lbkabid@novartismails.com',
#  'akgdjig@kod-maling.com',
#  'jbeacae@chemeng-masdar.com',
#  'hfikgld@efacs.net',
#  'jeffike@dupontmails.com',
#  'ebkikda@p33.org',
#  'bahifib@allemaling.com',
#  'ggjgbef@trango.co',
#  'lkceddh@matchpol.net',
#  'degllgh@anseohero.com',
#  'gghfcgd@yahoo.com.vn',
#  'khigila@hotspotmails.com',
#  'jeklfbb@interia.pl',
#  'iaigeid@kingofplace.site',
#  'jebflla@grow-mail.com',
#  'kalhbif@mailbox92.biz',
#  'eggahla@kodmailing.com',
#  'gcejhgd@mabermail.com',
#  'hcbbbjj@mailbox92.biz',
#  'ikfllll@singtelmails.com',
#  'hcfkjeg@grow-mail.com',
#  'kadllgi@lolas3.seo-linuxpl.com',
#  'baejkja@intervisionplc.com',
#  'ceefldc@businesskontakts.com',
#  'bhelech@matchpol.net',
#  'dhlefkh@dupontmails.com',
#  'ckiaaeh@businesstutorialsonline.org',
#  'delgfbh@brmailing.com',
#  'gjglbeg@webgarden.com',
#  'ccijgdi@digiuoso.com',
#  'hkegele@inemaling.com',
#  'jddfhcb@padita.net',
#  'bibgglf@trango.co',
#  'gghfdhf@mail.com',
#  'egfeced@hypermailbox.com',
#  'hieledf@gloriousfuturedays.com',
#  'ekajiah@protonmail.com',
#  'ejbealg@kingdomheartmail.com',
#  'gikiafe@brmailing.com',
#  'ihfddil@joomlaemails.com',
#  'lgejlbd@angrybirds2.pl',
#  'ikbjiid@p33.org',
#  'glebafa@sinemailing.com',
#  'hgigfkj@inemaling.com',
#  'iagkhia@teknokenar.com',
#  'ehigkgd@faithmail.org',
#  'efbkihk@anseohero.com',
#  'gagcbbh@opayq.com',
#  'edigakb@matchpol.net',
#  'hbjlcea@joomlaemails.com',
#  'kldlgjj@topbuysteroids365.com',
#  'eehhalh@digiuoso.com',
#  'kbjekkf@techspotny.com',
#  'abfldaf@gloriousfuturedays.com',
#  'jakdaah@ibmmails.com',
#  'ccaebhl@pullmail.info',
#  'alabcaa@kingofplace.site',
#  'klbabkl@cliptik.net',
#  'khcbllf@hubspotmails.com',
#  'klefjaf@chemeng-masdar.com',
#  'dagdaab@mozej.com',
#  'iijccgk@protonmail.com',
#  'gjcbffb@uminga.net',
#  'jihhfjf@topbuysteroids365.com',
#  'gbhhekc@lovelymail.info',
#  'dbhjcbj@businesskontakts.com',
#  'fhifcib@kingofplace.site',
#  'ffigaae@hubspotmails.com',
#  'ejbklgc@freefileserver.com',
#  'kdjaije@dupontmails.com',
#  'lhkaldc@novartismails.com',
#  'figdahj@businesstutorialsonline.org',
#  'hglclae@continumail.com',
#  'bcllbbd@mailclubs.info',
#  'alkdhig@kodmailing.com',
#  'hfajgic@financehowtolearn.com',
#  'kllfkae@businesskontakts.com',
#  'ikfjkgk@teknokenar.com',
#  'diakgjf@yopmail.com',
#  'cdlajad@hotmail.com',
#  'kieicab@mozej.com',
#  'kbfealg@kingdomheartmail.com',
#  'ahicgca@porsh.net',
#  'aebjlal@chemeng-masdar.com',
#  'hbglgci@inemaling.com',
#  'gjahbca@jourrapide.com',
#  'iilideg@protonmail.com',
#  'jldeddc@pokemail.net',
#  'kaigkgi@lexxip.com',
#  'dffgbke@faithmail.org',
#  'kgffbij@gmail4u.eu',
#  'jlckihi@justbigbox.com',
#  'hgdidbl@hand-painted-scarves.eu',
#  'ebhflgd@yostyle.com.vn',
#  'ggfgfej@temasekmail.com',
#  'lckhcjg@pokemail.net',
#  'hiijaad@devsapps.net',
#  'khlhdcd@teimur.com',
#  'kfbkccg@sobeessentialenergy.com',
#  'acehdcl@mailbox92.biz',
#  'hlcfgka@matchpol.net',
#  'hlhckhg@hand-painted-scarves.eu',
#  'fbefbje@shopsousvide.com',
#  'dfjkkah@binnary.com',
#  'iifhelk@babymails.com',
#  'edjfaai@yahoo.com',
#  'bjifdbk@anseohero.com',
#  'beabbed@joomlaemails.com',
#  'dciiifh@inemaling.com',
#  'gejhahh@interia.pl',
#  'jjkhheb@webgarden.com',
#  'iahhkdk@thiet-ke-web.org',
#  'ijhaclh@sinemailing.com',
#  'efbkaed@gmail.com',
#  'baeliea@haydoo.com',
#  'bgfiflc@mail.com',
#  'aeifkhb@yandex.com',
#  'hjhhbig@opayq.com',
#  'lkbijbg@drupalmails.com',
#  'hjiacbe@ginxmail.com',
#  'cjhebkh@baseblogger.com',
#  'cjdjifa@o2.pl',
#  'gcfgieg@cliptik.net',
#  'bggicha@joomlaemails.com',
#  'dechleb@faithmail.org',
#  'fghddhg@sin-mailing.com',
#  'jlifaei@hotmail.com',
#  'ldhfhki@sobeessentialenergy.com',
#  'fhkcgce@gmail.com',
#  'lecibcl@digiuoso.com',
#  'cgkiadj@digiuoso.com',
#  'bakeikj@kingofplace.site',
#  'egfikie@anseohero.com',
#  'dgcfekb@buysteroids365.com',
#  'ebibhdd@joomlaemails.com',
#  'abfakhi@freemailhosts.com',
#  'jkgeead@interia.pl',
#  'ddgjkga@hotspotmails.com',
#  'edfjfgk@yostyle.com.vn',
#  'ihldhil@cliptik.net',
#  'hbcgaaf@ibmmails.com',
#  'bjjbdgj@mail.com',
#  'beiaedl@p33.org',
#  'kjlaagg@teimur.com',
#  'llegbci@outlook.com',
#  'ajhiafa@businesskontakts.com',
#  'lafcdgd@teimur.com',
#  'keckbge@kod-maling.com',
#  'agfghbh@deepemailbox.com',
#  'lhgkilg@businesshowtomakemoney.com',
#  'akhhebc@singtelmails.com',
#  'kdfhdfi@devsapps.net',
#  'febdidb@singtelmails.com',
#  'fgdbeij@teknokenar.com',
#  'gfkaecb@deepemailbox.com',
#  'ellfdhj@shopsousvide.com',
#  'ldalhai@mailclubs.info',
#  'kkelhgh@temasekmail.com',
#  'ibkehbl@angrybirds2.pl',
#  'hlgigch@binnary.com',
#  'cjecidi@drupalmails.com',
#  'fbfaici@gmail.com',
#  'afdacbg@ibmmails.com',
#  'blfjakj@kingofplace.site',
#  'biagbai@pullmail.info',
#  'jechlfk@sobeessentialenergy.com',
#  'ckjefad@p33.org',
#  'aiijggi@singtelmails.com',
#  'bgddlkg@brmailing.com',
#  'gkibjbb@lexxip.com',
#  'lachcfb@sin-mailing.com',
#  'ajejcgg@faithmail.org',
#  'kghdhfe@consimail.com',
#  'ffflhjk@haydoo.com',
#  'ccgcfgf@outlook.com',
#  'edbjhab@digiuoso.com',
#  'ebcijgg@shopsousvide.com',
#  'cabklac@techspotny.com',
#  'ehjfiea@interia.pl',
#  'iecfidi@mail.ru',
#  'hdilabl@opayq.com',
#  'jidhjgb@hypermailbox.com',
#  'ghjihja@trango.co',
#  'chhfcde@consimail.com',
#  'fbfgcgj@hubspotmails.com',
#  'fhbjabf@digiuoso.com',
#  'jljaijj@freefileserver.com',
#  'cjjkjic@singtelmails.com',
#  'ajbckgf@digiuoso.com',
#  'ffcghal@porsh.net',
#  'iggihib@thiet-ke-web.org',
#  'fkhlegj@gmail.com',
#  'cfjdkic@hotspotmails.com',
#  'bhcebkf@efacs.net',
#  'lfgbagj@lexxip.com',
#  'fiifcdc@yostyle.com.vn',
#  'adaikaf@uminga.net',
#  'acibckg@freemailhosts.com',
#  'ikghgca@matchpol.net',
#  'lbjkbie@novartismails.com',
#  'hjiciac@yandex.com',
#  'bklhidg@pullmail.info',
#  'ddebged@thiet-ke-web.org',
#  'gffedjb@teknokenar.com',
#  'dhifgaf@cliptik.net',
#  'hkkahfj@faithmail.org',
#  'akiijhh@thiet-ke-web.org',
#  'ifajigd@chemeng-masdar.com',
#  'iigfchf@outlook.com',
#  'hcdeigf@visitinbox.com',
#  'lhlejhi@brmailing.com',
#  'ccdajia@kingdomheartmail.com',
#  'ejihdhk@lexxip.com',
#  'dfkdclc@ibmmails.com',
#  'jdigdii@matchpol.net',
#  'jjaeiih@babymails.com',
#  'ddlldbc@mail.com',
#  'bcffjfl@techspotny.com',
#  'ebkfcka@gmail4u.eu',
#  'legcgjk@consimail.com',
#  'hehbfhl@externetworks.com',
#  'dlaibib@kingofplace.site',
#  'hfidckl@1st-apparelsoftware.info',
#  'ggkhhli@faithmail.org',
#  'fcikbhk@novartismails.com',
#  'egacfif@kingofplace.site',
#  'gdggfhk@haydoo.com',
#  'ckefibj@grow-mail.com',
#  'diljjac@kod-maling.com',
#  'eaakeal@singtelmails.com',
#  'ciababj@yostyle.com.vn',
#  'dgjefbf@mozej.com',
#  'ecieahg@hotmail.com',
#  'diljfbc@freemailhosts.com',
#  'gljfcjb@deepemailbox.com',
#  'ljcgjhg@hand-painted-scarves.eu',
#  'gbdlcdk@pullmail.info',
#  'abhhgai@hand-painted-scarves.eu',
#  'biblddd@topbuysteroids365.com',
#  'ehgdbji@brmailing.com',
#  'abdhdca@kodmailing.com',
#  'jecfjac@ibmmails.com',
#  'hlcibjh@buysteroids365.com',
#  'fdljaah@anseohero.com',
#  'halcfii@efacs.net',
#  'igddicj@teimur.com',
#  'eikagbc@visitinbox.com',
#  'dhbfaek@designawebsite.in',
#  'jgeebkh@deepemailbox.com',
#  'chglcch@lovelymail.info',
#  'lilajbc@trango.co',
#  'cgdgfal@jourrapide.com',
#  'hjgfffl@motorcyclebd.com',
#  'ichbglg@bolo.eu.org',
#  'kedlbhb@gmail.com',
#  'geaidkd@allemaling.com',
#  'idjbgdj@abrighterfutureday.com',
#  'gbiijjk@o2.pl',
#  'ldicgdh@webgarden.com',
#  'callhca@continumail.com',
#  'bdaekhc@babymails.com',
#  'halkjka@freefileserver.com',
#  'hgacihi@justbigbox.com',
#  'idfdeih@teknokenar.com',
#  'kbiaife@matchpol.net',
#  'akebffl@queenofsite.online',
#  'eibjbie@gmx.com',
#  'ckjjibk@novartismails.com',
#  'ifdildh@shopsousvide.com',
#  'eacilkh@trango.co',
#  'adikkhl@motorcyclebd.com',
#  'ibbcicc@teimur.com',
#  'aidgkfd@thiet-ke-web.org',
#  'blhehkl@porsh.net',
#  'jbiajdd@protonmail.com',
#  'ghgefld@1st-apparelsoftware.info',
#  'kcedlib@temasekmail.com',
#  'lfcbdjk@drupalmails.com',
#  'lffkaek@lexxip.com',
#  'fdjihkh@novartismails.com',
#  'cicjahk@dupontmails.com',
#  'gdfabkl@checknowmail.com',
#  'akdjkff@mailclubs.info',
#  'lefclaf@teknokenar.com',
#  'clgfgbc@researchobservatories.org.uk',
#  'geeheai@babymails.com',
#  'flbeabk@thiet-ke-web.org',
#  'afdefke@mailclubs.info',
#  'gfeljgj@mailbox92.biz',
#  'fialgfb@faithmail.org',
#  'ifcbacf@kingofplace.site',
#  'biddjhj@pokemail.net',
#  'afeekia@shopsousvide.com',
#  'hglhcja@researchobservatories.org.uk',
#  'afalfkl@allemaling.com',
#  'idfjbcl@mozej.com',
#  'hdihjak@1st-apparelsoftware.info',
#  'ajflale@yopmail.com',
#  'lbejcfg@ginxmail.com',
#  'aeejhge@webgarden.com',
#  'giibhab@intervisionplc.com',
#  'bdcklfa@anseohero.com',
#  'gfidikh@sobeessentialenergy.com',
#  'ihfjjkj@hubspotmails.com',
#  'ijgcadd@allemaling.com',
#  'gakiebk@shopsousvide.com',
#  'ekiejag@p33.org',
#  'ggcidbd@rediffmail.com',
#  'ggbhlee@mail.ru',
#  'jladfck@1st-apparelsoftware.info',
#  'deigeaa@lexxip.com',
#  'fackjbk@mail.com',
#  'hglgklc@mailbox92.biz',
#  'ikgigbk@kod-maling.com',
#  'fbideah@kod-maling.com',
#  'bjhaaaj@opayq.com',
#  'ejkgddi@matchpol.net',
#  'efdfjde@porsh.net',
#  'ljfefhe@topbuysteroids365.com',
#  'abjjjlg@yourmailbox.co',
#  'jkefbha@yourmailbox.co',
#  'acjgcbf@matchpol.net',
#  'behfigb@freefileserver.com',
#  'cabbkdb@techspotny.com',
#  'lghhfgf@sobeessentialenergy.com',
#  'eiaeeac@teknokenar.com',
#  'fdgjclb@ginxmail.com',
#  'eegcdih@abrighterfutureday.com',
#  'lfhgggk@checknowmail.com',
#  'gahheie@yahoo.com.vn',
#  'idgglkk@businesskontakts.com',
#  'hjillla@porsh.net',
#  'calgidg@motorcyclebd.com',
#  'dhlclfi@o2.pl',
#  'cbkefcf@mabermail.com',
#  'cgikhga@efacs.net',
#  'dhliggk@padita.net',
#  'jffjljl@mozej.com',
#  'kgiilcf@thiet-ke-web.org',
#  'llfchfl@gmx.com',
#  'jjdjeeg@lolas3.seo-linuxpl.com',
#  'decfcge@hand-painted-scarves.eu',
#  'cddchda@kingdomheartmail.com',
#  'hackdal@sin-mailing.com',
#  'ghejjad@gloriousfuturedays.com',
#  'cfaiccj@p33.org',
#  'jhejkbj@novartismails.com',
#  'lbgahih@continumail.com',
#  'hcbiadc@binnary.com',
#  'bggbghf@kingofplace.site',
#  'akijgha@abrighterfutureday.com',
#  'heieckh@yourmailbox.co',
#  'ihfhkff@mabermail.com',
#  'lkeflkg@bolo.eu.org',
#  'lfffacd@abrighterfutureday.com',
#  'beidfak@out-email.com',
#  'lghdjkl@abrighterfutureday.com',
#  'jhebjgc@webgarden.com',
#  'fdegahd@chemeng-masdar.com',
#  'iifckdj@pullmail.info',
#  'deghhgg@kod-maling.com',
#  'ifkiahj@baseblogger.com',
#  'ahlheag@businesstutorialsonline.org',
#  'ekhildi@businesskontakts.com',
#  'gcfhfec@allemaling.com',
#  'ffgcehc@hand-painted-scarves.eu',
#  'fihecfa@mail.com',
#  'ligjege@gmail4u.eu',
#  'fgcdiif@consimail.com',
#  'giafakb@kod-maling.com',
#  'hagkgec@protonmail.com',
#  'jjbhkec@continumail.com',
#  'bbfejdb@cliptik.net',
#  'gebhjgk@grow-mail.com',
#  'addckhb@teknokenar.com',
#  'bkkgbka@novartismails.com',
#  'defgaak@techspotny.com',
#  'ddljgbb@lexxip.com',
#  'cjejfcc@freemailhosts.com',
#  'beidljj@continumail.com',
#  'igkehea@kingdomheartmail.com',
#  'hlflgde@wordpressmails.com',
#  'cgcdahf@freefileserver.com',
#  'gaikjdh@motorcyclebd.com',
#  'dbadcia@businesskontakts.com',
#  'hkfekji@singtelmails.com',
#  'kdjalff@wordpressmails.com',
#  'lghfcgb@shopsousvide.com',
#  'jfffkjk@dupontmails.com',
#  'edhgebj@joomlaemails.com',
#  'jcdadkh@babymails.com',
#  'klbjchi@nomail.ga']

# %% [markdown]
# ### spam_websites dummy data generation code

# %%
spam_website_csv = domains_data["spam_website"]
spam_website_domains = {urlparse(website).hostname for website in spam_website_csv}

# %%
spam_websites = list()
spam_website_domains = list(spam_website_domains)
sometimes_https = [random.randint(1,size-1) for i in range(0,int(size/10))]
def generate_website_domains():
    for i in range(0,size):
        one_name = str(get_one_random_name(letters))
        one_domain = str(get_one_random_domain(spam_website_domains)) 
        prefix = "http"
        if i in sometimes_https: 
                prefix = "https"
        website = prefix+"://"+one_domain
        spam_websites.append(website)
generate_website_domains()
spam_websites
# Out:
# ['http://www.banaby.pl',
#  'http://www.e-perfumy.sklep.pl',
#  'http://kodeware.net',
#  'https://superventasclub.blogspot.com.es',
#  'http://falconsvspatriots.net',
#  'http://andrews29aguirre.postbit.com',
#  'http://www.banaby.pl',
#  'http://None',
#  'https://loginaid.org',
#  'http://tropicalflowersonline.sitey.me',
#  'https://tawanrestaurant.com',
#  'https://topsevenreview.com',
#  'https://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://loginaid.org',
#  'http://crhacknew.com',
#  'http://start.me',
#  'http://giantsvspackers.co',
#  'http://bangaloreescortgirl.com',
#  'http://sieumuanhanh.com',
#  'http://www.projectwedding.com',
#  'http://www.nature.com',
#  'http://www.dubaismile.com',
#  'http://www.apkshare.net',
#  'http://piratesofthecaribbean-5.org',
#  'http://www.boostingkings.com',
#  'http://www.bookmarkee.com',
#  'http://alabamavsflorida.org',
#  'http://csr2updatedhacknew.com',
#  'https://thez9.com',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://buegelstationtest.de',
#  'http://fifa18coins.org',
#  'http://gethealthywithines.info',
#  'http://loginaid.org',
#  'http://www.mirlasabino.com',
#  'http://www.angelss.in',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://cracxpro.com',
#  'http://www.harryhost.com',
#  'http://www.montrealtherapy.com',
#  'http://0rz.tw',
#  'http://activationkeys.org',
#  'http://buegelstationtest.de',
#  'http://verycheapcarinsurance.us',
#  'http://www.mixlikes.com',
#  'http://karyasahabatglobal.com',
#  'http://www.kisaiya.co.uk',
#  'http://0rz.tw',
#  'http://gamehackerappdownload.com',
#  'http://giayplus.com',
#  'http://quantumcodequantumcode.com',
#  'http://giayplus.com',
#  'https://www.dubaismile.com',
#  'http://navetic.com',
#  'http://www.conductexam.com',
#  'http://www.esiptel.pl',
#  'http://gamehackerappdownload.com',
#  'http://www.invhome.in',
#  'http://www.karsltd.co.uk',
#  'http://musicparadiseapk.com',
#  'http://wrenchankle7.jiliblog.com',
#  'http://www.gunsplus.com.au',
#  'https://thez9.com',
#  'https://0rz.tw',
#  'http://buegelstationtest.de',
#  'http://www.thehinduchronicle.com',
#  'http://odkupimyszkode.pl',
#  'http://superventasclub.blogspot.com.es',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://email.tecsupportnubers.com',
#  'http://wrenchankle7.jiliblog.com',
#  'http://duelundernstsen0.blog5.net',
#  'http://www.pilatesbh.info',
#  'http://zombocalypseunblocked.info',
#  'http://csr2updatedhacknew.com',
#  'http://www.codecademy.com',
#  'http://www.dubaismile.com',
#  'http://start.me',
#  'http://zombocalypseunblocked.info',
#  'http://carlsbadfences.xyz',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://klout.com',
#  'http://freecodescheats.com',
#  'http://hireforseo.com',
#  'http://cybyte.com',
#  'http://www.fieldengineer.com',
#  'http://yourshot.nationalgeographic.com',
#  'http://licensekey.net',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://www.latestforextips.com',
#  'http://www.curatenieprofi.ro',
#  'http://handheldshowerheadguide.com',
#  'http://www.apkita.com',
#  'http://activationkeys.org',
#  'http://www.messeagentur-z3.ch',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://bitbucket.org',
#  'http://www.igassetmanagement.com',
#  'http://www.bookstraining.com',
#  'http://lionstreestore.tumblr.com',
#  'http://www.fieldengineer.com',
#  'https://www.199creative.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.curatenieprofi.ro',
#  'http://alabamavsflorida.org',
#  'http://www.mixlikes.com',
#  'http://www.agarwalcartransport.co.in',
#  'http://www.angelss.in',
#  'http://defineyourdirection.yolasite.com',
#  'http://www.codecademy.com',
#  'http://finance.yahoo.com',
#  'http://falconsvspatriots.net',
#  'http://www.curatenieprofi.ro',
#  'https://www.amztk.com',
#  'http://gemscochackz.com',
#  'http://tawanrestaurant.com',
#  'http://www.email-customer-care.com',
#  'http://globalprotec.com',
#  'http://www.approveloannow.com',
#  'http://navetic.com',
#  'https://www.myhealthyera.com',
#  'http://karyasahabatglobal.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.email-customer-care.com',
#  'http://www.igassetmanagement.com',
#  'http://www.robloxhack.org',
#  'http://windowdoubleglazed.parsiblog.com',
#  'https://testy-do-policji.pl',
#  'http://tanibankiet.pl',
#  'http://tanibankiet.pl',
#  'http://alabama-vs-clemson.us',
#  'http://1001togel.info',
#  'https://giayplus.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://www.housecleanercares.com.au',
#  'http://www.esiptel.pl',
#  'http://cochackertop.com',
#  'http://klout.com',
#  'http://bit.ly',
#  'http://licensekey.net',
#  'http://crupusnew.com',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://bitbucket.org',
#  'http://www.email-customer-care.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://sieumuanhanh.com',
#  'http://clevermosaics.com',
#  'http://bit.ly',
#  'http://kauf-wert.de',
#  'http://www.prnewswire.com',
#  'http://www.trx250r.net',
#  'http://caodangyduochcm.vn',
#  'http://www.myhealthyera.com',
#  'http://www.harryhost.com',
#  'http://www.camera24x7.com',
#  'http://www.boostingkings.com',
#  'http://musicparadiseapk.com',
#  'https://alabamavsclemson.net',
#  'http://www.142sure.com',
#  'http://quantumcodequantumcode.com',
#  'http://tawanrestaurant.com',
#  'http://thez9.com',
#  'http://www.montrealtherapy.com',
#  'http://www.seobrain.ca',
#  'http://tawanrestaurant.com',
#  'http://cracxpro.com',
#  'http://www.projectwedding.com',
#  'http://superventasclub.blogspot.com.es',
#  'https://www.dubaismile.com',
#  'http://cracxpro.com',
#  'https://www.cloudyads.com',
#  'http://www.culos-grandes.net',
#  'http://cupamericas.com',
#  'http://klout.com',
#  'http://goo.gl',
#  'http://www.trx250r.net',
#  'http://andropps.com',
#  'http://lionstreestore.tumblr.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://tanibankiet.pl',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://www.gunsplus.com.au',
#  'http://www.199creative.com',
#  'http://falconsvspackers.org',
#  'http://cochackertop.com',
#  'http://www.trx250r.net',
#  'https://www.newqbo.com',
#  'http://samsung.gulfegy-service.com',
#  'http://www.karsltd.co.uk',
#  'http://www.quickbooks-customer-support-number.com',
#  'http://www.agarwalcartransport.co.in',
#  'https://licensekey.net',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://hireforseo.com',
#  'https://free-credit-reports-from-all-3-bureaus.com',
#  'http://proserialkey.com',
#  'http://www.apkshare.net',
#  'http://rulle-gardiner.dk',
#  'http://piratesofthecaribbean-5.org',
#  'http://kauf-wert.de',
#  'http://wrenchankle7.jiliblog.com',
#  'http://www.prnewswire.com',
#  'http://andrews29aguirre.postbit.com',
#  'http://talleypoole67.suomiblog.com',
#  'http://www.schweizerkredit.swiss',
#  'http://activationkeys.org',
#  'http://true26orr.affiliatblogger.com',
#  'http://bitbucket.org',
#  'http://www.quickbooks-customer-support-number.com',
#  'http://podlogi24.net',
#  'http://www.horshamservices.com',
#  'http://www.curvalicious.fit',
#  'http://www.indexemperor.com',
#  'http://stolyskladane.pl',
#  'http://testy-do-policji.pl',
#  'http://hdwatchtvgametv.com',
#  'http://alabamavsclemson.net',
#  'https://globalprotec.com',
#  'http://vaytinchap99.com',
#  'http://www.sacredhypnogoddess.com',
#  'https://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://remimalca.com',
#  'http://rulle-gardiner.dk',
#  'http://crhacknew.com',
#  'http://samsung.gulfegy-service.com',
#  'http://cochackertop.com',
#  'http://bitbucket.org',
#  'http://www.camera24x7.com',
#  'http://shadanigroup.com',
#  'http://klout.com',
#  'http://www.nature.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'https://handheldshowerheadguide.com',
#  'http://www.curatenieprofi.ro',
#  'http://www.conductexam.com',
#  'http://bitbucket.org',
#  'http://giaytaycaocap.info',
#  'http://www.dubaismile.com',
#  'http://email.tecsupportnubers.com',
#  'http://www.trx250r.net',
#  'http://true26orr.affiliatblogger.com',
#  'http://www.curvalicious.fit',
#  'http://musicparadiseapk.com',
#  'http://shadanigroup.com',
#  'http://www.gunsplus.com.au',
#  'http://tropicalflowersonline.sitey.me',
#  'http://www.invhome.in',
#  'https://falconsvspatriotslive.org',
#  'http://www.curvalicious.fit',
#  'http://duelundernstsen0.blog5.net',
#  'http://www.hand-painted-scarves.eu',
#  'http://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'http://www.invhome.in',
#  'http://www.fireemblemheroestips.com',
#  'http://crupusnew.com',
#  'http://www.igassetmanagement.com',
#  'http://buegelstationtest.de',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://www.bother-printer-support.net',
#  'http://www.seobrain.ca',
#  'https://talleypoole67.suomiblog.com',
#  'http://alabamavclemson.co',
#  'http://odkupimyszkode.pl',
#  'http://buegelstationtest.de',
#  'http://www.invhome.in',
#  'http://www.indexemperor.com',
#  'http://www.horshamservices.com',
#  'http://www.newcitymovers.com',
#  'http://fifa18coins.org',
#  'http://gethealthywithines.info',
#  'http://www.gunsplus.com.au',
#  'http://www.harryhost.com',
#  'http://andrews29aguirre.postbit.com',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://bitbucket.org',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://www.e-perfumy.sklep.pl',
#  'http://www.antivirusnumberusa.com',
#  'http://crblasterus.com',
#  'http://duelundernstsen0.blog5.net',
#  'https://www.apkita.com',
#  'http://www.myhealthyera.com',
#  'http://sieumuanhanh.com',
#  'http://www.ivalley.co',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://tawanrestaurant.com',
#  'http://www.montrealtherapy.com',
#  'http://www.artonall.com',
#  'http://www.bother-printer-support.net',
#  'http://www.montrealtherapy.com',
#  'http://loginaid.org',
#  'http://www.horshamservices.com',
#  'http://www.mixlikes.com',
#  'http://www.gumtree.com.au',
#  'http://kodeware.net',
#  'http://www.mirlasabino.com',
#  'http://topsevenreview.com',
#  'http://cochackertop.com',
#  'http://www.buyhealthmart.com',
#  'http://www.gumtree.com.au',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://www.apkshare.net',
#  'http://quantumcodequantumcode.com',
#  'http://www.sharda.ac.in',
#  'http://musicparadiseapk.com',
#  'http://rulle-gardiner.dk',
#  'http://www.messeagentur-z3.ch',
#  'http://gethealthywithines.info',
#  'http://musicparadiseapk.com',
#  'http://www.142sure.com',
#  'http://testy-do-policji.pl',
#  'http://giayplus.com',
#  'http://sieumuanhanh.com',
#  'https://www.sacredhypnogoddess.com',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://www.agarwalcartransport.co.in',
#  'http://www.montrealtherapy.com',
#  'http://cochackertop.com',
#  'http://www.newcitymovers.com',
#  'https://alabamavwashington.org',
#  'http://www.oneridetheevent.com',
#  'http://musicparadiseapk.com',
#  'http://www.trx250r.net',
#  'http://www.sacredhypnogoddess.com',
#  'http://www.karsltd.co.uk',
#  'http://pureconceptions.com',
#  'http://minds.cool',
#  'http://falconsvspatriots.net',
#  'https://www.annesylviehenchoz.com',
#  'http://thebackupgeneratorguide.joomla.com',
#  'https://www.buyhealthmart.com',
#  'http://www.powaiflats.com',
#  'https://www.artonall.com',
#  'http://saedx.com',
#  'http://shadanigroup.com',
#  'http://hireforseo.com',
#  'http://bangaloreescortgirl.com',
#  'http://www.apkshare.net',
#  'http://fifa18coins.org',
#  'http://falconsvspatriots.net',
#  'http://free-credit-reports-from-all-3-bureaus.com',
#  'http://defineyourdirection.yolasite.com',
#  'http://www.myhealthyera.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.montrealtherapy.com',
#  'http://alabamavsclemson.net',
#  'http://fifa18coins.org',
#  'https://loginaid.org',
#  'http://www.horshamservices.com',
#  'https://www.199creative.com',
#  'http://www.angelss.in',
#  'http://clevermosaics.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://www.agarwalcartransport.co.in',
#  'http://www.bother-printer-support.net',
#  'http://bitbucket.org',
#  'http://hireforseo.com',
#  'http://www.karsltd.co.uk',
#  'http://kauf-wert.de',
#  'http://giaytaycaocap.info',
#  'http://www.gumtree.com.au',
#  'http://gemscochackz.com',
#  'http://alaamiahclean.com',
#  'http://falconsvspatriots.net',
#  'http://gemscochackz.com',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://www.esiptel.pl',
#  'http://www.camera24x7.com',
#  'http://www.gotshirtscy.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://globalprotec.com',
#  'http://handheldshowerheadguide.com',
#  'http://bitbucket.org',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://www.fireemblemheroestips.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.amztk.com',
#  'http://www.800tollfreenumber.net',
#  'https://www.thehinduchronicle.com',
#  'http://alabamavsclemson.net',
#  'http://lionstreestore.tumblr.com',
#  'http://tanibankiet.pl',
#  'http://cracxpro.com',
#  'http://www.driversfreedownload.com',
#  'http://www.nature.com',
#  'http://alabamavclemson.co',
#  'http://start.me',
#  'http://handheldshowerheadguide.com',
#  'http://loginaid.org',
#  'http://kauf-wert.de',
#  'http://www.bother-printer-support.net',
#  'http://csr2updatedhacknew.com',
#  'http://comocurarhemorroides.net',
#  'http://gorillazhumanz.com',
#  'http://www.testnaiq.com.pl',
#  'http://giayplus.com',
#  'http://www.projectwedding.com',
#  'http://hireforseo.com',
#  'http://www.ladystyl.pl',
#  'https://twitter.com',
#  'http://www.newcitymovers.com',
#  'http://www.angelss.in',
#  'http://www.cloudyads.com',
#  'http://loginaid.org',
#  'http://www.angelss.in',
#  'http://giayplus.com',
#  'http://www.annesylviehenchoz.com',
#  'http://www.mirlasabino.com',
#  'http://sieumuanhanh.com',
#  'http://www.schweizerkredit.swiss',
#  'http://www.apkshare.net',
#  'http://zombocalypseunblocked.info',
#  'http://topsevenreview.com',
#  'http://topsevenreview.com',
#  'http://gamehackerappdownload.com',
#  'http://www.fireemblemheroestips.com',
#  'http://wizaccounting.com',
#  'http://www.mixlikes.com',
#  'http://minds.cool',
#  'http://bangaloreescortgirl.com',
#  'https://www.driversfreedownload.com',
#  'http://www.teknokenar.com',
#  'http://www.banaby.pl',
#  'http://stolyskladane.pl',
#  'https://www.quickbooks-customer-support-number.com',
#  'http://www.kisaiya.co.uk',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://www.gotshirtscy.com',
#  'http://loginaid.org',
#  'http://stolyskladane.pl',
#  'http://hireforseo.com',
#  'http://www.angelss.in',
#  'http://thez9.com',
#  'http://podlogi24.net',
#  'http://clevermosaics.com',
#  'http://www.banaby.pl',
#  'http://falconsvspatriotslive.org',
#  'https://www.messeagentur-z3.ch',
#  'http://www.hand-painted-scarves.eu',
#  'https://1001togel.info',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://gorillazhumanz.com',
#  'http://crblasterus.com',
#  'http://goo.gl',
#  'http://www.dubaismile.com',
#  'http://None',
#  'http://None',
#  'http://www.quickbooksenterprisesupport.org',
#  'http://www.bother-printer-support.net',
#  'http://www.curatenieprofi.ro',
#  'http://www.angelss.in',
#  'http://navetic.com',
#  'http://alabamavsclemson.net',
#  'http://www.codecademy.com',
#  'http://yourshot.nationalgeographic.com',
#  'http://alabamavsclemson.net',
#  'http://www.culos-grandes.net',
#  'http://www.montrealtherapy.com',
#  'http://biurocash.pl',
#  'http://www.approveloannow.com',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://www.ivalley.co',
#  'http://www.boostingkings.com',
#  'http://wizaccounting.com',
#  'https://bit.ly',
#  'https://www.blackhatworld.com',
#  'http://www.prnewswire.com',
#  'http://csr2updatedhacknew.com',
#  'http://twitter.com',
#  'http://sieumuanhanh.com',
#  'http://podlogi24.net',
#  'http://www.seobrain.ca',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://theseoagency.org',
#  'http://www.replicahandbags.space',
#  'http://samsung.gulfegy-service.com',
#  'http://www.bookstraining.com',
#  'http://falconsvspatriots.net',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://giayplus.com',
#  'http://odkupimyszkode.pl',
#  'http://www.montrealtherapy.com',
#  'http://carlsbadfences.xyz',
#  'http://cracxpro.com',
#  'https://alabamavclemson.co',
#  'https://giayplus.com',
#  'https://vaytinchap99.com',
#  'http://true26orr.affiliatblogger.com',
#  'http://cupamericas.com',
#  'http://handheldshowerheadguide.com',
#  'http://cracxpro.com',
#  'http://quantumcodequantumcode.com',
#  'http://falconsvspackers.org',
#  'http://geminiwomen47.ampedpages.com',
#  'http://www.prnewswire.com',
#  'http://www.igassetmanagement.com',
#  'http://www.gumtree.com.au',
#  'http://www.banaby.pl',
#  'https://giaytaycaocap.info',
#  'http://www.mrvehicle.net',
#  'http://cupamericas.com',
#  'http://cybyte.com',
#  'http://docs.google.com',
#  'http://quantumcodequantumcode.com',
#  'http://cracxpro.com',
#  'http://alabamavwashington.org',
#  'https://www.agarwalcartransport.co.in',
#  'http://1001togel.info',
#  'http://www.curatenieprofi.ro',
#  'http://cybyte.com',
#  'http://proserialkey.com',
#  'http://start.me',
#  'http://www.newqbo.com',
#  'https://true26orr.affiliatblogger.com',
#  'http://twitter.com',
#  'http://www.gunsplus.com.au',
#  'http://www.199creative.com',
#  'http://talleypoole67.suomiblog.com',
#  'http://www.sharda.ac.in',
#  'http://www.newcitymovers.com',
#  'http://www.schweizerkredit.swiss',
#  'https://clevermosaics.com',
#  'http://hairrestorationlaboratoriesllc.com',
#  'http://twitter.com',
#  'http://flattr.com',
#  'http://www.esiptel.pl',
#  'http://freeeshopcodes.net',
#  'http://www.teknokenar.com',
#  'http://www.antivirusnumberusa.com',
#  'http://mp4gain.com',
#  'http://www.gumtree.com.au',
#  'http://0rz.tw',
#  'http://www.oneridetheevent.com',
#  'http://www.schweizerkredit.swiss',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://www.esiptel.pl',
#  'http://www.ladystyl.pl',
#  'http://www.cloudyads.com',
#  'https://falconsvspatriotslive.org',
#  'http://www.fireemblemheroestips.com',
#  'http://www.igassetmanagement.com',
#  'http://www.199creative.com',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://activationkeys.org',
#  'http://shadanigroup.com',
#  'http://www.kisaiya.co.uk',
#  'http://www.banaby.pl',
#  'http://bitbucket.org',
#  'http://alabamavsclemson.net',
#  'http://www.boostingkings.com',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://mp4gain.com',
#  'https://www.approveloannow.com',
#  'http://www.newqbo.com',
#  'https://www.newcitymovers.com',
#  'http://start.me',
#  'http://buegelstationtest.de',
#  'http://www.mrvehicle.net',
#  'http://vaytinchap99.com',
#  'http://falconsvspatriotslive.org',
#  'http://lionstreestore.tumblr.com',
#  'http://carlsbadfences.xyz',
#  'http://www.codecademy.com',
#  'http://true26orr.affiliatblogger.com',
#  'http://www.gotshirtscy.com',
#  'http://gamehackerappdownload.com',
#  'http://duelundernstsen0.blog5.net',
#  'http://finance.yahoo.com',
#  'http://www.driversfreedownload.com',
#  'http://odkupimyszkode.pl',
#  'http://www.bother-printer-support.net',
#  'http://navetic.com',
#  'http://activationkeys.org',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://fifa18coins.org',
#  'http://verycheapcarinsurance.us',
#  'http://www.quickbooks-customer-support-number.com',
#  'http://talleypoole67.suomiblog.com',
#  'http://www.invhome.in',
#  'http://hdwatchtvgametv.com',
#  'http://gethealthywithines.info',
#  'http://twitter.com',
#  'http://alabamavsflorida.org',
#  'http://thebackupgeneratorguide.joomla.com',
#  'http://www.annesylviehenchoz.com',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://goo.gl',
#  'http://andrews29aguirre.postbit.com',
#  'http://mp4gain.com',
#  'http://handheldshowerheadguide.com',
#  'http://theseoagency.org',
#  'http://www.invhome.in',
#  'http://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'https://falconsvspackers.org',
#  'http://zombocalypseunblocked.info',
#  'http://verycheapcarinsurance.us',
#  'http://www.prnewswire.com',
#  'http://clevermosaics.com',
#  'http://www.banaby.pl',
#  'http://kodeware.net',
#  'http://crblasterus.com',
#  'http://www.hand-painted-scarves.eu',
#  'http://www.esiptel.pl',
#  'http://finance.yahoo.com',
#  'https://www.newqbo.com',
#  'http://cracxpro.com',
#  'http://tawanrestaurant.com',
#  'http://www.mrvehicle.net',
#  'https://windowdoubleglazed.parsiblog.com',
#  'http://biurocash.pl',
#  'http://www.schweizerkredit.swiss',
#  'http://saedx.com',
#  'http://crblasterus.com',
#  'http://www.farinluck.com',
#  'http://stolyskladane.pl',
#  'http://kodeware.net',
#  'http://stolyskladane.pl',
#  'http://kauf-wert.de',
#  'http://falconsvspatriots.net',
#  'https://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'http://handheldshowerheadguide.com',
#  'http://gamehackerappdownload.com',
#  'https://www.newqbo.com',
#  'http://hdwatchtvgametv.com',
#  'https://alabamavclemson.co',
#  'http://www.powaiflats.com',
#  'http://www.apkshare.net',
#  'http://defineyourdirection.yolasite.com',
#  'http://goo.gl',
#  'http://www.teknokenar.com',
#  'http://www.camera24x7.com',
#  'http://www.fieldengineer.com',
#  'http://jekyllandhydedubai.com',
#  'http://www.trx250r.net',
#  'http://talleypoole67.suomiblog.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'https://alaamiahclean.com',
#  'http://www.trx250r.net',
#  'http://giayplus.com',
#  'http://www.nature.com',
#  'http://alabamavwashington.org',
#  'http://giayplus.com',
#  'http://www.myhealthyera.com',
#  'http://jekyllandhydedubai.com',
#  'https://www.housecleanercares.com.au',
#  'http://www.thehinduchronicle.com',
#  'http://alabamavsflorida.org',
#  'http://www.newcitymovers.com',
#  'http://samsung.gulfegy-service.com',
#  'http://pureconceptions.com',
#  'http://sieumuanhanh.com',
#  'http://windowdoubleglazed.parsiblog.com',
#  'http://www.oneridetheevent.com',
#  'http://www.replicahandbags.space',
#  'http://navetic.com',
#  'http://sieumuanhanh.com',
#  'http://www.schweizerkredit.swiss',
#  'http://odkupimyszkode.pl',
#  'http://gorillazhumanz.com',
#  'http://freecodescheats.com',
#  'http://comocurarhemorroides.net',
#  'http://gamehackerappdownload.com',
#  'http://remimalca.com',
#  'http://sieumuanhanh.com',
#  'http://globalprotec.com',
#  'http://mp4gain.com',
#  'http://minds.cool',
#  'https://hireforseo.com',
#  'http://www.mrvehicle.net',
#  'http://crhacknew.com',
#  'http://www.dubaismile.com',
#  'http://caodangyduochcm.vn',
#  'http://www.sacredhypnogoddess.com',
#  'http://wrenchankle7.jiliblog.com',
#  'http://www.gumtree.com.au',
#  'http://klout.com',
#  'http://alaamiahclean.com',
#  'http://royalrevolt2hack.online',
#  'http://cupamericas.com',
#  'https://www.blackhatworld.com',
#  'http://geminiwomen47.ampedpages.com',
#  'http://www.800tollfreenumber.net',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://bitbucket.org',
#  'http://karyasahabatglobal.com',
#  'http://lionstreestore.tumblr.com',
#  'http://www.blackhatworld.com',
#  'http://minds.cool',
#  'http://yourshot.nationalgeographic.com',
#  'http://www.montrealtherapy.com',
#  'http://geminiwomen47.ampedpages.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://www.ivalley.co',
#  'http://handheldshowerheadguide.com',
#  'http://proserialkey.com',
#  'https://www.fieldengineer.com',
#  'http://hireforseo.com',
#  'http://www.alivebetter.com',
#  'http://www.ivalley.co',
#  'http://www.142sure.com',
#  'http://bit.ly',
#  'http://www.conductexam.com',
#  'https://www.latestforextips.com',
#  'http://windowdoubleglazed.parsiblog.com',
#  'http://falconsvspatriots.net',
#  'http://www.nature.com',
#  'http://www.bookstraining.com',
#  'http://bit.ly',
#  'http://1001togel.info',
#  'https://goo.gl',
#  'http://www.cloudyads.com',
#  'http://sieumuanhanh.com',
#  'http://biurocash.pl',
#  'http://www.housecleanercares.com.au',
#  'http://falconsvspatriots.net',
#  'http://freeeshopcodes.net',
#  'http://www.approveloannow.com',
#  'http://comocurarhemorroides.net',
#  'http://lionstreestore.tumblr.com',
#  'https://gemscochackz.com',
#  'http://www.email-customer-care.com',
#  'http://yourshot.nationalgeographic.com',
#  'http://www.powaiflats.com',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://www.email-customer-care.com',
#  'http://falconsvspatriotslive.org',
#  'http://docs.google.com',
#  'http://defineyourdirection.yolasite.com',
#  'http://bitbucket.org',
#  'https://licensekey.net',
#  'https://www.powaiflats.com',
#  'http://freeeshopcodes.net',
#  'http://www.blackhatworld.com',
#  'http://www.indexemperor.com',
#  'http://flattr.com',
#  'http://www.nature.com',
#  'http://www.housecleanercares.com.au',
#  'http://jekyllandhydedubai.com',
#  'http://saedx.com',
#  'https://www.oneridetheevent.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://carlsbadfences.xyz',
#  'http://thecatholicthing.org',
#  'http://zombocalypseunblocked.info',
#  'http://www.farinluck.com',
#  'https://yorkshirepersonalinjury.mlst.org',
#  'http://hireforseo.com',
#  'http://bangaloreescortgirl.com',
#  'http://bit.ly',
#  'http://hdwatchtvgametv.com',
#  'http://biurocash.pl',
#  'http://twitter.com',
#  'https://yorkshirepersonalinjury.mlst.org',
#  'http://www.kisaiya.co.uk',
#  'http://alabamavclemson.co',
#  'http://www.annesylviehenchoz.com',
#  'http://start.me',
#  'http://activationkeys.org',
#  'http://clevermosaics.com',
#  'http://thecatholicthing.org',
#  'http://wrenchankle7.jiliblog.com',
#  'http://musicparadiseapk.com',
#  'http://gorillazhumanz.com',
#  'http://www.prnewswire.com',
#  'http://www.sharda.ac.in',
#  'http://www.newcitymovers.com',
#  'https://yourshot.nationalgeographic.com',
#  'http://caodangyduochcm.vn',
#  'http://stolyskladane.pl',
#  'http://carlsbadfences.xyz',
#  'http://www.montrealtherapy.com',
#  'http://odkupimyszkode.pl',
#  'http://free-credit-reports-from-all-3-bureaus.com',
#  'http://www.mrvehicle.net',
#  'http://zombocalypseunblocked.info',
#  'http://www.curatenieprofi.ro',
#  'http://fifa18coins.org',
#  'http://yorkshirepersonalinjury.mlst.org',
#  'http://www.quickbooksenterprisesupport.org',
#  'http://www.oneridetheevent.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://verycheapcarinsurance.us',
#  'http://falconsvspatriotslive.org',
#  'http://tanibankiet.pl',
#  'http://cupamericas.com',
#  'http://gamehackerappdownload.com',
#  'https://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://tropicalflowersonline.sitey.me',
#  'http://www.oneridetheevent.com',
#  'http://flattr.com',
#  'http://csr2updatedhacknew.com',
#  'http://wrenchankle7.jiliblog.com',
#  'http://www.banaby.pl',
#  'https://1001togel.info',
#  'http://www.codecademy.com',
#  'http://www.thehinduchronicle.com',
#  'http://www.driversfreedownload.com',
#  'http://www.projectwedding.com',
#  'http://www.142sure.com',
#  'http://www.indexemperor.com',
#  'http://free-credit-reports-from-all-3-bureaus.com',
#  'http://www.antivirusnumberusa.com',
#  'https://alabamavsclemson.net',
#  'http://www.latestforextips.com',
#  'https://www.pilatesbh.info',
#  'http://1001togel.info',
#  'http://giaytaycaocap.info',
#  'http://www.toursmiamitokeywest.com',
#  'http://www.oneridetheevent.com',
#  'http://www.cloudyads.com',
#  'http://cybyte.com',
#  'http://0rz.tw',
#  'http://www.bother-printer-support.net',
#  'http://www.hand-painted-scarves.eu',
#  'http://flattr.com',
#  'http://goo.gl',
#  'http://podlogi24.net',
#  'http://www.cloudyads.com',
#  'http://www.annesylviehenchoz.com',
#  'http://saedx.com',
#  'http://www.gunsplus.com.au',
#  'http://bitbucket.org',
#  'http://yourshot.nationalgeographic.com',
#  'http://www.antivirusnumberusa.com',
#  'http://minds.cool',
#  'http://www.banaby.pl',
#  'http://www.myhealthyera.com',
#  'http://jekyllandhydedubai.com',
#  'http://www.curvalicious.fit',
#  'http://bangaloreescortgirl.com',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://alaamiahclean.com',
#  'http://podlogi24.net',
#  'http://thez9.com',
#  'http://mp4gain.com',
#  'https://www.e-perfumy.sklep.pl',
#  'http://superventasclub.blogspot.com.es',
#  'http://www.amztk.com',
#  'http://www.buyhealthmart.com',
#  'http://remimalca.com',
#  'http://www.latestforextips.com',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://freecodescheats.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://mp4gain.com',
#  'http://thecatholicthing.org',
#  'http://buegelstationtest.de',
#  'https://www.invhome.in',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://www.camera24x7.com',
#  'https://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://www.quickbooks-customer-support-number.com',
#  'http://www.bee-plumbing.com',
#  'http://piratesofthecaribbean-5.org',
#  'http://www.buyhealthmart.com',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'https://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://start.me',
#  'http://www.prnewswire.com',
#  'http://tanibankiet.pl',
#  'http://tawanrestaurant.com',
#  'http://www.sharda.ac.in',
#  'https://www.annesylviehenchoz.com',
#  'http://hireforseo.com',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://pureconceptions.com',
#  'http://www.camera24x7.com',
#  'http://www.horshamservices.com',
#  'http://www.bee-plumbing.com',
#  'http://www.alivebetter.com',
#  'http://cracxpro.com',
#  'http://www.replicahandbags.space',
#  'http://www.gotshirtscy.com',
#  'http://thez9.com',
#  'http://gamehackerappdownload.com',
#  'http://www.mirlasabino.com',
#  'http://giaytaycaocap.info',
#  'https://buegelstationtest.de',
#  'http://defineyourdirection.yolasite.com',
#  'http://www.curvalicious.fit',
#  'http://falconsvspatriotslive.org',
#  'http://clevermosaics.com',
#  'http://www.quickbooks-customer-support-number.com',
#  'http://clevermosaics.com',
#  'http://odkupimyszkode.pl',
#  'http://www.annesylviehenchoz.com',
#  'https://karyasahabatglobal.com',
#  'http://musicparadiseapk.com',
#  'http://csr2updatedhacknew.com',
#  'https://quantumcodequantumcode.com',
#  'http://www.newcitymovers.com',
#  'http://flattr.com',
#  'http://andropps.com',
#  'http://www.800tollfreenumber.net',
#  'http://mp4gain.com',
#  'http://testy-do-policji.pl',
#  'http://www.trx250r.net',
#  'http://www.mrvehicle.net',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://saedx.com',
#  'http://0rz.tw',
#  'http://cracxpro.com',
#  'http://www.apkita.com',
#  'http://licensekey.net',
#  'http://www.powaiflats.com',
#  'http://kauf-wert.de',
#  'http://www.mrvehicle.net',
#  'http://falconsvspackers.org',
#  'http://saedx.com',
#  'https://www.codecademy.com',
#  'http://yorkshirepersonalinjury.mlst.org',
#  'http://www.email-customer-care.com',
#  'http://karyasahabatglobal.com',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://royalrevolt2hack.online',
#  'https://www.testnaiq.com.pl',
#  'http://www.myhealthyera.com',
#  'https://gorillazhumanz.com',
#  'http://duelundernstsen0.blog5.net',
#  'http://giayplus.com',
#  'http://samsung.gulfegy-service.com',
#  'http://www.driversfreedownload.com',
#  'http://bit.ly',
#  'http://www.housecleanercares.com.au',
#  'http://www.apkshare.net',
#  'http://caodangyduochcm.vn',
#  'https://www.esiptel.pl',
#  'http://buegelstationtest.de',
#  'http://www.sharda.ac.in',
#  'http://activationkeys.org',
#  'http://www.boostingkings.com',
#  'http://globalprotec.com',
#  'https://falconsvspatriots.net',
#  'http://zombocalypseunblocked.info',
#  'http://daftartembakfish.com',
#  'http://www.schweizerkredit.swiss',
#  'http://www.curatenieprofi.ro',
#  'http://www.robloxhack.org',
#  'http://www.driversfreedownload.com',
#  'http://alabamavwashington.org',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://www.karsltd.co.uk',
#  'http://www.boostingkings.com',
#  'http://jekyllandhydedubai.com',
#  'http://clevermosaics.com',
#  'http://www.powaiflats.com',
#  'http://carlsbadfences.xyz',
#  'http://www.gunsplus.com.au',
#  'http://remimalca.com',
#  'http://topsevenreview.com',
#  'http://www.bookmarkee.com',
#  'http://zombocalypseunblocked.info',
#  'http://goo.gl',
#  'http://www.bee-plumbing.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://podlogi24.net',
#  'http://www.esiptel.pl',
#  'http://buegelstationtest.de',
#  'http://www.mrvehicle.net',
#  'http://wizaccounting.com',
#  'http://www.sharda.ac.in',
#  'http://thez9.com',
#  'https://www.trx250r.net',
#  'http://www.culos-grandes.net',
#  'http://jekyllandhydedubai.com',
#  'http://www.thehinduchronicle.com',
#  'http://www.gunsplus.com.au',
#  'http://www.montrealtherapy.com',
#  'http://www.newqbo.com',
#  'http://www.dubaismile.com',
#  'https://duelundernstsen0.blog5.net',
#  'http://www.e-perfumy.sklep.pl',
#  'http://www.oneridetheevent.com',
#  'http://royalrevolt2hack.online',
#  'https://www.teknokenar.com',
#  'http://musicparadiseapk.com',
#  'http://www.projectwedding.com',
#  'http://www.apkshare.net',
#  'http://www.robloxhack.org',
#  'https://zombocalypseunblocked.info',
#  'http://royaleclashgemswin.com',
#  'https://www.banaby.pl',
#  'http://www.gotshirtscy.com',
#  'https://jekyllandhydedubai.com',
#  'http://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'http://gemscochackz.com',
#  'http://www.toursmiamitokeywest.com',
#  'http://www.gunsplus.com.au',
#  'http://www.teknokenar.com',
#  'http://remimalca.com',
#  'http://crupusnew.com',
#  'http://docs.google.com',
#  'http://comocurarhemorroides.net',
#  'http://kodeware.net',
#  'http://www.nature.com',
#  'https://hdwatchtvgametv.com']

# %% [markdown]
# ### spam_bios dummy data generation code

# %%
bio_url = " www.spam.org "
import json
import urllib.request
url = urllib.request.urlopen("https://raw.githubusercontent.com/sindresorhus/mnemonic-words/master/words.json")
words = json.loads(url.read())
random_word = random.choice(words)
spam_bio_link = [random.randint(1,size-1) for i in range(0,int(size*0.8))]


spam_bios=[0 for i in range(size)]
sentence = ''
for j in range(size):
    for k in range(3):
        for i in range(random.randint(0,50)):
             sentence = random.choice(words) +" "+"seo"+" "+sentence
             i+=random.randint(0,10)
        k+=1
        if j in spam_bio_link:
            sentence = sentence + bio_url
    spam_bios[j]= sentence
    j+=1

len(spam_bios)
# Out:
# 1000

# %% [markdown]
# ### spam_areas dummy data generation code

# %%
spam_areas = [None] *size

# %%
spam_area_set = [random.randint(1,size-1) for i in range(0,int(size*0.0002))]
for i in spam_area_set:
    spam_areas[i] = "spam_area"

# %%
len(spam_areas)
# Out:
# 1000

# %% [markdown]
# ### spam_privs dummy data generation code

# %%
spam_privs = [0] * size

# %% [markdown]
# ### spam_genders dummy data generation code

# %%
spam_gender_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.3))]
spam_genders = ["gender"]*size
for i in spam_gender_not_set:
    spam_genders[i] = None

# %% [markdown]
# ### spam_birth_dates dummy data generation code

# %%
import datetime
import random
from datetime import timedelta

spam_birth_dates = []
spam_birthdates_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.4))]
earliest = datetime.datetime(1998, 1, 1, 2, 30, 27, 5)
latest  = datetime.datetime.now()  - timedelta(days=7000)
delta = latest - earliest
int_delta = (delta.days * 24 * 60 * 60) + delta.seconds    
for i in range(size):
    random_second = random.randrange(int_delta)
    random_date = earliest + datetime.timedelta(seconds = random_second)
    spam_birth_dates.append(random_date)   


for i in spam_birthdates_not_set:
    spam_birth_dates[i] = None
len(spam_birth_dates)
# Out:
# 1000

# %% [markdown]
# ### spam_member_since dummy data generation code

# %%
import datetime
import random
		
spam_member_since = []
earliest = datetime.datetime(2000, 1, 1, 2, 30, 27, 5)
latest  = datetime.datetime.now()
delta = latest - earliest
int_delta = (delta.days * 24 * 60 * 60) + delta.seconds    
for i in range(size):
    random_second = random.randrange(int_delta)
    random_date = earliest + datetime.timedelta(seconds = random_second)
    spam_member_since.append(random_date)    
    
len(spam_member_since)
# Out:
# 1000

# %% [markdown]
# ### spam_email_confirm_dates dummy data generation code

# %%
from datetime import timedelta

spam_email_confirm_dates = list()

spam_email_confirm_dates_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.1))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = spam_member_since[i] + random_lengths[i]
    spam_email_confirm_dates.append( temp)
spam_email_confirm_dates

for i in spam_email_confirm_dates_not_set:
    spam_email_confirm_dates[i] = None

# %% [markdown]
# ### spam_last_updated dummy data generation code

# %%
#spam_last_updated
spam_last_updated = list()

spam_last_updated_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.2))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = spam_member_since[i] + random_lengths[i]
    spam_last_updated.append( temp)


for i in spam_last_updated_not_set:
    spam_last_updated[i] = None

# %% [markdown]
# ### spam_last_login_dates dummy data generation code

# %%
spam_last_login_dates = list()

spam_last_login_dates_not_set = [random.randint(1,size-1) for i in range(0,int(size*0.2))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = spam_member_since[i] + random_lengths[i]
    spam_last_login_dates.append( temp)


for i in spam_last_login_dates_not_set:
    spam_last_login_dates[i] = None

# %% [markdown]
# ## Create pickle file from generated data

# %%
import pickle

# %%
spam_dummy_data = {}

# %%
for i in range(1,size):
    temp = {
        'email' : spam_emails[i],
        'website' : spam_websites[i],
        'bio' : spam_bios[i],
        'area' : spam_areas[i],
        'privs' : spam_privs[i],
        'gender' : spam_genders[i],
        'birth_date' : spam_birth_dates[i],
        'member_since' : spam_member_since[i],
        'email_confirm_date' : spam_email_confirm_dates[i],
        'last_updated' : spam_last_updated[i],
        'last_login_date' : spam_last_login_dates[i],
    }
    spam_dummy_data[i] = temp

# %%
with open('spam_editors_dummy_data.pickle', 'wb') as handle:
    pickle.dump(spam_dummy_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
