# %%
# importing necessary libraries 
import numpy as np
import random
import pandas as pd
from urllib.parse import urlparse
import datetime
import pickle

# %%
size = 1000

# %% [markdown]
# # Spam dummy data creation

# %%
domains_data =  pd.read_csv("domains_data.csv")

# %%
domains_data.columns
# Out:
# Index(['spam_emails', 'spam_website', 'nonspam_emails'], dtype='object')

# %% [markdown]
# ### spam_emails dummy data generation code

# %%
spam_emails_csv = list(domains_data['spam_emails'])
spam_emails_csv
# Out:
# ['knottyunificati44@mail.ru',
#  'barrettallenjutefy@continumail.com',
#  'geminiswan10tnqqcp@drupalmails.com',
#  'paulcomb36nlutgy@joomlaemails.com',
#  'iqtest@angrybirds2.pl',
#  'morrisdykoma@inemaling.com',
#  'feigneddispatch@cfphone.net',
#  'ipop23@gmx.com',
#  'juteepoxy40tusssg@mailclubs.info',
#  'shrimpwheel16vvnxhf@joomlaemails.com',
#  'zen@bolo.eu.org',
#  'randompolish06iiocyr@deepemailbox.com',
#  'astonishingutop@uminga.net',
#  'e_pydrina@mail.ru',
#  'jermainecoakleybww@yahoo.com',
#  'lushmovie99@devsapps.net',
#  'mercadomichael@grow-mail.com',
#  'august@allemaling.com',
#  's.a.n.a.kh.a.l.i.d.3.2.6@gmail.com',
#  'calvindonald1@mail.ru',
#  'sheepbath07dvrzbn@drupalmails.com',
#  'kristenaisha868@gmail.com',
#  'killinconc60@gmail.com',
#  'goldbill34cqagtr@wordpressmails.com',
#  'faucetbroker16zbhbjl@joomlaemails.com',
#  'spearsoap69lojgvq@justbigbox.com',
#  'uglydesperado46@ginxmail.com',
#  'brightfruit27@cfphone.net',
#  'changeableyacht@uminga.net',
#  'humdrumtimetabl@uminga.net',
#  'currenkarleenpoxyji@kodmailing.com',
#  'grillrouter90nefkbh@wordpressmails.com',
#  'jerryjfoster@outlook.com',
#  'bungeegum@nomail.ga',
#  'locusjawise18@mail.ru',
#  'unsuitabledeity@devsapps.net',
#  'stickcut74oawxji@joomlaemails.com',
#  'mccrawanna743@mabermail.com',
#  'barcodescanner1@mail.ru',
#  'walletvalley32crdnba@joomlaemails.com',
#  'calh653684@gmail.com',
#  'cheaphosting007@trango.co',
#  'nestsound72qwasal@joomlaemails.com',
#  'moneypatch44jguvrn@joomlaemails.com',
#  'baityjose@visitinbox.com',
#  'zeniaheidrickjuy@yahoo.com',
#  'cadydbhxugaq@outlook.com',
#  'burkettchastity@yahoo.com',
#  'cityswitch94fliuna@joomlaemails.com',
#  'dryervent2@hotmail.com',
#  'cerealquill18rmwigr@hypermailbox.com',
#  'needbrazil37dlbesh@drupalmails.com',
#  'thingtights87cyvfhv@drupalmails.com',
#  'designpoet70rksjfc@wordpressmails.com',
#  'soillan46imrijl@joomlaemails.com',
#  'ira.1988.33@mail.ru',
#  'cupslash46wiuksf@drupalmails.com',
#  'jcapps57@webgarden.com',
#  'mosquewaste56moimwe@joomlaemails.com',
#  'nydiacargillqqgz@yahoo.com',
#  'jurysharon36dolfht@joomlaemails.com',
#  'manfred.bardola1990@o2.pl',
#  'bonsaibakery24icmwcy@abrighterfutureday.com',
#  'crowncloth35dzhyxx@wordpressmails.com',
#  'planetlilac13covkta@hotspotmails.com',
#  'duran243@out-email.com',
#  'moleshape16qgxgtt@joomlaemails.com',
#  'violinyam75wflgog@joomlaemails.com',
#  'morugandawson@gmail.com',
#  'plainbutton27gyubnt@joomlaemails.com',
#  'shedramati.3n51uh1@gmail.com',
#  'lundebycarolyne1011@digiuoso.com',
#  'carolyneparenteaupcn@yahoo.com',
#  'carolyne.suarezrpil@yahoo.com',
#  'carolynetruppuqmn@yahoo.com',
#  'asiavansumerenqmu@yahoo.com',
#  'davidscott@mabermail.com',
#  'motley@continumail.com',
#  'curveguilty16qosnkv@singtelmails.com',
#  'tacitenthusiast@devsapps.net',
#  'prosetuna73oykbir@joomlaemails.com',
#  'peppercrime73viqkkb@hypermailbox.com',
#  'beliefpasta40dpskvl@ibmmails.com',
#  'metalcondor47kzsfgr@abrighterfutureday.com',
#  'zinaida1hk2ge@mail.ru',
#  'summerlycra52wrfpnh@wordpressmails.com',
#  'poetactive51uofhle@joomlaemails.com',
#  'peacegray34fjmsqe@joomlaemails.com',
#  'birthclick01onaigf@ibmmails.com',
#  '2561peggyfowler@sobeessentialenergy.com',
#  'activebow41dnwyez@drupalmails.com',
#  'sternertujado@checknowmail.com',
#  'tennisburn14hgnuxe@temasekmail.com',
#  'choate654@consimail.com',
#  'babieswash98meewnk@joomlaemails.com',
#  'horaciomartin4020@buysteroids365.com',
#  'blackwoodsxashleaep@rediffmail.com',
#  'ilonafriedxbh@yahoo.com',
#  'elizebethpullemgrse@yahoo.com',
#  'oakoutput78uqttyh@abrighterfutureday.com',
#  'krasnozhon.lida@mail.ru',
#  'pimplemale16amvqwv@joomlaemails.com',
#  'gunpajama56wmoirc@drupalmails.com',
#  'bageljeff07mcxasv@abrighterfutureday.com',
#  'fangd467@gmail.com',
#  'shivanidhankhar7@gmail.com',
#  'quickbookenterprise@rediffmail.com',
#  'quickbooktraining92@outlook.com',
#  'gray70birchwpjcmm@intervisionplc.com',
#  'rogerstrichellkqn@yahoo.com',
#  'malvaforney1618@yahoo.com',
#  'spearsoap69lojgvq@justbigbox.com',
#  'sexmaple57hpukhg@justbigbox.com',
#  'duvallbeatrice@continumail.com',
#  'crowdjaw68oxrnbp@joomlaemails.com',
#  'turkeyfish16lituva@abrighterfutureday.com',
#  'artsquid15hxyvty@mailclubs.info',
#  'dollarbreak82yutbtj@joomlaemails.com',
#  'roaddate25nnnvok@joomlaemails.com',
#  'rumseyqimony@out-email.com',
#  'e_ushankina@mail.ru',
#  'oliverhilds@faithmail.org',
#  'willardledfod@faithmail.org',
#  'charfili30@gmail.com',
#  'fgklghbjjofghjflkj8487t5@gmail.com',
#  'moonakondo03@gmail.com',
#  '199creative.com@gmail.com',
#  'e9b2ee02@opayq.com',
#  'zitakim55@gmail.com',
#  'mohamedelareef1992@gmail.com',
#  'plolongnol3@gmail.com',
#  'chairbugle19lwissx@babymails.com',
#  'creamsingle78hvezyi@joomlaemails.com',
#  'fababetac@p33.org',
#  'comment9@freefileserver.com',
#  'priyayseo@gmail.com',
#  'h.neverus2@gmail.com',
#  'febrianisinta.fpr@gmail.com',
#  'sophieandrews803@gmail.com',
#  'randomdalban05@gmail.com',
#  'wekaari8899@gmail.com',
#  'ushehab51@gmail.com',
#  'alexasmith078@gmail.com',
#  'aryssetyawan27@gmail.com',
#  'mrsureprime@gmail.com',
#  '3657harrybarnette@thiet-ke-web.org',
#  'invhome12@gmail.com',
#  'professionalseo2008@gmail.com',
#  'rickpdomas@gmail.com',
#  'kasperskyantivirushelpdesk@gmail.com',
#  'omathewjohn@gmail.com',
#  'zahop@matchpol.net',
#  'admin@motorcyclebd.com',
#  'janeearora1992@gmail.com',
#  'anand.vihari222@gmail.com',
#  'wikarocezo@haydoo.com',
#  'himelpain24@gmail.com',
#  'priciljong@gmail.com',
#  'bethmichelle@matchpol.net',
#  'kathleenwarrencj@gmail.com',
#  'bi-sa.sa2017@yandex.com',
#  'chillmill71@gmail.com',
#  'cs.ibet57@gmail.com',
#  'mycadhome07@gmail.com',
#  'qbnumberus@gmail.com',
#  'jualanstorecom@gmail.com',
#  'farid404x@gmail.com',
#  'bupluhsn@gmail.com',
#  'webmaster@designawebsite.in',
#  'info@shopsousvide.com',
#  'nationalchiropractor+4@gmail.com',
#  'mohamed.shaaban0146@gmail.com',
#  'tvskyflixs@pokemail.net',
#  'skyflixs@pokemail.net',
#  'patwetzel92@gmail.com',
#  'gethighdaily111@gmail.com',
#  'seanpsion@mail.com',
#  'haoseo@yostyle.com.vn',
#  'thongtinveduhocduc@gmail.com',
#  'chamsocsacdeponline6@gmail.com',
#  '9gio32@gmail.com',
#  'giaytaynam2@gmail.com',
#  'giaytaynam123@gmail.com',
#  'nothin2505@gmail.com',
#  'angela_thuy@yahoo.com.vn',
#  'dongphucthienphuoc@gmail.com',
#  'sieumuanhanh1@gmail.com',
#  'lyndameltons@gmail.com',
#  'highmedstore@gmail.com',
#  'luyenthitienghan123@gmail.com',
#  'latulaskittwdtl@hotmail.com',
#  'chawlashilpi123@gmail.com',
#  'edensahkrpne@hotmail.com',
#  'arifboss439@gmail.com',
#  'hossiwlggali@hotmail.com',
#  'titlysarker102@gmail.com',
#  'aanik1012@gmail.com',
#  'zpkfbkstp@pullmail.info',
#  'vhevhjjdy@pullmail.info',
#  'fannie@sinemailing.com',
#  'clarabdias@outlook.com',
#  'pilatesbh@teimur.com',
#  'clarabowen970@allemaling.com',
#  'rnufxojk@gmail4u.eu',
#  'admin@hand-painted-scarves.eu',
#  '1490clarabartel@chemeng-masdar.com',
#  'brxjazmnpqy@hotmail.com',
#  'somakatun4587@gmail.com',
#  'sdtfghjmjklio@gmail.com',
#  'cfpchampionship17@gmail.com',
#  'liveto9@yandex.com',
#  'juyjty@gmail.com',
#  'jamesabauera@outlook.com',
#  'carolsclarka@outlook.com',
#  'andreadgraham@outlook.com',
#  'fifa18cheatshack@yahoo.com',
#  'josbuttlerharper@yahoo.com',
#  'no_one098@outlook.com',
#  'emilydmelo@outlook.com',
#  'threadplough07ipdzth@babymails.com',
#  'receptivedog9565@trango.co',
#  'receptivedynamo@trango.co',
#  'receptivedoctri06@trango.co',
#  'detailactive43pgpnuc@babymails.com',
#  'oksana.baturskaya@mail.ru',
#  'lacepickle57yyvkye@joomlaemails.com',
#  'hofabi@porsh.net',
#  'helenggardner@mail.com',
#  'fourbyfitouts1@gmail.com',
#  'cy20170805@gmail.com',
#  'agency2018@yandex.com',
#  'clancy201@mabermail.com',
#  'platenancy20lyjqis@intervisionplc.com',
#  'popovnin.yaroslav@mail.ru',
#  'oddershedeclancy20vnesfn@babymails.com',
#  'theseoagency2017@gmail.com',
#  'utopianlegacy20@devsapps.net',
#  'janetxdiaz@outlook.com',
#  'dolloffjanetxijumo@sin-mailing.com',
#  'cookjohan@outlook.com',
#  'zonejumbo87ogyelf@intervisionplc.com',
#  'lyrebetty41emdiwl@intervisionplc.com',
#  'gaylecookjonoky@brmailing.com',
#  'cookjohn471@kod-maling.com',
#  'cookjumper01pzagwy@babymails.com',
#  'cookjeans28jcytny@drupalmails.com',
#  'bablin@jourrapide.com',
#  'barbarassmith11@mail.com',
#  'glassmilk37wzgndn@drupalmails.com',
#  'grassmind28rybwcs@joomlaemails.com',
#  'pandaalto24cqfcsv@babymails.com',
#  'robertjones4153@businesstutorialsonline.org',
#  'paulariggs541@financehowtolearn.com',
#  '3538lonniearmstrong@researchobservatories.org.uk',
#  '7658marvinrock@businesshowtomakemoney.com',
#  'bulltent16nteysc@babymails.com',
#  'bulltent16nteysc@babymails.com',
#  'helmetfield55dczpam@joomlaemails.com',
#  'kirkpatrickcurrin35kvvqoz@babymails.com',
#  'christopher.sexton@yourmailbox.co',
#  'innatewhiz1@trango.co',
#  'makeupgrip59xorwnb@justbigbox.com',
#  'aa59@baseblogger.com',
#  'velazquezjoyce64cwnxuf@babymails.com',
#  'handsomecard56@padita.net',
#  'mrignayanikolkatashowroom@gmail.com',
#  'forkmonth54dfcbeg@babymails.com',
#  'danielarmstrong1497@topbuysteroids365.com',
#  'mimosamotion58xmhpgk@justbigbox.com',
#  'clarahunt91@gmail.com',
#  'jumanawilly@gmail.com',
#  'adamcrispin843@gmail.com',
#  'stephendevasya94@gmail.com',
#  '5975a3a66ed3a@mailbox92.biz',
#  '597750366c880@mailbox92.biz',
#  'rotuva@binnary.com',
#  'tajhorton@mail.com',
#  'valeriefpedrick@outlook.com',
#  'valerieford2@mail.ru',
#  'jonenkong@mail.com',
#  'marycbatson@outlook.com',
#  'jonnyhopes@outlook.com',
#  'ottohandal@mail.com',
#  'susandcook@outlook.com',
#  'henzlouip@outlook.com',
#  'irmaapeterson@mail.com',
#  'audraobalch@outlook.com',
#  'jackielwitt@mail.com',
#  'tendonfault@interia.pl',
#  'leighdnapper@outlook.com',
#  'sanderfrandsen@mail.com',
#  'joepflores@yopmail.com',
#  'louisjenem@mail.com',
#  'luibulks@outlook.com',
#  'hopepglaser@outlook.com',
#  'lauratbagwell@outlook.com',
#  'pameladgrant2@outlook.com',
#  'socksyrup99lqdhxt@intervisionplc.com',
#  'ahliqqnety@gmail.com',
#  'revenzeress@outlook.com',
#  'mbavalencia@hotmail.com',
#  'robbiewolf76@gmail.com',
#  'pacoxdeluna@gmail.com',
#  'herbalsejagat99@gmail.com',
#  'penthousedigital.co.uk@gmail.com',
#  'gnanasekar.6914@gmail.com',
#  'ahlicasino366@gmail.com',
#  'fullerdorothyj@gmail.com',
#  'bisapasti001@gmail.com',
#  'emmawilliamsvmak@gmail.com',
#  'adf98cb3@mozej.com',
#  'jogakhichuri30@gmail.com',
#  'divya35mehra@gmail.com',
#  'glxmcnfwkd32@gmail.com',
#  'approveloannow4@gmail.com',
#  'nativespellcaster@gmail.com',
#  'levihuongxuan@gmail.com',
#  'burnsubway56yysqlv@babymails.com',
#  'basketlunch00hoboiv@joomlaemails.com',
#  'apkdownload9108@lexxip.com',
#  'zombocalypse67@lexxip.com',
#  'alexandercginther02@protonmail.com',
#  'shadanigroup01@gmail.com',
#  'arijahari98@gmail.com',
#  'vipoku3@gmail.com',
#  'chudesuckhoe@gmail.com',
#  'angelinajohn9182@yahoo.com',
#  'shardagroup001@gmail.com',
#  'rawatsakshi289@gmail.com',
#  'conductexam.seo@gmail.com',
#  'alexson0126@gmail.com',
#  'meripyaribin.du0001@gmail.com',
#  'sosyal@teknokenar.com',
#  'nokiaemars@gmail.com',
#  'anikakmi47@gmail.com',
#  'markjohnn09@gmail.com',
#  'krishnakanth8796@gmail.com',
#  'angusa728@gmail.com',
#  'jack885256@gmail.com',
#  'laceymarkgeek@gmail.com',
#  'jonesgeek90@gmail.com',
#  'agarwalcartransport123@gmail.com',
#  'honeybella12@yopmail.com',
#  'happykelli15@yopmail.com',
#  'hotgoodsonsale@gmail.com',
#  'rappuxollyx-6168@yopmail.com',
#  'info.veintecmx@gmail.com',
#  'ixuhaffinn-6282@yopmail.com',
#  'shadanigroup01@gmail.com',
#  '800tollfreenumber3@gmail.com',
#  'smithdavid18299@gmail.com',
#  'awesomeeagler@gmail.com',
#  'amywatson490@gmail.com',
#  'jamesrhodetube@gmail.com',
#  'neilbhisma2671@gmail.com',
#  'camera247num@gmail.com',
#  'aaronruslee@gmail.com',
#  'jonnyjain820@gmail.com',
#  'masin83c@yahoo.com',
#  'wrewrewwrwrwr@gmail.com',
#  'meansakti@gmail.com',
#  'caodangsaigon.tphcm@gmail.com',
#  'lalitjain13923@gmail.com',
#  'shyamsingh18594@gmail.com',
#  'rani4567501@gmail.com',
#  'ahkhan@externetworks.com',
#  'yunmin1983ce@yahoo.com',
#  'ashaikfe@gmail.com',
#  'qizhenzln@gmail.com',
#  'nikithavalepu@gmail.com',
#  'nujuya@cliptik.net',
#  'christopherhobbs01@outlook.com',
#  'colinkroll@cliptik.net',
#  'paredesmusik@gmail.com',
#  'abc@intervisionplc.com',
#  'abc@lexxip.com',
#  'abc@joomlaemails.com',
#  'abc@babymails.com',
#  'abc@freemailhosts.com',
#  'abc@lovelymail.info',
#  'abc@kingdomheartmail.com',
#  'abc@wordpressmails.com',
#  'abc@abrighterfutureday.com',
#  'abc@hubspotmails.com',
#  'abc@trango.co',
#  'abc@devsapps.net',
#  'abc@businesskontakts.com',
#  'abc@drupalmails.com',
#  'abc@webgarden.com',
#  'abc@ibmmails.com',
#  'abc@hotspotmails.com',
#  'abc@cfphone.net',
#  'abc@queenofsite.online',
#  'abc@uminga.net',
#  'abc@singtelmails.com',
#  'abc@temasekmail.com',
#  'abc@hypermailbox.com',
#  'abc@gloriousfuturedays.com',
#  'abc@kingofplace.site',
#  'abc@1st-apparelsoftware.info',
#  'abc@padita.net',
#  'abc@deepemailbox.com',
#  'abc@lolas3.seo-linuxpl.com',
#  'abc@justbigbox.com',
#  'abc@dupontmails.com',
#  'abc@techspotny.com',
#  'abc@novartismails.com',
#  'abc@efacs.net',
#  'abc@anseohero.com']

# %%
spam_email_domains = {email.split("@")[1] for email in spam_emails_csv}
spam_email_domains = list(spam_email_domains)

# %%
spam_emails = list()
domains = list(spam_email_domains)
letters = ["a", "b", "c", "d","e", "f", "g", "h", "i", "j", "k", "l"]

def get_one_random_domain(domains):
        return domains[random.randint( 0, len(domains)-1)]


def get_one_random_name(letters):
    email_name = ""
    for i in range(7):
        email_name = email_name + letters[random.randint(0,11)]
    return email_name

def generate_random_emails(size):
    for i in range(0,size):
         one_name = str(get_one_random_name(letters))
         one_domain = str(get_one_random_domain(domains))  
         mail = one_name+'@'+one_domain
         spam_emails.append(mail)
generate_random_emails(size)

# %%
spam_emails
# Out:
# ['eikacca@inemaling.com',
#  'gcejakl@cliptik.net',
#  'ilkiali@deepemailbox.com',
#  'keahefc@devsapps.net',
#  'igekbei@inemaling.com',
#  'hjhekgj@pokemail.net',
#  'hckhbbe@trango.co',
#  'aakdfcj@sinemailing.com',
#  'cbkiggf@porsh.net',
#  'ghieaba@teknokenar.com',
#  'jdfdbaf@yandex.com',
#  'dfblchk@hotmail.com',
#  'ehlajad@kod-maling.com',
#  'bckljaf@yandex.com',
#  'hhagkia@cfphone.net',
#  'bgebhkd@interia.pl',
#  'gbcbiak@sobeessentialenergy.com',
#  'kdjdkif@faithmail.org',
#  'hidagba@hotmail.com',
#  'kkafgga@visitinbox.com',
#  'agjdfej@freefileserver.com',
#  'ebkjhij@mabermail.com',
#  'bajfefi@nomail.ga',
#  'khhfbjb@babymails.com',
#  'ibhdbah@teknokenar.com',
#  'hkkhlii@mail.ru',
#  'blbkkkk@thiet-ke-web.org',
#  'jhdlgba@matchpol.net',
#  'ehfgceg@interia.pl',
#  'ifaghij@padita.net',
#  'egiehhb@sin-mailing.com',
#  'cjkghed@teimur.com',
#  'ghddehh@hotspotmails.com',
#  'blbegel@gloriousfuturedays.com',
#  'iiajjdj@mabermail.com',
#  'lgcjhci@p33.org',
#  'bjcglij@padita.net',
#  'geckegb@pokemail.net',
#  'ablhkbb@queenofsite.online',
#  'gigajhi@lexxip.com',
#  'jgchdic@pullmail.info',
#  'fglklcg@shopsousvide.com',
#  'dfelhfk@yahoo.com',
#  'fheecgh@pokemail.net',
#  'bjlkhcf@haydoo.com',
#  'khidffi@visitinbox.com',
#  'llehakg@buysteroids365.com',
#  'hahalic@temasekmail.com',
#  'jcjkkgk@baseblogger.com',
#  'kkhkjcj@kodmailing.com',
#  'kbgegla@yourmailbox.co',
#  'lkdejfl@hotspotmails.com',
#  'bbahbgd@yahoo.com.vn',
#  'hklhlhi@anseohero.com',
#  'hicdlll@ginxmail.com',
#  'fjlchac@businesskontakts.com',
#  'hjbdbdb@babymails.com',
#  'dbgfbdk@externetworks.com',
#  'gfeehfd@porsh.net',
#  'gachjlg@gmail4u.eu',
#  'dljgidj@lexxip.com',
#  'chijfdf@chemeng-masdar.com',
#  'jakggic@hubspotmails.com',
#  'llcgghl@hypermailbox.com',
#  'fhgklge@buysteroids365.com',
#  'fglejkg@1st-apparelsoftware.info',
#  'aikebei@wordpressmails.com',
#  'dhbjkjh@teimur.com',
#  'kdacccl@anseohero.com',
#  'diakcge@deepemailbox.com',
#  'afjkfid@chemeng-masdar.com',
#  'ildcaeb@sobeessentialenergy.com',
#  'chlaibc@grow-mail.com',
#  'hdhakll@shopsousvide.com',
#  'dlbggkf@mabermail.com',
#  'jhibfcf@wordpressmails.com',
#  'bbhcbdh@out-email.com',
#  'gccdgkc@freefileserver.com',
#  'chiahkk@checknowmail.com',
#  'hifcjad@wordpressmails.com',
#  'bfkblfg@hypermailbox.com',
#  'cadgehj@porsh.net',
#  'cakifgk@porsh.net',
#  'belgbff@trango.co',
#  'cbjblda@financehowtolearn.com',
#  'lgficlg@temasekmail.com',
#  'aibhjgf@rediffmail.com',
#  'kfgebeg@mail.com',
#  'acbgffe@lovelymail.info',
#  'cbiijlf@interia.pl',
#  'ljbbkcd@mailbox92.biz',
#  'jddlakl@singtelmails.com',
#  'dbbggkj@cfphone.net',
#  'diddiil@businesstutorialsonline.org',
#  'lajable@haydoo.com',
#  'hagicbc@kodmailing.com',
#  'agjdfka@angrybirds2.pl',
#  'jghehdg@kingdomheartmail.com',
#  'kbbajbl@opayq.com',
#  'aedcdbf@teimur.com',
#  'cgaikfc@businesskontakts.com',
#  'cbjbbjb@brmailing.com',
#  'gbfalcb@mail.ru',
#  'fleefkb@p33.org',
#  'dedllbd@continumail.com',
#  'bgfdgej@1st-apparelsoftware.info',
#  'chaafkf@lovelymail.info',
#  'ahdaddg@freefileserver.com',
#  'dececlc@buysteroids365.com',
#  'fkclhbi@porsh.net',
#  'eleeale@webgarden.com',
#  'feheibi@lovelymail.info',
#  'jkhlkkd@digiuoso.com',
#  'clkkgda@shopsousvide.com',
#  'flljkil@angrybirds2.pl',
#  'klhjedl@digiuoso.com',
#  'akgibij@protonmail.com',
#  'hjbibbl@sinemailing.com',
#  'ibcfkhd@binnary.com',
#  'igbiddh@teknokenar.com',
#  'jejfkec@wordpressmails.com',
#  'cfhajjh@gloriousfuturedays.com',
#  'bgdgald@mabermail.com',
#  'eijcjjh@novartismails.com',
#  'gbegeak@teimur.com',
#  'kilachi@inemaling.com',
#  'jligegk@chemeng-masdar.com',
#  'eadcidf@motorcyclebd.com',
#  'cjbbdag@consimail.com',
#  'jgifiab@trango.co',
#  'hhcghge@buysteroids365.com',
#  'cfgjbfi@deepemailbox.com',
#  'diighje@p33.org',
#  'blbided@yandex.com',
#  'fhkdcjc@deepemailbox.com',
#  'hflhecg@thiet-ke-web.org',
#  'ighihih@yostyle.com.vn',
#  'dlaihbb@gmail.com',
#  'ifhbelk@interia.pl',
#  'djgaghj@designawebsite.in',
#  'iddgeik@joomlaemails.com',
#  'hjghjcf@yostyle.com.vn',
#  'bfchddi@grow-mail.com',
#  'gbjdhlg@1st-apparelsoftware.info',
#  'aebbifb@cliptik.net',
#  'hhfablc@padita.net',
#  'gdifhjc@trango.co',
#  'klhgffa@teknokenar.com',
#  'cfcidge@ibmmails.com',
#  'ejfkill@freemailhosts.com',
#  'fbkflki@mailbox92.biz',
#  'dfabaej@consimail.com',
#  'lababei@binnary.com',
#  'bgebddl@kingofplace.site',
#  'achagae@sinemailing.com',
#  'laibgbe@digiuoso.com',
#  'ahghaaa@o2.pl',
#  'hfbehlj@dupontmails.com',
#  'dafagcl@intervisionplc.com',
#  'bakjdfh@drupalmails.com',
#  'fdbbbjl@hand-painted-scarves.eu',
#  'ddhlajh@businesstutorialsonline.org',
#  'daaicaf@efacs.net',
#  'cchdbhh@opayq.com',
#  'blihkjf@kodmailing.com',
#  'iekflaf@abrighterfutureday.com',
#  'echbbke@yahoo.com.vn',
#  'gidebgd@drupalmails.com',
#  'lagilgl@businesskontakts.com',
#  'glcfjch@rediffmail.com',
#  'cjfjlkj@angrybirds2.pl',
#  'kiaehbl@checknowmail.com',
#  'ffijkbc@cliptik.net',
#  'jkhaeic@queenofsite.online',
#  'halkfid@pokemail.net',
#  'lgkhibe@cliptik.net',
#  'hkafllc@o2.pl',
#  'aakdfdd@kingofplace.site',
#  'acdjcgh@businesstutorialsonline.org',
#  'ibafcdk@yourmailbox.co',
#  'aldfbkc@singtelmails.com',
#  'blecdde@researchobservatories.org.uk',
#  'fjcekki@1st-apparelsoftware.info',
#  'efdcflg@sobeessentialenergy.com',
#  'fklhhfj@yahoo.com.vn',
#  'fhfgkid@devsapps.net',
#  'khedjda@chemeng-masdar.com',
#  'ddhelcc@hotspotmails.com',
#  'dcfgkdh@outlook.com',
#  'aegjdek@inemaling.com',
#  'eaiijcc@rediffmail.com',
#  'kiklhce@gmail.com',
#  'iddfigh@checknowmail.com',
#  'gehgkef@continumail.com',
#  'dlkadkf@rediffmail.com',
#  'ehjchbd@out-email.com',
#  'chabkhe@mail.com',
#  'gflilad@efacs.net',
#  'ccbchaa@continumail.com',
#  'akfbjbh@ginxmail.com',
#  'icgaljb@businesstutorialsonline.org',
#  'cjeiael@kod-maling.com',
#  'ijeghgb@queenofsite.online',
#  'hfckgfl@queenofsite.online',
#  'akadlbj@opayq.com',
#  'dljbbdf@devsapps.net',
#  'jeaibab@lovelymail.info',
#  'khbdllk@designawebsite.in',
#  'blfffcl@allemaling.com',
#  'kidclie@kodmailing.com',
#  'elaeece@yourmailbox.co',
#  'fflaigl@opayq.com',
#  'jeglgag@cliptik.net',
#  'bdijjlh@mailbox92.biz',
#  'ieffbhj@trango.co',
#  'dcghbhc@justbigbox.com',
#  'kedgdak@mail.com',
#  'gabgbil@deepemailbox.com',
#  'dckdffj@inemaling.com',
#  'dcbckhd@angrybirds2.pl',
#  'klikabb@pullmail.info',
#  'cbjlcie@sinemailing.com',
#  'beffkee@sin-mailing.com',
#  'hfajghb@lexxip.com',
#  'lhagbih@faithmail.org',
#  'jfakgcg@ibmmails.com',
#  'lgbkgab@gmail4u.eu',
#  'gikflgj@padita.net',
#  'celhcbg@checknowmail.com',
#  'eidecli@wordpressmails.com',
#  'egeklle@intervisionplc.com',
#  'ljjcbcb@binnary.com',
#  'iacbegg@lolas3.seo-linuxpl.com',
#  'bdaehab@faithmail.org',
#  'lhgbcbj@pokemail.net',
#  'ghcfiil@1st-apparelsoftware.info',
#  'lhbcfif@angrybirds2.pl',
#  'acfilei@bolo.eu.org',
#  'cibfiae@freefileserver.com',
#  'lighahj@lovelymail.info',
#  'ackkbii@businesstutorialsonline.org',
#  'kaleabl@cliptik.net',
#  'lcbdaii@novartismails.com',
#  'gfjhjcj@pullmail.info',
#  'ahbbebk@pokemail.net',
#  'achfbgl@yahoo.com.vn',
#  'bdgchik@p33.org',
#  'hdfgakg@yahoo.com.vn',
#  'agkejjd@joomlaemails.com',
#  'jklhcjg@deepemailbox.com',
#  'klfljbg@lexxip.com',
#  'jccjkjk@queenofsite.online',
#  'giajaeb@interia.pl',
#  'khbbbeh@lexxip.com',
#  'chbaefc@sin-mailing.com',
#  'faljflc@sinemailing.com',
#  'lddccic@kodmailing.com',
#  'keacace@baseblogger.com',
#  'heiijja@novartismails.com',
#  'deagljc@grow-mail.com',
#  'ccalbia@novartismails.com',
#  'khalijb@mabermail.com',
#  'iedkgib@mail.com',
#  'gihhgde@designawebsite.in',
#  'jcehdjk@matchpol.net',
#  'glkhckh@kod-maling.com',
#  'ehlijch@businesshowtomakemoney.com',
#  'egeehek@gloriousfuturedays.com',
#  'hghhfgk@padita.net',
#  'edfghld@devsapps.net',
#  'dalikab@cfphone.net',
#  'hiibhch@kingofplace.site',
#  'ebifiea@mailbox92.biz',
#  'ilfbifi@consimail.com',
#  'kfheljl@kod-maling.com',
#  'bkjhfdd@businesstutorialsonline.org',
#  'ilhjlgd@padita.net',
#  'jelhgcj@mail.ru',
#  'fhlclgg@mailclubs.info',
#  'ggefjbk@haydoo.com',
#  'bialhkj@dupontmails.com',
#  'igajblb@financehowtolearn.com',
#  'icdfgdb@yahoo.com',
#  'ljjdjfa@checknowmail.com',
#  'djehlll@matchpol.net',
#  'cfdecii@ginxmail.com',
#  'afjbcie@researchobservatories.org.uk',
#  'ikdlhji@mabermail.com',
#  'ieebkgh@externetworks.com',
#  'claechh@mail.ru',
#  'adcgkjg@yahoo.com.vn',
#  'igkedfj@temasekmail.com',
#  'gfhkgih@dupontmails.com',
#  'bfbeadl@ibmmails.com',
#  'klbdghc@gloriousfuturedays.com',
#  'fialdbb@cliptik.net',
#  'ccjcglh@teknokenar.com',
#  'ijcljif@1st-apparelsoftware.info',
#  'jbbakdd@justbigbox.com',
#  'dihcaea@cfphone.net',
#  'hbideag@wordpressmails.com',
#  'afckiie@continumail.com',
#  'bddjakb@checknowmail.com',
#  'alcciij@sin-mailing.com',
#  'fhigdgd@ginxmail.com',
#  'kbkejdf@trango.co',
#  'lbllclb@bolo.eu.org',
#  'chgkcic@ginxmail.com',
#  'ihjflfj@chemeng-masdar.com',
#  'ikidcgj@yandex.com',
#  'kklfcib@mabermail.com',
#  'akgjjfg@checknowmail.com',
#  'bfdikff@businesskontakts.com',
#  'gidelhh@abrighterfutureday.com',
#  'bkhhbeh@shopsousvide.com',
#  'abgkcjf@binnary.com',
#  'cechhlj@sinemailing.com',
#  'fbddaee@anseohero.com',
#  'edaihdh@hand-painted-scarves.eu',
#  'kclfijj@matchpol.net',
#  'jglalda@sinemailing.com',
#  'jkdifib@baseblogger.com',
#  'liblgel@anseohero.com',
#  'gjalikh@sin-mailing.com',
#  'cbclgee@mabermail.com',
#  'hfgkhei@justbigbox.com',
#  'fikalcb@sinemailing.com',
#  'afhagjf@p33.org',
#  'gfjldeg@trango.co',
#  'eadaldb@techspotny.com',
#  'cdiaghd@anseohero.com',
#  'bcdehjf@rediffmail.com',
#  'fldcklf@devsapps.net',
#  'bbbgcfk@gloriousfuturedays.com',
#  'echjibb@hotspotmails.com',
#  'ledhckc@continumail.com',
#  'ecjkdee@deepemailbox.com',
#  'egiaeff@shopsousvide.com',
#  'ifbdkjc@ibmmails.com',
#  'kbkelgf@digiuoso.com',
#  'egeahjg@techspotny.com',
#  'ecjaiei@yopmail.com',
#  'khegklg@freefileserver.com',
#  'bchfjle@opayq.com',
#  'hglhcjg@webgarden.com',
#  'lgfjela@outlook.com',
#  'gckfhde@yahoo.com.vn',
#  'ffibejk@nomail.ga',
#  'caeegbb@out-email.com',
#  'bigjhdd@sobeessentialenergy.com',
#  'lhcldge@cliptik.net',
#  'bhjfgle@kodmailing.com',
#  'kfjlbkb@devsapps.net',
#  'kgkjiki@opayq.com',
#  'ecljfha@mozej.com',
#  'eejclah@sin-mailing.com',
#  'ieailib@abrighterfutureday.com',
#  'jlfldfj@faithmail.org',
#  'blaecae@binnary.com',
#  'jgabccl@cfphone.net',
#  'ajleieg@teknokenar.com',
#  'eibeggi@businesshowtomakemoney.com',
#  'hffcefd@businesskontakts.com',
#  'daileki@brmailing.com',
#  'aghefjl@novartismails.com',
#  'ibakheg@outlook.com',
#  'djjfagh@hotspotmails.com',
#  'khchefd@jourrapide.com',
#  'kdchbch@p33.org',
#  'jcbeicl@webgarden.com',
#  'bhjaaje@thiet-ke-web.org',
#  'ijlgjhe@lovelymail.info',
#  'ccfbiai@padita.net',
#  'glhdfjg@visitinbox.com',
#  'bhilecg@pullmail.info',
#  'bfhiedc@out-email.com',
#  'gjhckdh@buysteroids365.com',
#  'acidghf@intervisionplc.com',
#  'gckcela@mailclubs.info',
#  'iljgbac@yahoo.com.vn',
#  'affgedd@lexxip.com',
#  'fiakghi@sinemailing.com',
#  'bgccbga@opayq.com',
#  'lckchih@opayq.com',
#  'flhidfd@jourrapide.com',
#  'difgjbg@yandex.com',
#  'dekflje@ibmmails.com',
#  'blaaglk@interia.pl',
#  'gdalegk@anseohero.com',
#  'eaachcc@singtelmails.com',
#  'jladbge@babymails.com',
#  'kadhlag@mabermail.com',
#  'cidghab@hubspotmails.com',
#  'gliigij@out-email.com',
#  'lhdigfc@intervisionplc.com',
#  'gdckiek@visitinbox.com',
#  'eacfefk@mozej.com',
#  'hgkjflk@efacs.net',
#  'kkfhlkb@designawebsite.in',
#  'hhjbfbh@mail.com',
#  'clffjje@lexxip.com',
#  'cbalcei@yahoo.com.vn',
#  'bdkjijg@anseohero.com',
#  'fakgglj@gloriousfuturedays.com',
#  'ealbcda@researchobservatories.org.uk',
#  'ldfdagj@gmail4u.eu',
#  'hjibgal@devsapps.net',
#  'flicbdd@efacs.net',
#  'aelglci@binnary.com',
#  'hilcchd@kod-maling.com',
#  'daffcfh@novartismails.com',
#  'ddfbcfk@mailbox92.biz',
#  'lbibfdb@padita.net',
#  'ckdjefh@intervisionplc.com',
#  'dcbbfdf@ginxmail.com',
#  'gdegbha@abrighterfutureday.com',
#  'khjaceb@lolas3.seo-linuxpl.com',
#  'acfkaga@temasekmail.com',
#  'abkahdk@freefileserver.com',
#  'feejllf@hand-painted-scarves.eu',
#  'laefhbd@mailbox92.biz',
#  'gcdlibj@shopsousvide.com',
#  'blckeci@externetworks.com',
#  'dfhkhca@p33.org',
#  'hbciejh@teknokenar.com',
#  'hhahaea@1st-apparelsoftware.info',
#  'gfkgied@anseohero.com',
#  'bhdelde@freefileserver.com',
#  'jjihjag@jourrapide.com',
#  'hcjjldi@mailbox92.biz',
#  'ecgiied@teimur.com',
#  'bhefkfd@kingofplace.site',
#  'eaifela@continumail.com',
#  'gleefhc@gloriousfuturedays.com',
#  'hefbglj@ibmmails.com',
#  'akkdaad@mozej.com',
#  'cjfidhj@trango.co',
#  'fbejlei@lolas3.seo-linuxpl.com',
#  'dglkicb@kingofplace.site',
#  'llhbejf@angrybirds2.pl',
#  'cggfgbg@gmx.com',
#  'iffagec@teimur.com',
#  'eecdfdi@continumail.com',
#  'jadgcfa@efacs.net',
#  'abgblkj@interia.pl',
#  'lgehbjk@bolo.eu.org',
#  'bacjkhg@mozej.com',
#  'dlaalbc@kingdomheartmail.com',
#  'bddgicg@hotspotmails.com',
#  'haahbhf@webgarden.com',
#  'ejbijlc@sinemailing.com',
#  'bdlaakg@faithmail.org',
#  'fihbjhl@1st-apparelsoftware.info',
#  'healfdk@deepemailbox.com',
#  'gakdele@lolas3.seo-linuxpl.com',
#  'hhkkjhl@consimail.com',
#  'lcihjia@protonmail.com',
#  'bfebbck@buysteroids365.com',
#  'fhjhaeh@o2.pl',
#  'ahcibca@baseblogger.com',
#  'gelfdda@mail.com',
#  'hdicaif@rediffmail.com',
#  'dhjjckb@motorcyclebd.com',
#  'ljjjcba@continumail.com',
#  'fghbleb@hubspotmails.com',
#  'fcceekg@ginxmail.com',
#  'eillffg@rediffmail.com',
#  'clihaal@grow-mail.com',
#  'ikhkfak@cfphone.net',
#  'fllbgik@motorcyclebd.com',
#  'eelblaa@babymails.com',
#  'jfgjldd@brmailing.com',
#  'bhhldji@hubspotmails.com',
#  'igggabl@haydoo.com',
#  'hcaejca@yahoo.com.vn',
#  'jicgakk@haydoo.com',
#  'hccejaa@baseblogger.com',
#  'habfgll@hotspotmails.com',
#  'kldhjdg@hotmail.com',
#  'ehhdcff@webgarden.com',
#  'aajblhc@mail.ru',
#  'ljglcef@hand-painted-scarves.eu',
#  'kbekigg@techspotny.com',
#  'djekhcb@teknokenar.com',
#  'efdhbjf@novartismails.com',
#  'fehebka@financehowtolearn.com',
#  'ddefkgb@rediffmail.com',
#  'gljelgl@yandex.com',
#  'jgadlhk@uminga.net',
#  'hldjbad@drupalmails.com',
#  'kickfbb@designawebsite.in',
#  'idgcdel@motorcyclebd.com',
#  'chekjci@jourrapide.com',
#  'gkalfaf@trango.co',
#  'gececli@joomlaemails.com',
#  'lfhhejj@yostyle.com.vn',
#  'jeeallc@externetworks.com',
#  'ddklikb@gmail4u.eu',
#  'kecegbe@grow-mail.com',
#  'dbjjebf@kod-maling.com',
#  'lihlfba@lexxip.com',
#  'eellkhj@freefileserver.com',
#  'glbceik@anseohero.com',
#  'jdibkji@singtelmails.com',
#  'eaklaei@digiuoso.com',
#  'ffgibel@freemailhosts.com',
#  'iejiall@bolo.eu.org',
#  'balkglj@pokemail.net',
#  'gllhkaj@yostyle.com.vn',
#  'ajicdad@ibmmails.com',
#  'eegdche@out-email.com',
#  'fceeflf@opayq.com',
#  'iekhjlf@p33.org',
#  'dhfhage@ibmmails.com',
#  'bdgligf@kodmailing.com',
#  'kjeebfa@bolo.eu.org',
#  'jlbhkjb@sin-mailing.com',
#  'echecdk@efacs.net',
#  'iihhacj@haydoo.com',
#  'kelgdle@queenofsite.online',
#  'hjefikb@porsh.net',
#  'lgldgjb@padita.net',
#  'fflgafd@kingdomheartmail.com',
#  'fjhdfif@abrighterfutureday.com',
#  'bakalfl@hubspotmails.com',
#  'gdlbkkc@grow-mail.com',
#  'cljdkki@interia.pl',
#  'jbgadbk@motorcyclebd.com',
#  'afecclj@dupontmails.com',
#  'jgblaef@mozej.com',
#  'agbhflg@abrighterfutureday.com',
#  'jedidjd@inemaling.com',
#  'hbaifkj@thiet-ke-web.org',
#  'aahealg@jourrapide.com',
#  'cfjgbcd@mozej.com',
#  'ldeeigc@mail.ru',
#  'kjfefkj@matchpol.net',
#  'adcfkhb@efacs.net',
#  'ijjfkdk@faithmail.org',
#  'igicfaa@uminga.net',
#  'egleihh@visitinbox.com',
#  'gjbfaag@binnary.com',
#  'dcklahf@mail.com',
#  'jjchllc@yandex.com',
#  'fkaiihe@uminga.net',
#  'afghelg@mail.ru',
#  'jhblfaf@yostyle.com.vn',
#  'fbjjill@mail.ru',
#  'djaeeea@financehowtolearn.com',
#  'cegibal@opayq.com',
#  'afljkjl@gloriousfuturedays.com',
#  'gadlgbb@consimail.com',
#  'gfiaaga@kingdomheartmail.com',
#  'fdjekeg@singtelmails.com',
#  'afgaffg@angrybirds2.pl',
#  'dgbddgf@lolas3.seo-linuxpl.com',
#  'lifhbek@intervisionplc.com',
#  'jblahdi@researchobservatories.org.uk',
#  'hfdhcee@yahoo.com',
#  'lifjldi@mozej.com',
#  'gdgcjll@abrighterfutureday.com',
#  'kbgcbdj@binnary.com',
#  'cdcdldd@kod-maling.com',
#  'ejjcjbl@out-email.com',
#  'hhhcgkd@ginxmail.com',
#  'heelikd@matchpol.net',
#  'jdedcla@inemaling.com',
#  'fbejgdl@opayq.com',
#  'gifbcib@kingofplace.site',
#  'cackaia@externetworks.com',
#  'dchfgja@kodmailing.com',
#  'lijabfk@sobeessentialenergy.com',
#  'haelbcg@intervisionplc.com',
#  'bebcljj@grow-mail.com',
#  'jjghigf@chemeng-masdar.com',
#  'iecdjdl@faithmail.org',
#  'hcefhgh@businesskontakts.com',
#  'dlkfaak@businesskontakts.com',
#  'hbjkebi@mailclubs.info',
#  'djdcbhl@thiet-ke-web.org',
#  'hkjjkhc@anseohero.com',
#  'cagjejd@ibmmails.com',
#  'cikbifi@yourmailbox.co',
#  'hkggefh@freefileserver.com',
#  'llhedef@outlook.com',
#  'agaffcb@mozej.com',
#  'ghblaig@thiet-ke-web.org',
#  'bhjelbk@joomlaemails.com',
#  'gjkadkf@anseohero.com',
#  'gkgbihh@researchobservatories.org.uk',
#  'laliiff@externetworks.com',
#  'ledgdad@deepemailbox.com',
#  'ghheiif@sin-mailing.com',
#  'hjgdhkh@trango.co',
#  'kghbhcd@consimail.com',
#  'adkifij@teimur.com',
#  'bhgdkjh@hotmail.com',
#  'behdfdd@outlook.com',
#  'fkkfcjj@babymails.com',
#  'cjjdhkk@checknowmail.com',
#  'cebbfcf@novartismails.com',
#  'hahalkg@researchobservatories.org.uk',
#  'bkadlba@efacs.net',
#  'jijadii@teimur.com',
#  'bikjjie@binnary.com',
#  'klhfjhc@brmailing.com',
#  'aibjidl@shopsousvide.com',
#  'bcbbegh@allemaling.com',
#  'giejfld@financehowtolearn.com',
#  'ijgldla@techspotny.com',
#  'daaljcj@businesshowtomakemoney.com',
#  'jiiigac@researchobservatories.org.uk',
#  'hhhhdjl@pullmail.info',
#  'eeedlib@bolo.eu.org',
#  'hbacllh@cliptik.net',
#  'kdfkdbf@shopsousvide.com',
#  'klaibea@yandex.com',
#  'bbddaal@businesstutorialsonline.org',
#  'cbkeeki@yopmail.com',
#  'gfggkda@webgarden.com',
#  'kdcejhf@matchpol.net',
#  'hcflaek@o2.pl',
#  'hhkgbda@lovelymail.info',
#  'elbekjk@haydoo.com',
#  'jaijfdk@teknokenar.com',
#  'cgjclhg@inemaling.com',
#  'faclifi@hubspotmails.com',
#  'dfhdagk@kodmailing.com',
#  'ffcgiak@businesshowtomakemoney.com',
#  'hegdaca@rediffmail.com',
#  'fkgdjif@angrybirds2.pl',
#  'dgeehaa@faithmail.org',
#  'hhdbhcg@ginxmail.com',
#  'akfbeik@continumail.com',
#  'hbfclib@ginxmail.com',
#  'keaadla@joomlaemails.com',
#  'fjgageh@consimail.com',
#  'iigggjc@yahoo.com',
#  'jclkick@kingofplace.site',
#  'lllgfll@motorcyclebd.com',
#  'fbajkih@gmail4u.eu',
#  'aahdblj@kod-maling.com',
#  'bideadk@pullmail.info',
#  'jikdcle@buysteroids365.com',
#  'iebefge@yostyle.com.vn',
#  'dbgjaaj@mail.ru',
#  'jhlehdd@singtelmails.com',
#  'jafihjf@checknowmail.com',
#  'fbiebil@anseohero.com',
#  'jaiaeeg@porsh.net',
#  'akkbeee@baseblogger.com',
#  'hgcibbj@uminga.net',
#  'fbcicjj@novartismails.com',
#  'fdlaial@angrybirds2.pl',
#  'baacgkk@mailbox92.biz',
#  'dcjjjhl@novartismails.com',
#  'kkhbici@hubspotmails.com',
#  'cjcbfed@digiuoso.com',
#  'ddheghd@businesstutorialsonline.org',
#  'hfablee@researchobservatories.org.uk',
#  'ihjbhbh@queenofsite.online',
#  'gekbcjj@kingdomheartmail.com',
#  'elkdilb@pokemail.net',
#  'ehadldj@singtelmails.com',
#  'cjdkbfh@consimail.com',
#  'kifhffj@intervisionplc.com',
#  'flhlaeh@freemailhosts.com',
#  'gblhkkc@cliptik.net',
#  'lhakcck@intervisionplc.com',
#  'lklabag@webgarden.com',
#  'hdalhfk@allemaling.com',
#  'hdjbegh@yostyle.com.vn',
#  'clbjekg@mozej.com',
#  'fabgfel@lolas3.seo-linuxpl.com',
#  'dheafcd@gmail.com',
#  'aakhafc@thiet-ke-web.org',
#  'bdkkgfa@freemailhosts.com',
#  'bcgfjlb@techspotny.com',
#  'kacaebj@lolas3.seo-linuxpl.com',
#  'belikjj@pokemail.net',
#  'ehfieil@angrybirds2.pl',
#  'aklhlfk@justbigbox.com',
#  'bdgikfl@ibmmails.com',
#  'bcacakf@gmail.com',
#  'ddfceja@hotmail.com',
#  'kjdlfdc@haydoo.com',
#  'hdljdeh@teimur.com',
#  'blkehfl@gloriousfuturedays.com',
#  'gcgedfk@businesskontakts.com',
#  'fgeaddj@lovelymail.info',
#  'eheckla@motorcyclebd.com',
#  'gilhigi@webgarden.com',
#  'gkligjf@sinemailing.com',
#  'beidlkh@joomlaemails.com',
#  'klfhgfl@gmail.com',
#  'dleaiia@businesstutorialsonline.org',
#  'hicegdi@webgarden.com',
#  'liejiff@lexxip.com',
#  'liihijg@mabermail.com',
#  'kfhalkc@rediffmail.com',
#  'ceekjkk@yahoo.com.vn',
#  'deaihah@grow-mail.com',
#  'bgabakj@interia.pl',
#  'agdefej@justbigbox.com',
#  'aebcgfj@porsh.net',
#  'liffidk@joomlaemails.com',
#  'dcbhdaa@mabermail.com',
#  'clijfdb@pullmail.info',
#  'bfhabkg@hubspotmails.com',
#  'dicgahj@out-email.com',
#  'gkidhbj@businesshowtomakemoney.com',
#  'dddjcda@sinemailing.com',
#  'bgbbfdf@baseblogger.com',
#  'gdligaf@buysteroids365.com',
#  'hhjghaf@externetworks.com',
#  'iclflbl@abrighterfutureday.com',
#  'liiilja@drupalmails.com',
#  'iefldkk@o2.pl',
#  'gbhakdj@porsh.net',
#  'ldllajk@businesstutorialsonline.org',
#  'ahedldf@visitinbox.com',
#  'ejeidfg@topbuysteroids365.com',
#  'giklfdd@queenofsite.online',
#  'lkablll@lexxip.com',
#  'lkekbag@externetworks.com',
#  'fhbjdgg@lexxip.com',
#  'dlbeibd@o2.pl',
#  'echelcd@angrybirds2.pl',
#  'cagcifj@grow-mail.com',
#  'lagcfdf@sinemailing.com',
#  'kadibfd@babymails.com',
#  'jdjbhll@externetworks.com',
#  'hidaedh@mailclubs.info',
#  'llaljdh@digiuoso.com',
#  'jlkdfeg@mail.com',
#  'baaegfk@kingofplace.site',
#  'aabfjhe@hotspotmails.com',
#  'kjghcke@dupontmails.com',
#  'fafejhd@lexxip.com',
#  'jhdcllh@kodmailing.com',
#  'galhbfg@temasekmail.com',
#  'ckggebi@topbuysteroids365.com',
#  'kbhiiac@hotmail.com',
#  'hdjbdih@nomail.ga',
#  'cfblllh@yourmailbox.co',
#  'hdcclkb@mozej.com',
#  'dhebdij@pokemail.net',
#  'ahgdjfj@hotspotmails.com',
#  'ljefhba@cfphone.net',
#  'fkhdclf@sobeessentialenergy.com',
#  'eekklie@nomail.ga',
#  'ejfilec@hotmail.com',
#  'kkfhlae@devsapps.net',
#  'hjelekc@lovelymail.info',
#  'afefbee@drupalmails.com',
#  'glbfjcf@justbigbox.com',
#  'ecleghf@teimur.com',
#  'eilgike@chemeng-masdar.com',
#  'hekafge@financehowtolearn.com',
#  'ikkgcdb@queenofsite.online',
#  'dchfhja@hotspotmails.com',
#  'kfjdeje@cliptik.net',
#  'abddchh@yostyle.com.vn',
#  'eaalgfd@anseohero.com',
#  'cchjkdc@dupontmails.com',
#  'licfcli@abrighterfutureday.com',
#  'iccfkgh@lovelymail.info',
#  'jejaikk@yahoo.com.vn',
#  'cigdeej@yahoo.com',
#  'hhkbdae@porsh.net',
#  'cdadbbg@teknokenar.com',
#  'dfidibi@lovelymail.info',
#  'aieekll@ginxmail.com',
#  'begeail@abrighterfutureday.com',
#  'bfldagg@externetworks.com',
#  'cbfjfdb@visitinbox.com',
#  'gjbfkde@yahoo.com',
#  'dijdaej@teimur.com',
#  'ekdfgjf@ibmmails.com',
#  'ikjilgk@mozej.com',
#  'cdcdggl@mozej.com',
#  'djbaeig@externetworks.com',
#  'hahggbg@p33.org',
#  'cdglhla@cfphone.net',
#  'kkldfdl@hand-painted-scarves.eu',
#  'bhhaghe@p33.org',
#  'hifdkaf@techspotny.com',
#  'halccgg@temasekmail.com',
#  'jgddagk@matchpol.net',
#  'fcjbaid@deepemailbox.com',
#  'alddcfe@yopmail.com',
#  'ekdahkg@justbigbox.com',
#  'leabccj@pokemail.net',
#  'fhegehe@webgarden.com',
#  'djdhhjl@allemaling.com',
#  'fkhdaij@webgarden.com',
#  'hkhfclb@o2.pl',
#  'glbkjjc@out-email.com',
#  'hkkadfb@pokemail.net',
#  'bdbagda@ginxmail.com',
#  'iecbadg@webgarden.com',
#  'fhbhefd@yahoo.com',
#  'icjjkcj@novartismails.com',
#  'jbackbc@continumail.com',
#  'jfjkfca@yopmail.com',
#  'ciidkbk@businesshowtomakemoney.com',
#  'lbbdedh@designawebsite.in',
#  'gaehfkh@yourmailbox.co',
#  'igddggb@yahoo.com.vn',
#  'lalhdhi@allemaling.com',
#  'eibkhki@haydoo.com',
#  'lfcgeja@deepemailbox.com',
#  'jhcfhif@sinemailing.com',
#  'cldbccb@webgarden.com',
#  'akgjlba@babymails.com',
#  'kjahfab@novartismails.com',
#  'bhkikih@drupalmails.com',
#  'ccbfehl@cliptik.net',
#  'lglhkdl@opayq.com',
#  'babdbfe@lovelymail.info',
#  'lfkieaj@ibmmails.com',
#  'hhcefcj@binnary.com',
#  'geabdde@businesstutorialsonline.org',
#  'cidcabd@padita.net',
#  'clkkded@abrighterfutureday.com',
#  'hajkjkj@buysteroids365.com',
#  'bffehbf@matchpol.net',
#  'iajhfhl@justbigbox.com',
#  'jdljdaj@thiet-ke-web.org',
#  'jcfggli@lolas3.seo-linuxpl.com',
#  'dhjgbef@lovelymail.info',
#  'gbfbkbc@matchpol.net',
#  'ibchhak@rediffmail.com',
#  'fhfdldj@yourmailbox.co',
#  'jllldcc@angrybirds2.pl',
#  'baighfc@efacs.net',
#  'gklfjle@visitinbox.com',
#  'fhkkgdi@rediffmail.com',
#  'heghgjk@freemailhosts.com',
#  'igehdak@dupontmails.com',
#  'ifgkbhk@yostyle.com.vn',
#  'bikaaal@lolas3.seo-linuxpl.com',
#  'lkfdkld@thiet-ke-web.org',
#  'edghiic@externetworks.com',
#  'klfichh@webgarden.com',
#  'bkejbkc@singtelmails.com',
#  'bcefkjf@shopsousvide.com',
#  'ccdehkb@out-email.com',
#  'ccbilbb@padita.net',
#  'dlelgdh@out-email.com',
#  'fkbgdij@yahoo.com.vn',
#  'fbdgkgg@gmail4u.eu',
#  'kjhlhda@haydoo.com',
#  'ddbbigk@opayq.com',
#  'jbjilga@jourrapide.com',
#  'alkfade@businesshowtomakemoney.com',
#  'dcikbff@trango.co',
#  'cadddle@o2.pl',
#  'jkdhhic@outlook.com',
#  'eigcghb@1st-apparelsoftware.info',
#  'blkflek@trango.co',
#  'dfgfjkh@hubspotmails.com',
#  'laggkbi@wordpressmails.com',
#  'aibedjl@angrybirds2.pl',
#  'kkjdiic@hypermailbox.com',
#  'cdgiicc@researchobservatories.org.uk',
#  'bgijifl@devsapps.net',
#  'kcgadgl@abrighterfutureday.com',
#  'hficacd@babymails.com',
#  'dkbkigg@queenofsite.online',
#  'hbkijaa@inemaling.com',
#  'igbhghd@kingdomheartmail.com',
#  'ehaahdd@teknokenar.com',
#  'hbcgdfi@yahoo.com.vn',
#  'djifhah@ginxmail.com',
#  'kdgcake@o2.pl',
#  'abhkhbc@sobeessentialenergy.com',
#  'ebbeghj@mailclubs.info',
#  'gbcaijl@gmail4u.eu',
#  'ghdejea@yandex.com',
#  'fadjjcc@yourmailbox.co',
#  'deihfjh@novartismails.com',
#  'haibafc@outlook.com',
#  'ddekbfc@o2.pl',
#  'hcbadlf@outlook.com',
#  'iafdaef@lovelymail.info',
#  'gakgdhd@inemaling.com',
#  'keckadf@hypermailbox.com',
#  'jgiklab@businesskontakts.com',
#  'cidikdf@wordpressmails.com',
#  'cfckcbj@inemaling.com',
#  'kfbdakg@babymails.com',
#  'ebgbfdc@businesskontakts.com',
#  'cchbcbl@pokemail.net',
#  'iafkdlb@motorcyclebd.com',
#  'akcdhfe@rediffmail.com',
#  'abghijb@rediffmail.com',
#  'egdfljd@kingdomheartmail.com',
#  'killfbh@digiuoso.com',
#  'edjiedk@temasekmail.com',
#  'jgcdiak@lovelymail.info',
#  'bcjcdjj@visitinbox.com',
#  'khdkigh@businesshowtomakemoney.com',
#  'ikbhfgf@digiuoso.com',
#  'lfkhhbe@deepemailbox.com',
#  'hkbacdi@lolas3.seo-linuxpl.com',
#  'ededjih@binnary.com',
#  'jjajgkb@1st-apparelsoftware.info',
#  'kaiacgc@chemeng-masdar.com',
#  'gecbfgi@digiuoso.com',
#  'kjaekgc@shopsousvide.com',
#  'kbldekb@queenofsite.online',
#  'kiibela@freemailhosts.com',
#  'eahaked@outlook.com',
#  'hjdhbbe@1st-apparelsoftware.info',
#  'bddaeel@pullmail.info',
#  'calfgcl@lovelymail.info',
#  'flilgdh@kod-maling.com',
#  'fgjeafj@jourrapide.com',
#  'bkbdfgc@inemaling.com',
#  'fefjehc@intervisionplc.com',
#  'glkedih@externetworks.com',
#  'ccccaeg@novartismails.com',
#  'ahhlgij@p33.org',
#  'ilkfkdg@grow-mail.com',
#  'jkdgbgf@bolo.eu.org',
#  'igbdibk@visitinbox.com',
#  'halkkij@inemaling.com',
#  'ifjghkc@brmailing.com',
#  'akkhlel@porsh.net',
#  'djflehi@financehowtolearn.com',
#  'gdalkjb@designawebsite.in',
#  'jcdlbgl@teimur.com',
#  'clcilbe@out-email.com',
#  'bjikjac@gmx.com',
#  'jkffaga@lolas3.seo-linuxpl.com',
#  'bcffjbc@joomlaemails.com',
#  'bfbkeje@kingdomheartmail.com',
#  'klijecg@dupontmails.com',
#  'ilaidji@porsh.net',
#  'ffbaiea@justbigbox.com',
#  'aefcchh@babymails.com',
#  'elkifhg@haydoo.com',
#  'hflfjhh@novartismails.com',
#  'jibcdbb@shopsousvide.com',
#  'aiaflbd@interia.pl',
#  'jaiehcf@mail.com',
#  'jicieef@1st-apparelsoftware.info',
#  'fbighjl@deepemailbox.com',
#  'hcchfdf@teimur.com',
#  'fffebda@visitinbox.com',
#  'dffjbja@grow-mail.com',
#  'ejklkjh@sin-mailing.com',
#  'fkgckbk@pokemail.net',
#  'cckcdaa@jourrapide.com',
#  'acekiej@motorcyclebd.com',
#  'dadkdec@sobeessentialenergy.com',
#  'kaejcji@kodmailing.com',
#  'lgeekhf@efacs.net',
#  'gcaddje@gmx.com',
#  'ijfihkd@intervisionplc.com',
#  'ffebehj@interia.pl',
#  'klgjehi@1st-apparelsoftware.info',
#  'baeclfj@angrybirds2.pl',
#  'iaedhhc@kodmailing.com',
#  'hekkeei@temasekmail.com',
#  'aajbldk@babymails.com',
#  'bhfjakk@interia.pl',
#  'jcakchk@allemaling.com',
#  'adihfek@freemailhosts.com',
#  'bdcjeij@grow-mail.com',
#  'dghblee@chemeng-masdar.com',
#  'fgbafgj@thiet-ke-web.org',
#  'lbdjihj@binnary.com',
#  'dldalje@porsh.net',
#  'hlbddij@faithmail.org',
#  'geggaeb@ginxmail.com',
#  'hkabige@externetworks.com',
#  'habkkbb@1st-apparelsoftware.info',
#  'dkjjekh@hand-painted-scarves.eu',
#  'eafbikh@kingofplace.site',
#  'bkkfblh@justbigbox.com',
#  'jlldhbi@sinemailing.com',
#  'glccblk@bolo.eu.org',
#  'efafcef@jourrapide.com',
#  'ikjdebj@thiet-ke-web.org',
#  'jbifilb@chemeng-masdar.com',
#  'bffiglk@mailclubs.info',
#  'djdhbia@o2.pl',
#  'gilflec@ibmmails.com',
#  'dcgegak@devsapps.net',
#  'dgbdfbd@gmx.com',
#  'bkdjijh@1st-apparelsoftware.info',
#  'cblhgdg@faithmail.org',
#  'ielfalh@researchobservatories.org.uk',
#  'beajhal@hubspotmails.com',
#  'gfjedkd@continumail.com',
#  'kheeadc@businesskontakts.com',
#  'djfefea@hypermailbox.com',
#  'lghifid@brmailing.com']

# %% [markdown]
# ### spam_websites dummy data generation code

# %%
spam_website_csv = domains_data["spam_website"]
spam_website_domains = {urlparse(website).hostname for website in spam_website_csv}

# %%
spam_websites = list()
spam_website_domains = list(spam_website_domains)
sometimes_https = [random.randint(1,1000) for i in range(0,100)]
def generate_website_domains():
    for i in range(0,1000):
        one_name = str(get_one_random_name(letters))
        one_domain = str(get_one_random_domain(spam_website_domains)) 
        prefix = "http"
        if i in sometimes_https: 
                prefix = "https"
        website = prefix+"://"+one_domain
        spam_websites.append(website)
generate_website_domains()
spam_websites
# Out:
# ['http://pureconceptions.com',
#  'http://gamehackerappdownload.com',
#  'http://zombocalypseunblocked.info',
#  'https://defineyourdirection.yolasite.com',
#  'http://hairrestorationlaboratoriesllc.com',
#  'http://gethealthywithines.info',
#  'http://goo.gl',
#  'http://cupamericas.com',
#  'http://start.me',
#  'http://alabamavclemson.co',
#  'http://true26orr.affiliatblogger.com',
#  'http://www.amztk.com',
#  'https://0rz.tw',
#  'http://www.antivirusnumberusa.com',
#  'http://www.invhome.in',
#  'http://zombocalypseunblocked.info',
#  'http://topsevenreview.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://www.karsltd.co.uk',
#  'http://musicparadiseapk.com',
#  'http://www.bee-plumbing.com',
#  'http://www.mcafeeantivirussupportnumbers.com',
#  'http://thez9.com',
#  'http://bit.ly',
#  'http://www.schweizerkredit.swiss',
#  'http://www.seobrain.ca',
#  'http://www.email-customer-care.com',
#  'http://www.culos-grandes.net',
#  'http://testy-do-policji.pl',
#  'http://thebackupgeneratorguide.joomla.com',
#  'http://www.142sure.com',
#  'http://remimalca.com',
#  'http://www.farinluck.com',
#  'http://biurocash.pl',
#  'http://falconsvspatriots.net',
#  'http://daftartembakfish.com',
#  'http://duelundernstsen0.blog5.net',
#  'http://www.ladystyl.pl',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://www.pilatesbh.info',
#  'http://None',
#  'http://falconsvspatriotslive.org',
#  'http://None',
#  'http://cracxpro.com',
#  'http://bitbucket.org',
#  'http://www.hand-painted-scarves.eu',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://1001togel.info',
#  'http://www.driversfreedownload.com',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://www.mrvehicle.net',
#  'http://odkupimyszkode.pl',
#  'http://daftartembakfish.com',
#  'http://www.artonall.com',
#  'http://www.bookstraining.com',
#  'http://zombocalypseunblocked.info',
#  'https://royalrevolt2hack.online',
#  'https://www.pilatesbh.info',
#  'http://www.codecademy.com',
#  'http://www.culos-grandes.net',
#  'http://alabama-vs-clemson.us',
#  'http://www.ivalley.co',
#  'https://www.cheapcarhirefaroairport.co.uk',
#  'https://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://www.bookstraining.com',
#  'http://www.ivalley.co',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://comocurarhemorroides.net',
#  'http://1001togel.info',
#  'https://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://flattr.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'https://falconsvspatriotslive.org',
#  'http://shadanigroup.com',
#  'http://www.powaiflats.com',
#  'http://www.apkshare.net',
#  'https://www.blackhatworld.com',
#  'http://www.horshamservices.com',
#  'http://www.powaiflats.com',
#  'http://fifa18coins.org',
#  'http://tawanrestaurant.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'https://cupamericas.com',
#  'http://www.latestforextips.com',
#  'http://rulle-gardiner.dk',
#  'http://www.bother-printer-support.net',
#  'http://minds.cool',
#  'http://pureconceptions.com',
#  'http://www.alivebetter.com',
#  'http://www.bookmarkee.com',
#  'http://www.gunsplus.com.au',
#  'http://www.nature.com',
#  'http://cupamericas.com',
#  'http://samsung.gulfegy-service.com',
#  'http://duelundernstsen0.blog5.net',
#  'http://None',
#  'http://0rz.tw',
#  'http://www.invhome.in',
#  'https://gamehackerappdownload.com',
#  'http://www.newqbo.com',
#  'http://www.mixlikes.com',
#  'http://www.karsltd.co.uk',
#  'http://www.invhome.in',
#  'http://licensekey.net',
#  'http://tawanrestaurant.com',
#  'http://giantsvspackers.co',
#  'http://www.blackhatworld.com',
#  'http://www.schweizerkredit.swiss',
#  'http://proserialkey.com',
#  'http://www.sharda.ac.in',
#  'http://tawanrestaurant.com',
#  'http://tawanrestaurant.com',
#  'http://www.bookmarkee.com',
#  'http://goo.gl',
#  'http://www.harryhost.com',
#  'http://www.alivebetter.com',
#  'http://www.newcitymovers.com',
#  'https://piratesofthecaribbean-5.org',
#  'https://www.indexemperor.com',
#  'http://www.bookstraining.com',
#  'http://www.teknokenar.com',
#  'http://www.ivalley.co',
#  'http://royalrevolt2hack.online',
#  'http://falconsvspatriotslive.org',
#  'http://alabamavclemson.co',
#  'https://www.projectwedding.com',
#  'https://cupamericas.com',
#  'http://www.quickbooksenterprisesupport.org',
#  'https://carlsbadfences.xyz',
#  'http://www.800tollfreenumber.net',
#  'http://www.apkita.com',
#  'http://www.alivebetter.com',
#  'http://crhacknew.com',
#  'http://www.bookmarkee.com',
#  'http://www.toursmiamitokeywest.com',
#  'http://clevermosaics.com',
#  'http://1001togel.info',
#  'http://www.montrealtherapy.com',
#  'http://www.approveloannow.com',
#  'http://www.myhealthyera.com',
#  'http://licensekey.net',
#  'http://www.nature.com',
#  'http://www.142sure.com',
#  'http://www.housecleanercares.com.au',
#  'https://giantsvspackers.co',
#  'http://alabama-vs-clemson.us',
#  'http://www.seobrain.ca',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://www.powaiflats.com',
#  'http://kodeware.net',
#  'http://start.me',
#  'https://www.apkita.com',
#  'http://falconsvspatriots.net',
#  'http://tropicalflowersonline.sitey.me',
#  'http://buegelstationtest.de',
#  'http://www.bother-printer-support.net',
#  'http://yorkshirepersonalinjury.mlst.org',
#  'http://royalrevolt2hack.online',
#  'http://quantumcodequantumcode.com',
#  'http://www.bother-printer-support.net',
#  'http://loginaid.org',
#  'https://globalprotec.com',
#  'http://www.approveloannow.com',
#  'http://remimalca.com',
#  'http://www.thehinduchronicle.com',
#  'https://quantumcodequantumcode.com',
#  'https://email.tecsupportnubers.com',
#  'http://www.800tollfreenumber.net',
#  'http://klout.com',
#  'http://www.messeagentur-z3.ch',
#  'http://crupusnew.com',
#  'http://daftartembakfish.com',
#  'http://gemscochackz.com',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://None',
#  'http://testy-do-policji.pl',
#  'http://www.projectwedding.com',
#  'https://1001togel.info',
#  'http://www.pilatesbh.info',
#  'https://tropicalflowersonline.sitey.me',
#  'http://saedx.com',
#  'http://www.cloudyads.com',
#  'http://shadanigroup.com',
#  'http://gethealthywithines.info',
#  'http://www.culos-grandes.net',
#  'https://mp4gain.com',
#  'http://www.142sure.com',
#  'http://www.ivalley.co',
#  'http://www.gumtree.com.au',
#  'http://www.igassetmanagement.com',
#  'http://www.mcafeeantivirussupportnumbers.com',
#  'http://1001togel.info',
#  'http://www.conductexam.com',
#  'http://csr2updatedhacknew.com',
#  'http://None',
#  'http://www.testnaiq.com.pl',
#  'http://www.mixlikes.com',
#  'http://hairrestorationlaboratoriesllc.com',
#  'http://www.fieldengineer.com',
#  'http://docs.google.com',
#  'http://www.mixlikes.com',
#  'http://www.seobrain.ca',
#  'http://www.teknokenar.com',
#  'http://cracxpro.com',
#  'http://www.curatenieprofi.ro',
#  'http://licensekey.net',
#  'http://minds.cool',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://geminiwomen47.ampedpages.com',
#  'http://www.projectwedding.com',
#  'http://geminiwomen47.ampedpages.com',
#  'http://www.culos-grandes.net',
#  'http://www.driversfreedownload.com',
#  'http://www.mirlasabino.com',
#  'https://www.hand-painted-scarves.eu',
#  'http://gethealthywithines.info',
#  'http://www.bee-plumbing.com',
#  'http://thez9.com',
#  'http://email.tecsupportnubers.com',
#  'http://www.nature.com',
#  'https://activationkeys.org',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://www.199creative.com',
#  'http://gemscochackz.com',
#  'http://alabamavsflorida.org',
#  'http://duelundernstsen0.blog5.net',
#  'http://caodangyduochcm.vn',
#  'http://www.toursmiamitokeywest.com',
#  'http://cupamericas.com',
#  'http://www.indexemperor.com',
#  'http://www.karsltd.co.uk',
#  'http://stolyskladane.pl',
#  'https://email.tecsupportnubers.com',
#  'http://www.fieldengineer.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://www.trx250r.net',
#  'http://www.email-customer-care.com',
#  'https://www.blackhatworld.com',
#  'https://www.prnewswire.com',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://caodangyduochcm.vn',
#  'http://www.antivirusnumberusa.com',
#  'http://docs.google.com',
#  'http://odkupimyszkode.pl',
#  'http://crblasterus.com',
#  'http://thez9.com',
#  'http://email.tecsupportnubers.com',
#  'http://saedx.com',
#  'http://0rz.tw',
#  'http://www.bookmarkee.com',
#  'http://talleypoole67.suomiblog.com',
#  'http://csr2updatedhacknew.com',
#  'http://globalprotec.com',
#  'https://start.me',
#  'http://gorillazhumanz.com',
#  'http://www.testnaiq.com.pl',
#  'http://www.kisaiya.co.uk',
#  'https://www.gumtree.com.au',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://hireforseo.com',
#  'http://www.ladystyl.pl',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://crupusnew.com',
#  'http://1001togel.info',
#  'http://geminiwomen47.ampedpages.com',
#  'http://true26orr.affiliatblogger.com',
#  'http://navetic.com',
#  'http://docs.google.com',
#  'http://true26orr.affiliatblogger.com',
#  'http://thebackupgeneratorguide.joomla.com',
#  'http://hairrestorationlaboratoriesllc.com',
#  'http://www.curvalicious.fit',
#  'http://caodangyduochcm.vn',
#  'http://tawanrestaurant.com',
#  'http://bangaloreescortgirl.com',
#  'http://www.angelss.in',
#  'https://www.angelss.in',
#  'http://verycheapcarinsurance.us',
#  'http://www.fieldengineer.com',
#  'http://thebackupgeneratorguide.joomla.com',
#  'https://www.driversfreedownload.com',
#  'https://flattr.com',
#  'http://www.gunsplus.com.au',
#  'http://None',
#  'http://klout.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.mcafeeantivirussupportnumbers.com',
#  'http://www.igassetmanagement.com',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://andropps.com',
#  'http://www.toursmiamitokeywest.com',
#  'http://carlsbadfences.xyz',
#  'http://www.antivirusnumberusa.com',
#  'http://www.e-perfumy.sklep.pl',
#  'http://tawanrestaurant.com',
#  'http://www.camera24x7.com',
#  'http://quantumcodequantumcode.com',
#  'http://verycheapcarinsurance.us',
#  'http://thez9.com',
#  'http://hireforseo.com',
#  'http://kauf-wert.de',
#  'http://www.bee-plumbing.com',
#  'http://clevermosaics.com',
#  'http://theseoagency.org',
#  'http://duelundernstsen0.blog5.net',
#  'http://www.bookstraining.com',
#  'http://zombocalypseunblocked.info',
#  'http://www.culos-grandes.net',
#  'https://www.bookmarkee.com',
#  'http://windowdoubleglazed.parsiblog.com',
#  'http://falconsvspatriotslive.org',
#  'http://fifa18coins.org',
#  'https://www.142sure.com',
#  'http://www.latestforextips.com',
#  'http://www.agarwalcartransport.co.in',
#  'http://alabamavsclemson.net',
#  'http://www.mirlasabino.com',
#  'http://www.codecademy.com',
#  'http://falconsvspackers.org',
#  'http://www.approveloannow.com',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://email.tecsupportnubers.com',
#  'http://www.mrvehicle.net',
#  'http://tawanrestaurant.com',
#  'http://www.angelss.in',
#  'http://www.quickbooks-customer-support-number.com',
#  'http://tawanrestaurant.com',
#  'https://www.fieldengineer.com',
#  'http://www.bookmarkee.com',
#  'http://www.harryhost.com',
#  'http://caodangyduochcm.vn',
#  'http://www.blackhatworld.com',
#  'http://buegelstationtest.de',
#  'http://www.latestforextips.com',
#  'http://www.codecademy.com',
#  'http://www.culos-grandes.net',
#  'http://www.blackhatworld.com',
#  'http://musicparadiseapk.com',
#  'http://www.karsltd.co.uk',
#  'http://www.prnewswire.com',
#  'https://gamehackerappdownload.com',
#  'https://www.oneridetheevent.com',
#  'http://www.blackhatworld.com',
#  'http://www.conductexam.com',
#  'http://jekyllandhydedubai.com',
#  'https://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://www.housecleanercares.com.au',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://hairrestorationlaboratoriesllc.com',
#  'http://mp4gain.com',
#  'http://biurocash.pl',
#  'http://podlogi24.net',
#  'http://saedx.com',
#  'http://mp4gain.com',
#  'http://freeeshopcodes.net',
#  'http://hireforseo.com',
#  'http://www.newcitymovers.com',
#  'http://www.800tollfreenumber.net',
#  'http://www.culos-grandes.net',
#  'http://www.horshamservices.com',
#  'http://piratesofthecaribbean-5.org',
#  'http://www.housecleanercares.com.au',
#  'http://freecodescheats.com',
#  'https://www.latestforextips.com',
#  'http://alabamavsclemson.net',
#  'http://www.annesylviehenchoz.com',
#  'http://www.142sure.com',
#  'http://hireforseo.com',
#  'http://biurocash.pl',
#  'http://www.blackhatworld.com',
#  'http://stolyskladane.pl',
#  'https://royaleclashgemswin.com',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://lionstreestore.tumblr.com',
#  'http://www.fireemblemheroestips.com',
#  'http://andrews29aguirre.postbit.com',
#  'http://buegelstationtest.de',
#  'http://sieumuanhanh.com',
#  'http://www.fieldengineer.com',
#  'http://www.142sure.com',
#  'http://www.powaiflats.com',
#  'http://free-credit-reports-from-all-3-bureaus.com',
#  'http://hairrestorationlaboratoriesllc.com',
#  'http://www.codecademy.com',
#  'http://duelundernstsen0.blog5.net',
#  'http://bit.ly',
#  'http://quantumcodequantumcode.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://start.me',
#  'http://www.powaiflats.com',
#  'http://www.mrvehicle.net',
#  'http://fifa18coins.org',
#  'http://carlsbadfences.xyz',
#  'http://saedx.com',
#  'http://giaytaycaocap.info',
#  'http://www.seobrain.ca',
#  'http://sieumuanhanh.com',
#  'http://www.banaby.pl',
#  'http://www.angelss.in',
#  'http://www.mixlikes.com',
#  'http://www.antivirusnumberusa.com',
#  'http://crupusnew.com',
#  'http://loginaid.org',
#  'https://hairrestorationlaboratoriesllc.com',
#  'http://www.800tollfreenumber.net',
#  'http://www.ivalley.co',
#  'https://www.messeagentur-z3.ch',
#  'https://tawanrestaurant.com',
#  'http://kodeware.net',
#  'http://www.invhome.in',
#  'http://www.pilatesbh.info',
#  'http://goo.gl',
#  'http://www.powaiflats.com',
#  'http://www.antivirusnumberusa.com',
#  'http://tanibankiet.pl',
#  'http://comocurarhemorroides.net',
#  'http://proserialkey.com',
#  'http://theseoagency.org',
#  'http://alabamavclemson.co',
#  'https://www.bee-plumbing.com',
#  'http://daftartembakfish.com',
#  'http://www.e-perfumy.sklep.pl',
#  'http://thecatholicthing.org',
#  'http://falconsvspatriots.net',
#  'http://klout.com',
#  'http://caodangyduochcm.vn',
#  'http://www.bother-printer-support.net',
#  'http://www.newcitymovers.com',
#  'http://www.bother-printer-support.net',
#  'https://proserialkey.com',
#  'http://alabamavwashington.org',
#  'http://www.199creative.com',
#  'https://handheldshowerheadguide.com',
#  'https://handheldshowerheadguide.com',
#  'http://www.teknokenar.com',
#  'https://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://www.projectwedding.com',
#  'http://alabamavsflorida.org',
#  'http://www.toursmiamitokeywest.com',
#  'http://crhacknew.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.toursmiamitokeywest.com',
#  'http://falconsvspatriots.net',
#  'http://www.horshamservices.com',
#  'http://www.projectwedding.com',
#  'http://duelundernstsen0.blog5.net',
#  'http://www.angelss.in',
#  'http://royaleclashgemswin.com',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://www.sharda.ac.in',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://topsevenreview.com',
#  'http://sieumuanhanh.com',
#  'https://www.camera24x7.com',
#  'http://www.esiptel.pl',
#  'http://www.mcafeeantivirussupportnumbers.com',
#  'http://www.seobrain.ca',
#  'https://yorkshirepersonalinjury.mlst.org',
#  'http://testy-do-policji.pl',
#  'http://thebackupgeneratorguide.joomla.com',
#  'http://kauf-wert.de',
#  'http://www.mcafeeantivirussupportnumbers.com',
#  'http://www.buyhealthmart.com',
#  'http://globalprotec.com',
#  'http://alabamavclemson.co',
#  'http://alabamavsflorida.org',
#  'http://goo.gl',
#  'http://start.me',
#  'http://proserialkey.com',
#  'http://www.indexemperor.com',
#  'http://mp4gain.com',
#  'http://www.ivalley.co',
#  'http://1001togel.info',
#  'http://www.culos-grandes.net',
#  'http://www.fireemblemheroestips.com',
#  'http://www.cloudyads.com',
#  'http://alaamiahclean.com',
#  'https://www.codecademy.com',
#  'http://www.quickbooks-customer-support-number.com',
#  'http://www.latestforextips.com',
#  'http://podlogi24.net',
#  'http://www.horshamservices.com',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://crblasterus.com',
#  'http://alabamavwashington.org',
#  'http://www.oneridetheevent.com',
#  'http://www.amztk.com',
#  'http://free-credit-reports-from-all-3-bureaus.com',
#  'http://www.bookmarkee.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://www.antivirusnumberusa.com',
#  'http://zombocalypseunblocked.info',
#  'https://start.me',
#  'https://mp4gain.com',
#  'http://alaamiahclean.com',
#  'http://topsevenreview.com',
#  'https://minds.cool',
#  'http://lionstreestore.tumblr.com',
#  'http://www.antivirusnumberusa.com',
#  'http://www.ladystyl.pl',
#  'http://www.apkshare.net',
#  'http://www.142sure.com',
#  'http://crhacknew.com',
#  'http://www.142sure.com',
#  'http://carlsbadfences.xyz',
#  'http://www.142sure.com',
#  'http://theseoagency.org',
#  'http://www.apkshare.net',
#  'http://wrenchankle7.jiliblog.com',
#  'http://email.tecsupportnubers.com',
#  'http://vaytinchap99.com',
#  'http://www.agarwalcartransport.co.in',
#  'http://www.kisaiya.co.uk',
#  'http://testy-do-policji.pl',
#  'http://lionstreestore.tumblr.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://royaleclashgemswin.com',
#  'http://www.angelss.in',
#  'http://andropps.com',
#  'http://giaytaycaocap.info',
#  'http://www.oneridetheevent.com',
#  'http://mp4gain.com',
#  'http://www.robloxhack.org',
#  'http://www.replicahandbags.space',
#  'https://www.sharda.ac.in',
#  'https://www.quickbooks-customer-support-number.com',
#  'http://talleypoole67.suomiblog.com',
#  'http://vaytinchap99.com',
#  'https://tanibankiet.pl',
#  'http://comocurarhemorroides.net',
#  'http://verycheapcarinsurance.us',
#  'http://crhacknew.com',
#  'http://alabamavclemson.co',
#  'http://duelundernstsen0.blog5.net',
#  'http://www.montrealtherapy.com',
#  'http://www.testnaiq.com.pl',
#  'http://windowdoubleglazed.parsiblog.com',
#  'http://samsung.gulfegy-service.com',
#  'http://www.myhealthyera.com',
#  'http://www.newqbo.com',
#  'http://gamehackerappdownload.com',
#  'http://falconsvspatriotslive.org',
#  'http://royalrevolt2hack.online',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://www.projectwedding.com',
#  'http://vaytinchap99.com',
#  'http://www.annesylviehenchoz.com',
#  'http://www.dubaismile.com',
#  'http://www.kisaiya.co.uk',
#  'http://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'http://gamehackerappdownload.com',
#  'http://alabama-vs-clemson.us',
#  'http://vaytinchap99.com',
#  'http://daftartembakfish.com',
#  'https://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'http://docs.google.com',
#  'https://cochackertop.com',
#  'http://www.indexemperor.com',
#  'http://www.invhome.in',
#  'http://free-credit-reports-from-all-3-bureaus.com',
#  'http://mp4gain.com',
#  'http://www.email-customer-care.com',
#  'http://shadanigroup.com',
#  'http://cybyte.com',
#  'http://www.hand-painted-scarves.eu',
#  'http://biurocash.pl',
#  'http://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'http://buegelstationtest.de',
#  'https://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://crhacknew.com',
#  'http://verycheapcarinsurance.us',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://wizaccounting.com',
#  'http://yourshot.nationalgeographic.com',
#  'http://yorkshirepersonalinjury.mlst.org',
#  'http://shadanigroup.com',
#  'http://csr2updatedhacknew.com',
#  'http://giantsvspackers.co',
#  'http://www.approveloannow.com',
#  'http://www.kisaiya.co.uk',
#  'http://duelundernstsen0.blog5.net',
#  'http://quantumcodequantumcode.com',
#  'http://www.dubaismile.com',
#  'http://www.800tollfreenumber.net',
#  'http://www.approveloannow.com',
#  'http://www.artonall.com',
#  'http://gethealthywithines.info',
#  'https://alabamavsflorida.org',
#  'http://www.sharda.ac.in',
#  'http://www.indexemperor.com',
#  'http://crhacknew.com',
#  'https://twitter.com',
#  'http://www.myhealthyera.com',
#  'http://tanibankiet.pl',
#  'http://www.gunsplus.com.au',
#  'http://www.codecademy.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://zombocalypseunblocked.info',
#  'http://alabama-vs-clemson.us',
#  'http://xn--42c6ajj7bc8hyfua2dt.com',
#  'http://www.testnaiq.com.pl',
#  'http://www.schweizerkredit.swiss',
#  'http://vaytinchap99.com',
#  'http://0rz.tw',
#  'http://www.amztk.com',
#  'http://handheldshowerheadguide.com',
#  'http://wrenchankle7.jiliblog.com',
#  'https://activationkeys.org',
#  'https://www.thehinduchronicle.com',
#  'http://www.apkita.com',
#  'http://tropicalflowersonline.sitey.me',
#  'http://www.annesylviehenchoz.com',
#  'http://freecodescheats.com',
#  'http://finance.yahoo.com',
#  'http://goo.gl',
#  'http://www.ladystyl.pl',
#  'http://www.gunsplus.com.au',
#  'http://www.schweizerkredit.swiss',
#  'http://www.cheapcarhirefaroairport.co.uk',
#  'http://cracxpro.com',
#  'http://cochackertop.com',
#  'http://alabamavclemson.co',
#  'http://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'https://windowdoubleglazed.parsiblog.com',
#  'http://royalrevolt2hack.online',
#  'http://www.e-perfumy.sklep.pl',
#  'http://www.toursmiamitokeywest.com',
#  'http://www.driversfreedownload.com',
#  'http://www.conductexam.com',
#  'https://www.gunsplus.com.au',
#  'http://www.curatenieprofi.ro',
#  'http://kauf-wert.de',
#  'http://crhacknew.com',
#  'http://gethealthywithines.info',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://www.messeagentur-z3.ch',
#  'https://www.artonall.com',
#  'http://www.gotshirtscy.com',
#  'http://www.agarwalcartransport.co.in',
#  'http://www.latestforextips.com',
#  'http://jekyllandhydedubai.com',
#  'http://bit.ly',
#  'http://www.driversfreedownload.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://flattr.com',
#  'http://www.e-perfumy.sklep.pl',
#  'http://podlogi24.net',
#  'http://wrenchankle7.jiliblog.com',
#  'http://www.apkshare.net',
#  'https://www.montrealtherapy.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.prnewswire.com',
#  'http://hireforseo.com',
#  'http://www.karsltd.co.uk',
#  'http://www.toursmiamitokeywest.com',
#  'http://www.fieldengineer.com',
#  'http://alaamiahclean.com',
#  'https://tropicalflowersonline.sitey.me',
#  'http://quantumcodequantumcode.com',
#  'http://andropps.com',
#  'http://email.tecsupportnubers.com',
#  'http://saedx.com',
#  'http://www.curatenieprofi.ro',
#  'http://www.nature.com',
#  'http://flattr.com',
#  'https://andropps.com',
#  'http://andropps.com',
#  'http://www.alivebetter.com',
#  'http://free-credit-reports-from-all-3-bureaus.com',
#  'http://docs.google.com',
#  'http://alabama-vs-clemson.us',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'http://bit.ly',
#  'http://giantsvspackers.co',
#  'http://www.apkita.com',
#  'http://rulle-gardiner.dk',
#  'http://kodeware.net',
#  'http://www.apkita.com',
#  'http://odkupimyszkode.pl',
#  'http://www.messeagentur-z3.ch',
#  'http://bit.ly',
#  'http://www.bother-printer-support.net',
#  'http://www.agarwalcartransport.co.in',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://duelundernstsen0.blog5.net',
#  'http://true26orr.affiliatblogger.com',
#  'https://www.mrvehicle.net',
#  'http://www.camera24x7.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://quantumcodequantumcode.com',
#  'https://karyasahabatglobal.com',
#  'http://www.hand-painted-scarves.eu',
#  'http://remimalca.com',
#  'http://crblasterus.com',
#  'http://wizaccounting.com',
#  'http://mp4gain.com',
#  'http://freecodescheats.com',
#  'http://cochackertop.com',
#  'http://yorkshirepersonalinjury.mlst.org',
#  'http://www.pilatesbh.info',
#  'http://kauf-wert.de',
#  'http://www.igassetmanagement.com',
#  'https://www.trx250r.net',
#  'http://freeeshopcodes.net',
#  'http://www.driversfreedownload.com',
#  'http://www.amztk.com',
#  'http://thez9.com',
#  'http://www.annesylviehenchoz.com',
#  'http://www.blackhatworld.com',
#  'http://www.agarwalcartransport.co.in',
#  'http://gamehackerappdownload.com',
#  'https://yourshot.nationalgeographic.com',
#  'http://comocurarhemorroides.net',
#  'http://gorillazhumanz.com',
#  'http://www.driversfreedownload.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.kisaiya.co.uk',
#  'http://jekyllandhydedubai.com',
#  'http://www.latestforextips.com',
#  'http://www.bookstraining.com',
#  'http://crupusnew.com',
#  'http://kodeware.net',
#  'http://falconsvspatriotslive.org',
#  'http://www.esiptel.pl',
#  'http://www.invhome.in',
#  'http://rulle-gardiner.dk',
#  'http://www.codecademy.com',
#  'http://defineyourdirection.yolasite.com',
#  'http://globalprotec.com',
#  'http://bit.ly',
#  'http://superventasclub.blogspot.com.es',
#  'http://www.nature.com',
#  'http://andrews29aguirre.postbit.com',
#  'http://email.tecsupportnubers.com',
#  'http://loginaid.org',
#  'http://finance.yahoo.com',
#  'https://www.apkshare.net',
#  'http://www.amztk.com',
#  'http://www.apkshare.net',
#  'http://www.fieldengineer.com',
#  'http://www.800tollfreenumber.net',
#  'http://yorkshirepersonalinjury.mlst.org',
#  'http://www.approveloannow.com',
#  'http://remimalca.com',
#  'http://giayplus.com',
#  'http://pureconceptions.com',
#  'http://daftartembakfish.com',
#  'http://www.curvalicious.fit',
#  'http://www.pilatesbh.info',
#  'http://loginaid.org',
#  'http://tanibankiet.pl',
#  'http://giantsvspackers.co',
#  'http://licensekey.net',
#  'http://www.antivirusnumberusa.com',
#  'http://www.annesylviehenchoz.com',
#  'https://kauf-wert.de',
#  'http://www.quickbooks-customer-support-number.com',
#  'http://www.ivalley.co',
#  'http://proserialkey.com',
#  'http://pureconceptions.com',
#  'http://andropps.com',
#  'http://www.annesylviehenchoz.com',
#  'http://www.142sure.com',
#  'http://klout.com',
#  'http://alabamavclemson.co',
#  'http://email.tecsupportnubers.com',
#  'http://www.myhealthyera.com',
#  'http://www.agarwalcartransport.co.in',
#  'http://www.fieldengineer.com',
#  'http://kodeware.net',
#  'http://royaleclashgemswin.com',
#  'http://www.142sure.com',
#  'http://odkupimyszkode.pl',
#  'http://www.sacredhypnogoddess.com',
#  'http://www.bookmarkee.com',
#  'http://giaytaycaocap.info',
#  'http://quantumcodequantumcode.com',
#  'http://buegelstationtest.de',
#  'http://www.mixlikes.com',
#  'http://www.invhome.in',
#  'http://giantsvspackers.co',
#  'http://jekyllandhydedubai.com',
#  'http://minds.cool',
#  'http://www.boostingkings.com',
#  'https://crblasterus.com',
#  'http://www.800tollfreenumber.net',
#  'http://freecodescheats.com',
#  'http://defineyourdirection.yolasite.com',
#  'http://bitbucket.org',
#  'http://biurocash.pl',
#  'http://quantumcodequantumcode.com',
#  'http://www.alivebetter.com',
#  'http://www.dubaismile.com',
#  'http://stolyskladane.pl',
#  'http://www.kisaiya.co.uk',
#  'https://topsevenreview.com',
#  'http://www.blackhatworld.com',
#  'http://theseoagency.org',
#  'http://superventasclub.blogspot.com.es',
#  'https://vaytinchap99.com',
#  'http://www.harryhost.com',
#  'http://www.replicahandbags.space',
#  'http://www.camera24x7.com',
#  'http://tawanrestaurant.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://giayplus.com',
#  'https://1001togel.info',
#  'http://www.buyhealthmart.com',
#  'http://comocurarhemorroides.net',
#  'http://gethealthywithines.info',
#  'http://podlogi24.net',
#  'http://hireforseo.com',
#  'http://carlsbadfences.xyz',
#  'http://www.driversfreedownload.com',
#  'http://kauf-wert.de',
#  'http://true26orr.affiliatblogger.com',
#  'http://www.angelss.in',
#  'http://crblasterus.com',
#  'http://www.fieldengineer.com',
#  'http://www.blackhatworld.com',
#  'http://tropicalflowersonline.sitey.me',
#  'http://klout.com',
#  'http://alabamavsflorida.org',
#  'http://www.driversfreedownload.com',
#  'http://yourshot.nationalgeographic.com',
#  'http://www.camera24x7.com',
#  'http://www.horshamservices.com',
#  'http://saedx.com',
#  'http://www.schweizerkredit.swiss',
#  'http://www.mixlikes.com',
#  'http://twitter.com',
#  'https://www.approveloannow.com',
#  'http://mp4gain.com',
#  'http://www.buyhealthmart.com',
#  'http://navetic.com',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://licensekey.net',
#  'http://yorkshirepersonalinjury.mlst.org',
#  'http://www.email-customer-care.com',
#  'https://xn--l3cfhbc4blu7hme8nya7h5b.com',
#  'http://www.indexemperor.com',
#  'http://crblasterus.com',
#  'http://www.amztk.com',
#  'http://freecodescheats.com',
#  'http://klout.com',
#  'http://www.sacredhypnogoddess.com',
#  'http://wizaccounting.com',
#  'http://andropps.com',
#  'http://globalprotec.com',
#  'https://carlsbadfences.xyz',
#  'http://buegelstationtest.de',
#  'http://www.apkita.com',
#  'http://hdwatchtvgametv.com',
#  'http://twitter.com',
#  'http://www.annesylviehenchoz.com',
#  'http://samsung.gulfegy-service.com',
#  'http://www.curatenieprofi.ro',
#  'http://www.seobrain.ca',
#  'http://remimalca.com',
#  'http://xn--o3cauave1ec9b1ab7psbzd.com',
#  'http://www.quickbooksenterprisesupport.org',
#  'http://comocurarhemorroides.net',
#  'https://www.quickbooksenterprisesupport.org',
#  'http://freecodescheats.com',
#  'http://thecatholicthing.org',
#  'http://www.housecleanercares.com.au',
#  'http://www.gotshirtscy.com',
#  'http://www.gumtree.com.au',
#  'http://detroitmetrotowing.blogspot.com',
#  'http://www.gunsplus.com.au',
#  'http://freecodescheats.com',
#  'http://www.dubaismile.com',
#  'http://saedx.com',
#  'http://alaamiahclean.com',
#  'http://xn--22cdj7cza3a5azftb6cg2h1eva.com',
#  'https://www.teknokenar.com',
#  'http://gemscochackz.com',
#  'http://stolyskladane.pl',
#  'http://www.teknokenar.com',
#  'http://www.toursmiamitokeywest.com',
#  'http://cracxpro.com',
#  'http://www.horshamservices.com',
#  'https://www.fieldengineer.com',
#  'http://talleypoole67.suomiblog.com',
#  'http://crupusnew.com',
#  'http://andrews29aguirre.postbit.com',
#  'http://gamehackerappdownload.com',
#  'http://freeeshopcodes.net',
#  'http://freeeshopcodes.net',
#  'http://www.pilatesbh.info',
#  'http://talleypoole67.suomiblog.com',
#  'http://bestdryherbvaporizerunder100.blogspot.com',
#  'http://jekyllandhydedubai.com',
#  'http://testy-do-policji.pl',
#  'http://thecatholicthing.org',
#  'http://minds.cool',
#  'https://kodeware.net',
#  'http://www.ladystyl.pl',
#  'http://wizaccounting.com',
#  'http://www.driversfreedownload.com',
#  'http://giayplus.com',
#  'http://www.ivalley.co',
#  'https://www.gumtree.com.au',
#  'http://tropicalflowersonline.sitey.me',
#  'http://piratesofthecaribbean-5.org',
#  'http://cochackertop.com',
#  'https://comocurarhemorroides.net',
#  'http://www.boostingkings.com',
#  'https://musicparadiseapk.com',
#  'http://www.come-curare-le-emorroidi.it',
#  'http://csr2updatedhacknew.com',
#  'http://www.driversfreedownload.com',
#  'http://www.housecleanercares.com.au',
#  'http://duelundernstsen0.blog5.net',
#  'http://www.bookmarkee.com',
#  'http://www.driversfreedownload.com',
#  'http://www.karsltd.co.uk',
#  'http://navetic.com',
#  'http://www.toursmiamitokeywest.com',
#  'http://samsung.gulfegy-service.com',
#  'http://loginaid.org',
#  'http://royalrevolt2hack.online',
#  'http://www.boostingkings.com',
#  'http://daftartembakfish.com',
#  'http://yorkshirepersonalinjury.mlst.org',
#  'http://proserialkey.com',
#  'http://caodangyduochcm.vn',
#  'http://www.messeagentur-z3.ch',
#  'http://www.myhealthyera.com',
#  'http://thez9.com',
#  'http://falconsvspatriotslive.org',
#  'http://www.quickbooksenterprisesupport.org',
#  'http://yourshot.nationalgeographic.com',
#  'http://activationkeys.org',
#  'http://fifa18coins.org',
#  'http://www.annesylviehenchoz.com',
#  'https://www.farinluck.com',
#  'http://giaytaycaocap.info',
#  'http://gamehackerappdownload.com',
#  'http://www.mixlikes.com',
#  'http://www.projectwedding.com',
#  'http://karyasahabatglobal.com',
#  'http://www.pilatesbh.info',
#  'http://alabamavsflorida.org',
#  'https://www.oneridetheevent.com',
#  'http://wrenchankle7.jiliblog.com',
#  'http://zombocalypseunblocked.info',
#  'http://www.gunsplus.com.au',
#  'https://piratesofthecaribbean-5.org',
#  'http://wrenchankle7.jiliblog.com',
#  'http://thecatholicthing.org',
#  'http://comocurarhemorroides.net',
#  'http://www.replicahandbags.space',
#  'http://proserialkey.com',
#  'http://tawanrestaurant.com',
#  'http://detroitmetrotowing.blogspot.com',
#  'https://biurocash.pl',
#  'http://www.buyhealthmart.com',
#  'http://caodangyduochcm.vn',
#  'http://alabamavwashington.org',
#  'http://thez9.com',
#  'http://proserialkey.com',
#  'http://cracxpro.com',
#  'http://www.apkshare.net',
#  'http://goo.gl',
#  'http://hdwatchtvgametv.com',
#  'http://windowdoubleglazed.parsiblog.com',
#  'http://thez9.com',
#  'http://bit.ly',
#  'https://www.bookstraining.com',
#  'http://proserialkey.com',
#  'http://hairrestorationlaboratoriesllc.com',
#  'http://falconsvspatriotslive.org',
#  'http://pureconceptions.com',
#  'http://giayplus.com',
#  'http://remimalca.com',
#  'http://bangaloreescortgirl.com',
#  'http://www.mixlikes.com',
#  'http://thebackupgeneratorguide.joomla.com',
#  'http://comocurarhemorroides.net',
#  'http://thez9.com',
#  'http://xn--42cgal0e2budc6bydvc0dvg1cvcd.com',
#  'http://biurocash.pl',
#  'http://mp4gain.com',
#  'http://cybyte.com',
#  'http://www.bee-plumbing.com',
#  'http://www.ladystyl.pl',
#  'http://bit.ly',
#  'http://navetic.com',
#  'http://giantsvspackers.co',
#  'http://www.myhealthyera.com',
#  'http://docs.google.com',
#  'http://www.mixlikes.com',
#  'http://proserialkey.com',
#  'http://www.curvalicious.fit',
#  'http://falconsvspackers.org',
#  'http://www.latestforextips.com']

# %% [markdown]
# ### spam_bios dummy data generation code

# %%
bio_url = " www.spam.org "
import json
import urllib.request
url = urllib.request.urlopen("https://raw.githubusercontent.com/sindresorhus/mnemonic-words/master/words.json")
words = json.loads(url.read())
random_word = random.choice(words)
spam_bio_link = [random.randint(1,size) for i in range(0,int(size*0.8))]


spam_bios=[0 for i in range(size)]
sentence = ''
for j in range(size):
    for k in range(3):
        for i in range(random.randint(0,50)):
             sentence = random.choice(words) +" "+"seo"+" "+sentence
             i+=random.randint(0,10)
        k+=1
        if j in spam_bio_link:
            sentence = sentence + bio_url
    spam_bios[j]= sentence
    j+=1

len(spam_bios)
# Out:
# 1000

# %% [markdown]
# ### spam_areas dummy data generation code

# %%
spam_areas = [None] *size

# %%
spam_area_set = [random.randint(1,size) for i in range(0,int(size*0.02))]
for i in spam_area_set:
    spam_areas[i] = "spam_area"

# %%
len(spam_areas)
# Out:
# 1000

# %% [markdown]
# ### spam_privs dummy data generation code

# %%
spam_privs = [0] * size

# %% [markdown]
# ### spam_genders dummy data generation code

# %%
spam_gender_not_set = [random.randint(1,size) for i in range(0,int(size*0.3))]
spam_genders = ["gender"]*size
for i in spam_gender_not_set:
    spam_genders[i] = None

# %% [markdown]
# ### spam_birth_dates dummy data generation code

# %%
import datetime
import random
		
spam_birth_dates = []
spam_birthdates_not_set = [random.randint(1,size) for i in range(0,int(size*0.4))]
earliest = datetime.datetime(1998, 1, 1, 2, 30, 27, 5)
latest  = datetime.datetime.now()  - timedelta(days=7000)
delta = latest - earliest
int_delta = (delta.days * 24 * 60 * 60) + delta.seconds    
for i in range(size):
    random_second = random.randrange(int_delta)
    random_date = earliest + datetime.timedelta(seconds = random_second)
    spam_birth_dates.append(random_date)   


for i in spam_birthdates_not_set:
    spam_birth_dates[i] = None
len(spam_birth_dates)
# Out:
# 1000

# %% [markdown]
# ### spam_member_since dummy data generation code

# %%
import datetime
import random
		
spam_member_since = []
earliest = datetime.datetime(2000, 1, 1, 2, 30, 27, 5)
latest  = datetime.datetime.now()
delta = latest - earliest
int_delta = (delta.days * 24 * 60 * 60) + delta.seconds    
for i in range(size):
    random_second = random.randrange(int_delta)
    random_date = earliest + datetime.timedelta(seconds = random_second)
    spam_member_since.append(random_date)    
    
len(spam_member_since)
# Out:
# 1000

# %% [markdown]
# ### spam_email_confirm_dates dummy data generation code

# %%
from datetime import timedelta

spam_email_confirm_dates = list()

spam_email_confirm_dates_not_set = [random.randint(1,size) for i in range(0,int(size*0.1))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = spam_member_since[i] + random_lengths[i]
    spam_email_confirm_dates.append( temp)
spam_email_confirm_dates

for i in spam_email_confirm_dates_not_set:
    spam_email_confirm_dates[i] = None

# %% [markdown]
# ### spam_last_updated dummy data generation code

# %%
#spam_last_updated
spam_last_updated = list()

spam_last_updated_not_set = [random.randint(1,size) for i in range(0,int(size*0.2))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = spam_member_since[i] + random_lengths[i]
    spam_last_updated.append( temp)


for i in spam_last_updated_not_set:
    spam_last_updated[i] = None

# %% [markdown]
# ### spam_last_login_dates dummy data generation code

# %%
spam_last_login_dates = list()

spam_last_login_dates_not_set = [random.randint(1,size) for i in range(0,int(size*0.2))]

random_lengths = [timedelta(seconds = random.randint(1,100000)) for i in range(0,size)]

for i in range(0,size):
    temp = spam_member_since[i] + random_lengths[i]
    spam_last_login_dates.append( temp)


for i in spam_last_login_dates_not_set:
    spam_last_login_dates[i] = None

# %% [markdown]
# ## Create pickle file from generated data

# %%
import pickle

# %%
spam_dummy_data = {}

# %%
for i in range(1,size):
    temp = {
        'email' : spam_emails[i],
        'website' : spam_websites[i],
        'bio' : spam_bios[i],
        'area' : spam_areas[i],
        'privs' : spam_privs[i],
        'gender' : spam_gender[i],
        'birth_date' : spam_birth_dates[i],
        'member_since' : spam_member_since[i],
        'email_confirm_date' : spam_email_confirm_dates[i],
        'last_updated' : spam_last_updated[i],
        'last_login_date' : spam_last_login_dates[i],
    }
    spam_dummy_data[i] = temp

# %%
with open('spam_editors_dummy_data.pickle', 'wb') as handle:
    pickle.dump(spam_dummy_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
